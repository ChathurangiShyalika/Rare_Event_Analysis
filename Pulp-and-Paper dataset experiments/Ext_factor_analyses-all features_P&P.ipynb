# %%
import matplotlib.pyplot as plt4
import numpy as np
import pandas as pd
from matplotlib import pyplot

# %%
df = pd.read_csv("processminer-rare-event-mts - data.csv") 
df.head(n=5)  # visualize the data.
# Out:
#           time  y        x1        x2        x3         x4        x5  \
# 0  5/1/99 0:00  0  0.376665 -4.596435 -4.095756  13.497687 -0.118830
# 1  5/1/99 0:02  0  0.475720 -4.542502 -4.018359  16.230659 -0.128733
# 2  5/1/99 0:04  0  0.363848 -4.681394 -4.353147  14.127997 -0.138636
# 3  5/1/99 0:06  0  0.301590 -4.758934 -4.023612  13.161566 -0.148142
# 4  5/1/99 0:08  0  0.265578 -4.749928 -4.333150  15.267340 -0.155314
#
#           x6        x7        x8  ...        x52       x53       x54  \
# 0 -20.669883  0.000732 -0.061114  ...  10.091721  0.053279 -4.936434
# 1 -18.758079  0.000732 -0.061114  ...  10.095871  0.062801 -4.937179
# 2 -17.836632  0.010803 -0.061114  ...  10.100265  0.072322 -4.937924
# 3 -18.517601  0.002075 -0.061114  ...  10.104660  0.081600 -4.938669
# 4 -17.505913  0.000732 -0.061114  ...  10.109054  0.091121 -4.939414
#
#          x55        x56       x57       x58       x59       x60  x61
# ...

# %%
# Remove time column 
df = df.drop(['time','y'], axis=1)

# %%
# Remove y column 
df = df.drop(['y'], axis=1)

# %%
#feature_drift_percentage 
# find the percentage change with the previous row
df2= df
df2=df2.pct_change()
df2=df2.rename(columns=
               {'x1': 'x1_pct_change', 'x2': 'x2_pct_change','x3': 'x3_pct_change', 'x4': 'x4_pct_change', 'x5': 'x5_pct_change',
               'x6': 'x6_pct_change', 'x7': 'x7_pct_change','x8': 'x8_pct_change', 'x9': 'x9_pct_change', 'x10': 'x10_pct_change',
                'x11': 'x11_pct_change', 'x12': 'x12_pct_change','x13': 'x13_pct_change', 'x14': 'x14_pct_change', 'x15': 'x15_pct_change',
                'x16': 'x16_pct_change', 'x17': 'x17_pct_change','x18': 'x18_pct_change', 'x19': 'x19_pct_change', 'x20': 'x20_pct_change',
               'x21': 'x21_pct_change', 'x22': 'x22_pct_change','x23': 'x23_pct_change', 'x24': 'x24_pct_change', 'x25': 'x25_pct_change',
                'x26': 'x26_pct_change', 'x27': 'x27_pct_change','x28': 'x28_pct_change', 'x29': 'x29_pct_change',
                'x30': 'x30_pct_change', 'x31': 'x31_pct_change','x32': 'x32_pct_change', 'x33': 'x33_pct_change',
                'x34': 'x34_pct_change', 'x35': 'x35_pct_change','x36': 'x36_pct_change', 'x37': 'x37_pct_change',
                'x38': 'x38_pct_change', 'x39': 'x39_pct_change','x40': 'x40_pct_change', 'x41': 'x41_pct_change',
                'x42': 'x42_pct_change', 'x43': 'x43_pct_change','x44': 'x44_pct_change', 'x45': 'x45_pct_change',
                'x46': 'x46_pct_change', 'x47': 'x47_pct_change','x48': 'x48_pct_change', 'x49': 'x49_pct_change',
                'x50': 'x50_pct_change', 'x51': 'x51_pct_change','x52': 'x52_pct_change', 'x53': 'x53_pct_change',
                'x54': 'x54_pct_change', 'x55': 'x55_pct_change','x56': 'x56_pct_change', 'x57': 'x57_pct_change',
                'x58': 'x58_pct_change', 'x59': 'x59_pct_change','x60': 'x60_pct_change', 'x61': 'x61_pct_change'})
df2

# %%
#feature_drift_percentage -PERIOD-5
# find the percentage change with the previous row
df22= df
df22=df22.pct_change(periods=5)
df22=df22.rename(columns=
               {'x1': 'x1_pct_change_5', 'x2': 'x2_pct_change_5','x3': 'x3_pct_change_5', 'x4': 'x4_pct_change_5', 'x5': 'x5_pct_change_5',
               'x6': 'x6_pct_change_5', 'x7': 'x7_pct_change_5','x8': 'x8_pct_change_5', 'x9': 'x9_pct_change_5', 'x10': 'x10_pct_change_5',
                'x11': 'x11_pct_change_5', 'x12': 'x12_pct_change_5','x13': 'x13_pct_change_5', 'x14': 'x14_pct_change_5', 'x15': 'x15_pct_change_5',
                'x16': 'x16_pct_change_5', 'x17': 'x17_pct_change_5','x18': 'x18_pct_change_5', 'x19': 'x19_pct_change_5', 'x20': 'x20_pct_change_5',
               'x21': 'x21_pct_change_5', 'x22': 'x22_pct_change_5','x23': 'x23_pct_change_5', 'x24': 'x24_pct_change_5', 'x25': 'x25_pct_change_5',
                'x26': 'x26_pct_change_5', 'x27': 'x27_pct_change_5','x28': 'x28_pct_change_5', 'x29': 'x29_pct_change_5',
                'x30': 'x30_pct_change_5', 'x31': 'x31_pct_change_5','x32': 'x32_pct_change_5', 'x33': 'x33_pct_change_5',
                'x34': 'x34_pct_change_5', 'x35': 'x35_pct_change_5','x36': 'x36_pct_change_5', 'x37': 'x37_pct_change_5',
                'x38': 'x38_pct_change_5', 'x39': 'x39_pct_change_5','x40': 'x40_pct_change_5', 'x41': 'x41_pct_change_5',
                'x42': 'x42_pct_change_5', 'x43': 'x43_pct_change_5','x44': 'x44_pct_change_5', 'x45': 'x45_pct_change_5',
                'x46': 'x46_pct_change_5', 'x47': 'x47_pct_change_5','x48': 'x48_pct_change_5', 'x49': 'x49_pct_change_5',
                'x50': 'x50_pct_change_5', 'x51': 'x51_pct_change_5','x52': 'x52_pct_change_5', 'x53': 'x53_pct_change_5',
                'x54': 'x54_pct_change_5', 'x55': 'x55_pct_change_5','x56': 'x56_pct_change_5', 'x57': 'x57_pct_change_5',
                'x58': 'x58_pct_change_5', 'x59': 'x59_pct_change_5','x60': 'x60_pct_change_5', 'x61': 'x61_pct_change_5'})
df22
# Out:
#        x1_pct_change_5  x2_pct_change_5  x3_pct_change_5  x4_pct_change_5  \
# 0                  NaN              NaN              NaN              NaN
# 1                  NaN              NaN              NaN              NaN
# 2                  NaN              NaN              NaN              NaN
# 3                  NaN              NaN              NaN              NaN
# 4                  NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 18393         0.041252        -0.094298        -3.377863         0.019235
# 18394        -0.048910        -0.166841        41.776313        -0.008832
# 18395        -0.032081        -0.462800         1.737939         0.004180
# 18396        -0.050211        -0.358012         0.896924         0.011856
# 18397        -0.026199        -0.207465         1.230123         0.020846
#
#        x5_pct_change_5  x6_pct_change_5  x7_pct_change_5  x8_pct_change_5  \
# ...

# %%
#feature_drift_percentage -PERIOD-2
# find the percentage change with the previous row
df23= df
df23=df23.pct_change(periods=2)
df23=df23.rename(columns=
               {'x1': 'x1_pct_change_2', 'x2': 'x2_pct_change_2','x3': 'x3_pct_change_2', 'x4': 'x4_pct_change_2', 'x5': 'x5_pct_change_2',
               'x6': 'x6_pct_change_2', 'x7': 'x7_pct_change_2','x8': 'x8_pct_change_2', 'x9': 'x9_pct_change_2', 'x10': 'x10_pct_change_2',
                'x11': 'x11_pct_change_2', 'x12': 'x12_pct_change_2','x13': 'x13_pct_change_2', 'x14': 'x14_pct_change_2', 'x15': 'x15_pct_change_2',
                'x16': 'x16_pct_change_2', 'x17': 'x17_pct_change_2','x18': 'x18_pct_change_2', 'x19': 'x19_pct_change_2', 'x20': 'x20_pct_change_2',
               'x21': 'x21_pct_change_2', 'x22': 'x22_pct_change_2','x23': 'x23_pct_change_2', 'x24': 'x24_pct_change_2', 'x25': 'x25_pct_change_2',
                'x26': 'x26_pct_change_2', 'x27': 'x27_pct_change_2','x28': 'x28_pct_change_2', 'x29': 'x29_pct_change_2',
                'x30': 'x30_pct_change_2', 'x31': 'x31_pct_change_2','x32': 'x32_pct_change_2', 'x33': 'x33_pct_change_2',
                'x34': 'x34_pct_change_2', 'x35': 'x35_pct_change_2','x36': 'x36_pct_change_2', 'x37': 'x37_pct_change_2',
                'x38': 'x38_pct_change_2', 'x39': 'x39_pct_change_2','x40': 'x40_pct_change_2', 'x41': 'x41_pct_change_2',
                'x42': 'x42_pct_change_2', 'x43': 'x43_pct_change_2','x44': 'x44_pct_change_2', 'x45': 'x45_pct_change_2',
                'x46': 'x46_pct_change_2', 'x47': 'x47_pct_change_2','x48': 'x48_pct_change_2', 'x49': 'x49_pct_change_2',
                'x50': 'x50_pct_change_2', 'x51': 'x51_pct_change_2','x52': 'x52_pct_change_2', 'x53': 'x53_pct_change_2',
                'x54': 'x54_pct_change_2', 'x55': 'x55_pct_change_2','x56': 'x56_pct_change_2', 'x57': 'x57_pct_change_2',
                'x58': 'x58_pct_change_2', 'x59': 'x59_pct_change_2','x60': 'x60_pct_change_2', 'x61': 'x61_pct_change_2'})
df23

# %%
#feature_drift_percentage -PERIOD-3
# find the percentage change with the previous row
df24= df
df24 = df24.drop(['time'], axis=1)
df24=df24.pct_change(periods=3)
df24=df24.rename(columns=
               {'x1': 'x1_pct_change_3', 'x2': 'x2_pct_change_3','x3': 'x3_pct_change_3', 'x4': 'x4_pct_change_3', 'x5': 'x5_pct_change_3',
               'x6': 'x6_pct_change_3', 'x7': 'x7_pct_change_3','x8': 'x8_pct_change_3', 'x9': 'x9_pct_change_3', 'x10': 'x10_pct_change_3',
                'x11': 'x11_pct_change_3', 'x12': 'x12_pct_change_3','x13': 'x13_pct_change_3', 'x14': 'x14_pct_change_3', 'x15': 'x15_pct_change_3',
                'x16': 'x16_pct_change_3', 'x17': 'x17_pct_change_3','x18': 'x18_pct_change_3', 'x19': 'x19_pct_change_3', 'x20': 'x20_pct_change_3',
               'x21': 'x21_pct_change_3', 'x22': 'x22_pct_change_3','x23': 'x23_pct_change_3', 'x24': 'x24_pct_change_3', 'x25': 'x25_pct_change_3',
                'x26': 'x26_pct_change_3', 'x27': 'x27_pct_change_3','x28': 'x28_pct_change_3', 'x29': 'x29_pct_change_3',
                'x30': 'x30_pct_change_3', 'x31': 'x31_pct_change_3','x32': 'x32_pct_change_3', 'x33': 'x33_pct_change_3',
                'x34': 'x34_pct_change_3', 'x35': 'x35_pct_change_3','x36': 'x36_pct_change_3', 'x37': 'x37_pct_change_3',
                'x38': 'x38_pct_change_3', 'x39': 'x39_pct_change_3','x40': 'x40_pct_change_3', 'x41': 'x41_pct_change_3',
                'x42': 'x42_pct_change_3', 'x43': 'x43_pct_change_3','x44': 'x44_pct_change_3', 'x45': 'x45_pct_change_3',
                'x46': 'x46_pct_change_3', 'x47': 'x47_pct_change_3','x48': 'x48_pct_change_3', 'x49': 'x49_pct_change_3',
                'x50': 'x50_pct_change_3', 'x51': 'x51_pct_change_3','x52': 'x52_pct_change_3', 'x53': 'x53_pct_change_3',
                'x54': 'x54_pct_change_3', 'x55': 'x55_pct_change_3','x56': 'x56_pct_change_3', 'x57': 'x57_pct_change_3',
                'x58': 'x58_pct_change_3', 'x59': 'x59_pct_change_3','x60': 'x60_pct_change_3', 'x61': 'x61_pct_change_3'})
df24
# Out:
#        x1_pct_change_3  x2_pct_change_3  x3_pct_change_3  x4_pct_change_3  \
# 0                  NaN              NaN              NaN              NaN
# 1                  NaN              NaN              NaN              NaN
# 2                  NaN              NaN              NaN              NaN
# 3            -0.199315         0.035353        -0.017614        -0.024902
# 4            -0.441734         0.045663         0.078338        -0.059352
# ...                ...              ...              ...              ...
# 18393         0.027518        -0.061440         2.325850         0.006584
# 18394        -0.025804        -0.030878         1.752434        -0.006269
# 18395        -0.042912        -0.387790         0.257397         0.010649
# 18396        -0.062225        -0.466725        -0.047150         0.002644
# 18397        -0.003563        -0.079572         0.056054         0.023350
#
#        x5_pct_change_3  x6_pct_change_3  x7_pct_change_3  x8_pct_change_3  \
# ...

# %%
#lag features

df1['lag_1'] = df1['x3'].shift(1)
df1['lag_2'] = df1['x3'].shift(2)
df1['lag_3'] = df1['x3'].shift(3)
df1['lag_4'] = df1['x3'].shift(4)
df1['lag_5'] = df1['x3'].shift(5)
df1['lag_6'] = df1['x3'].shift(6)
df1['lag_7'] = df1['x3'].shift(7)

df3 = df1[['time', 'lag_1', 'lag_2', 'lag_3', 'lag_4', 'lag_5', 'lag_6', 'lag_7', 'x3']]
df3.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [9], line 3
#       1 #lag features
# ----> 3 df1['lag_1'] = df1['x3'].shift(1)
#       4 df1['lag_2'] = df1['x3'].shift(2)
#       5 df1['lag_3'] = df1['x3'].shift(3)
#
# NameError: name 'df1' is not defined

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
plot_acf(df3['x3'], lags=700)
plot_pacf(df3['x3'], lags=700)
# Out:
# /Users/chathurangishyalika/opt/anaconda3/envs/tensorflow/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(df3['x3'], lags=10)
plot_pacf(df3['x3'], lags=10)

# %%
#The partial autocorrelation function shows a high correlation with the first lag and lesser correlation with 
#the second and third lag. The autocorrelation function shows a slow decay, which means that the future values have a 
#very high correlation with its past values.

#so, we can choose only lag 1 is significant here.

#https://statisticsbyjim.com/time-series/autocorrelation-partial-autocorrelation/

# %%
#lag features
df1=df
df1['lag_1_x1'] = df1['x1'].shift(1)
df1['lag_1_x2'] = df1['x2'].shift(1)
df1['lag_1_x3'] = df1['x3'].shift(1)
df1['lag_1_x4'] = df1['x4'].shift(1)
df1['lag_1_x5'] = df1['x5'].shift(1)
df1['lag_1_x6'] = df1['x6'].shift(1)
df1['lag_1_x7'] = df1['x7'].shift(1)
df1['lag_1_x8'] = df1['x8'].shift(1)
df1['lag_1_x9'] = df1['x9'].shift(1)
df1['lag_1_x10'] = df1['x10'].shift(1)
df1['lag_1_x11'] = df1['x11'].shift(1)
df1['lag_1_x12'] = df1['x12'].shift(1)
df1['lag_1_x13'] = df1['x13'].shift(1)
df1['lag_1_x14'] = df1['x14'].shift(1)
df1['lag_1_x15'] = df1['x15'].shift(1)
df1['lag_1_x16'] = df1['x16'].shift(1)
df1['lag_1_x17'] = df1['x17'].shift(1)
df1['lag_1_x18'] = df1['x18'].shift(1)
df1['lag_1_x19'] = df1['x19'].shift(1)
df1['lag_1_x20'] = df1['x20'].shift(1)
df1['lag_1_x21'] = df1['x21'].shift(1)
df1['lag_1_x22'] = df1['x22'].shift(1)
df1['lag_1_x23'] = df1['x23'].shift(1)
df1['lag_1_x24'] = df1['x24'].shift(1)
df1['lag_1_x25'] = df1['x25'].shift(1)
df1['lag_1_x26'] = df1['x26'].shift(1)
df1['lag_1_x27'] = df1['x27'].shift(1)
df1['lag_1_x28'] = df1['x28'].shift(1)
df1['lag_1_x29'] = df1['x29'].shift(1)
df1['lag_1_x30'] = df1['x30'].shift(1)
df1['lag_1_x31'] = df1['x31'].shift(1)
df1['lag_1_x32'] = df1['x32'].shift(1)
df1['lag_1_x33'] = df1['x33'].shift(1)
df1['lag_1_x34'] = df1['x34'].shift(1)
df1['lag_1_x35'] = df1['x35'].shift(1)
df1['lag_1_x36'] = df1['x36'].shift(1)
df1['lag_1_x37'] = df1['x37'].shift(1)
df1['lag_1_x38'] = df1['x38'].shift(1)
df1['lag_1_x39'] = df1['x39'].shift(1)
df1['lag_1_x40'] = df1['x40'].shift(1)
df1['lag_1_x41'] = df1['x41'].shift(1)
df1['lag_1_x42'] = df1['x42'].shift(1)
df1['lag_1_x43'] = df1['x43'].shift(1)
df1['lag_1_x44'] = df1['x44'].shift(1)
df1['lag_1_x45'] = df1['x45'].shift(1)
df1['lag_1_x46'] = df1['x46'].shift(1)
df1['lag_1_x47'] = df1['x47'].shift(1)
df1['lag_1_x48'] = df1['x48'].shift(1)
df1['lag_1_x49'] = df1['x49'].shift(1)
df1['lag_1_x50'] = df1['x50'].shift(1)
df1['lag_1_x51'] = df1['x51'].shift(1)
df1['lag_1_x52'] = df1['x52'].shift(1)
df1['lag_1_x53'] = df1['x53'].shift(1)
df1['lag_1_x54'] = df1['x54'].shift(1)
df1['lag_1_x55'] = df1['x55'].shift(1)
df1['lag_1_x56'] = df1['x56'].shift(1)
df1['lag_1_x57'] = df1['x57'].shift(1)
df1['lag_1_x58'] = df1['x58'].shift(1)
df1['lag_1_x59'] = df1['x59'].shift(1)
df1['lag_1_x60'] = df1['x60'].shift(1)
df1['lag_1_x61'] = df1['x61'].shift(1)


df3 = df1[['time', 'lag_1_x1', 'lag_1_x2', 'lag_1_x3', 'lag_1_x4', 'lag_1_x5',
          'lag_1_x6', 'lag_1_x7', 'lag_1_x8', 'lag_1_x9', 'lag_1_x10',
          'lag_1_x11', 'lag_1_x12', 'lag_1_x13', 'lag_1_x14', 'lag_1_x15',
          'lag_1_x16', 'lag_1_x17', 'lag_1_x18', 'lag_1_x19', 'lag_1_x20',
          'lag_1_x21', 'lag_1_x22', 'lag_1_x23', 'lag_1_x24', 'lag_1_x25',
          'lag_1_x26', 'lag_1_x27', 'lag_1_x28', 'lag_1_x29', 'lag_1_x30',
          'lag_1_x31', 'lag_1_x32', 'lag_1_x33', 'lag_1_x34', 'lag_1_x35',
          'lag_1_x36', 'lag_1_x37', 'lag_1_x38', 'lag_1_x39', 'lag_1_x40',
          'lag_1_x41', 'lag_1_x42', 'lag_1_x43', 'lag_1_x44', 'lag_1_x45',
          'lag_1_x46', 'lag_1_x47', 'lag_1_x48', 'lag_1_x49', 'lag_1_x50',
          'lag_1_x51', 'lag_1_x52', 'lag_1_x53', 'lag_1_x54', 'lag_1_x55',
          'lag_1_x56', 'lag_1_x57', 'lag_1_x58', 'lag_1_x59', 'lag_1_x60',
          'lag_1_x61']]
df3.head(10)
# Out:
#           time  lag_1_x1  lag_1_x2  lag_1_x3   lag_1_x4  lag_1_x5   lag_1_x6  \
# 0  5/1/99 0:00       NaN       NaN       NaN        NaN       NaN        NaN
# 1  5/1/99 0:02  0.376665 -4.596435 -4.095756  13.497687 -0.118830 -20.669883
# 2  5/1/99 0:04  0.475720 -4.542502 -4.018359  16.230659 -0.128733 -18.758079
# 3  5/1/99 0:06  0.363848 -4.681394 -4.353147  14.127997 -0.138636 -17.836632
# 4  5/1/99 0:08  0.301590 -4.758934 -4.023612  13.161566 -0.148142 -18.517601
# 5  5/1/99 0:10  0.265578 -4.749928 -4.333150  15.267340 -0.155314 -17.505913
# 6  5/1/99 0:12  0.381253 -4.611746 -4.085072  14.143195 -0.162501 -16.494255
# 7  5/1/99 0:14  0.313325 -4.530210 -4.120931  18.681465 -0.169672 -15.329521
# 8  5/1/99 0:16  0.396401 -4.699047 -4.074193  21.307655 -0.176859 -13.937523
# 9  5/1/99 0:18  0.342688 -4.553506 -4.188885  22.892035 -0.184046 -13.630058
#
#    lag_1_x7  lag_1_x8  lag_1_x9  ...  lag_1_x52  lag_1_x53  lag_1_x54  \
# ...

# %%
#Rolling window

df1=df
df1['rolling_mean_x1'] = df1['x1'].rolling(window=7).mean()
df1['rolling_mean_x2'] = df1['x2'].rolling(window=7).mean()
df1['rolling_mean_x3'] = df1['x3'].rolling(window=7).mean()
df1['rolling_mean_x4'] = df1['x4'].rolling(window=7).mean()
df1['rolling_mean_x5'] = df1['x5'].rolling(window=7).mean()
df1['rolling_mean_x6'] = df1['x6'].rolling(window=7).mean()
df1['rolling_mean_x7'] = df1['x7'].rolling(window=7).mean()
df1['rolling_mean_x8'] = df1['x8'].rolling(window=7).mean()
df1['rolling_mean_x9'] = df1['x9'].rolling(window=7).mean()
df1['rolling_mean_x10'] = df1['x10'].rolling(window=7).mean()
df1['rolling_mean_x11'] = df1['x11'].rolling(window=7).mean()
df1['rolling_mean_x12'] = df1['x12'].rolling(window=7).mean()
df1['rolling_mean_x13'] = df1['x13'].rolling(window=7).mean()
df1['rolling_mean_x14'] = df1['x14'].rolling(window=7).mean()
df1['rolling_mean_x15'] = df1['x15'].rolling(window=7).mean()
df1['rolling_mean_x16'] = df1['x16'].rolling(window=7).mean()
df1['rolling_mean_x17'] = df1['x17'].rolling(window=7).mean()
df1['rolling_mean_x18'] = df1['x18'].rolling(window=7).mean()
df1['rolling_mean_x19'] = df1['x19'].rolling(window=7).mean()
df1['rolling_mean_x20'] = df1['x20'].rolling(window=7).mean()
df1['rolling_mean_x21'] = df1['x21'].rolling(window=7).mean()
df1['rolling_mean_x22'] = df1['x22'].rolling(window=7).mean()
df1['rolling_mean_x23'] = df1['x23'].rolling(window=7).mean()
df1['rolling_mean_x24'] = df1['x24'].rolling(window=7).mean()
df1['rolling_mean_x25'] = df1['x25'].rolling(window=7).mean()
df1['rolling_mean_x26'] = df1['x26'].rolling(window=7).mean()
df1['rolling_mean_x27'] = df1['x27'].rolling(window=7).mean()
df1['rolling_mean_x28'] = df1['x28'].rolling(window=7).mean()
df1['rolling_mean_x29'] = df1['x29'].rolling(window=7).mean()
df1['rolling_mean_x30'] = df1['x30'].rolling(window=7).mean()
df1['rolling_mean_x31'] = df1['x31'].rolling(window=7).mean()
df1['rolling_mean_x32'] = df1['x32'].rolling(window=7).mean()
df1['rolling_mean_x33'] = df1['x33'].rolling(window=7).mean()
df1['rolling_mean_x34'] = df1['x34'].rolling(window=7).mean()
df1['rolling_mean_x35'] = df1['x35'].rolling(window=7).mean()
df1['rolling_mean_x36'] = df1['x36'].rolling(window=7).mean()
df1['rolling_mean_x37'] = df1['x37'].rolling(window=7).mean()
df1['rolling_mean_x38'] = df1['x38'].rolling(window=7).mean()
df1['rolling_mean_x39'] = df1['x39'].rolling(window=7).mean()
df1['rolling_mean_x40'] = df1['x40'].rolling(window=7).mean()
df1['rolling_mean_x41'] = df1['x41'].rolling(window=7).mean()
df1['rolling_mean_x42'] = df1['x42'].rolling(window=7).mean()
df1['rolling_mean_x43'] = df1['x43'].rolling(window=7).mean()
df1['rolling_mean_x44'] = df1['x44'].rolling(window=7).mean()
df1['rolling_mean_x45'] = df1['x45'].rolling(window=7).mean()
df1['rolling_mean_x46'] = df1['x46'].rolling(window=7).mean()
df1['rolling_mean_x47'] = df1['x47'].rolling(window=7).mean()
df1['rolling_mean_x48'] = df1['x48'].rolling(window=7).mean()
df1['rolling_mean_x49'] = df1['x49'].rolling(window=7).mean()
df1['rolling_mean_x50'] = df1['x50'].rolling(window=7).mean()
df1['rolling_mean_x51'] = df1['x51'].rolling(window=7).mean()
df1['rolling_mean_x52'] = df1['x52'].rolling(window=7).mean()
df1['rolling_mean_x53'] = df1['x53'].rolling(window=7).mean()
df1['rolling_mean_x54'] = df1['x54'].rolling(window=7).mean()
df1['rolling_mean_x55'] = df1['x55'].rolling(window=7).mean()
df1['rolling_mean_x56'] = df1['x56'].rolling(window=7).mean()
df1['rolling_mean_x57'] = df1['x57'].rolling(window=7).mean()
df1['rolling_mean_x58'] = df1['x58'].rolling(window=7).mean()
df1['rolling_mean_x59'] = df1['x59'].rolling(window=7).mean()
df1['rolling_mean_x60'] = df1['x60'].rolling(window=7).mean()
df1['rolling_mean_x61'] = df1['x61'].rolling(window=7).mean()


df4 = df1[['time', 'rolling_mean_x1', 'rolling_mean_x2', 'rolling_mean_x3', 'rolling_mean_x4', 'rolling_mean_x5',
          'rolling_mean_x6', 'rolling_mean_x7', 'rolling_mean_x8', 'rolling_mean_x9', 'rolling_mean_x10',
          'rolling_mean_x11', 'rolling_mean_x12', 'rolling_mean_x13', 'rolling_mean_x14', 'rolling_mean_x15',
          'rolling_mean_x16', 'rolling_mean_x17', 'rolling_mean_x18', 'rolling_mean_x19', 'rolling_mean_x20',
          'rolling_mean_x21', 'rolling_mean_x22', 'rolling_mean_x23', 'rolling_mean_x24', 'rolling_mean_x25',
          'rolling_mean_x26', 'rolling_mean_x27', 'rolling_mean_x28', 'rolling_mean_x29', 'rolling_mean_x30',
          'rolling_mean_x31', 'rolling_mean_x32', 'rolling_mean_x33', 'rolling_mean_x34', 'rolling_mean_x35',
          'rolling_mean_x36', 'rolling_mean_x37', 'rolling_mean_x38', 'rolling_mean_x39', 'rolling_mean_x40',
          'rolling_mean_x41', 'rolling_mean_x42', 'rolling_mean_x43', 'rolling_mean_x44', 'rolling_mean_x45',
          'rolling_mean_x46', 'rolling_mean_x47', 'rolling_mean_x48', 'rolling_mean_x49', 'rolling_mean_x50',
          'rolling_mean_x51', 'rolling_mean_x52', 'rolling_mean_x53', 'rolling_mean_x54', 'rolling_mean_x55',
          'rolling_mean_x56', 'rolling_mean_x57', 'rolling_mean_x58', 'rolling_mean_x59', 'rolling_mean_x60',
          'rolling_mean_x61']]
df4.head(10)
# Out:
#           time  rolling_mean_x1  rolling_mean_x2  rolling_mean_x3  \
# 0  5/1/99 0:00              NaN              NaN              NaN
# 1  5/1/99 0:02              NaN              NaN              NaN
# 2  5/1/99 0:04              NaN              NaN              NaN
# 3  5/1/99 0:06              NaN              NaN              NaN
# 4  5/1/99 0:08              NaN              NaN              NaN
# 5  5/1/99 0:10              NaN              NaN              NaN
# 6  5/1/99 0:12         0.353997        -4.638735        -4.147147
# 7  5/1/99 0:14         0.356817        -4.653394        -4.144066
# 8  5/1/99 0:16         0.337812        -4.654966        -4.168427
# 9  5/1/99 0:18         0.351299        -4.648990        -4.153198
#
#    rolling_mean_x4  rolling_mean_x5  rolling_mean_x6  rolling_mean_x7  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# ...

# %%
df1
# Out:
#                 time        x1        x2        x3          x4        x5  \
# 0        5/1/99 0:00  0.376665 -4.596435 -4.095756   13.497687 -0.118830
# 1        5/1/99 0:02  0.475720 -4.542502 -4.018359   16.230659 -0.128733
# 2        5/1/99 0:04  0.363848 -4.681394 -4.353147   14.127997 -0.138636
# 3        5/1/99 0:06  0.301590 -4.758934 -4.023612   13.161566 -0.148142
# 4        5/1/99 0:08  0.265578 -4.749928 -4.333150   15.267340 -0.155314
# ...              ...       ...       ...       ...         ...       ...
# 18393  5/28/99 23:58 -0.877441  0.786430  0.406426  135.301215  0.112295
# 18394   5/29/99 0:00 -0.843988  0.633086  0.561918  133.228949  0.141332
# 18395   5/29/99 0:02 -0.826547  0.450126  0.334582  134.977973  0.170370
# 18396   5/29/99 0:04 -0.822843  0.419383  0.387263  135.658942  0.199422
# 18397   5/29/99 0:06 -0.840981  0.582710  0.593416  136.339880  0.228460
#
#               x6        x7        x8        x9  ...  rolling_mean_x52  \
# ...

# %%
#Expanding Window

#df1=df
df1['expanding_mean_x1'] = df1['x1'].expanding(2).mean()
df1['expanding_mean_x2'] = df1['x2'].expanding(2).mean()
df1['expanding_mean_x3'] = df1['x3'].expanding(2).mean()
df1['expanding_mean_x4'] = df1['x4'].expanding(2).mean()
df1['expanding_mean_x5'] = df1['x5'].expanding(2).mean()
df1['expanding_mean_x6'] = df1['x6'].expanding(2).mean()
df1['expanding_mean_x7'] = df1['x7'].expanding(2).mean()
df1['expanding_mean_x8'] = df1['x8'].expanding(2).mean()
df1['expanding_mean_x9'] = df1['x9'].expanding(2).mean()
df1['expanding_mean_x10'] = df1['x10'].expanding(2).mean()
df1['expanding_mean_x11'] = df1['x11'].expanding(2).mean()
df1['expanding_mean_x12'] = df1['x12'].expanding(2).mean()
df1['expanding_mean_x13'] = df1['x13'].expanding(2).mean()
df1['expanding_mean_x14'] = df1['x14'].expanding(2).mean()
df1['expanding_mean_x15'] = df1['x15'].expanding(2).mean()
df1['expanding_mean_x16'] = df1['x16'].expanding(2).mean()
df1['expanding_mean_x17'] = df1['x17'].expanding(2).mean()
df1['expanding_mean_x18'] = df1['x18'].expanding(2).mean()
df1['expanding_mean_x19'] = df1['x19'].expanding(2).mean()
df1['expanding_mean_x20'] = df1['x20'].expanding(2).mean()
df1['expanding_mean_x21'] = df1['x21'].expanding(2).mean()
df1['expanding_mean_x22'] = df1['x22'].expanding(2).mean()
df1['expanding_mean_x23'] = df1['x23'].expanding(2).mean()
df1['expanding_mean_x24'] = df1['x24'].expanding(2).mean()
df1['expanding_mean_x25'] = df1['x25'].expanding(2).mean()
df1['expanding_mean_x26'] = df1['x26'].expanding(2).mean()
df1['expanding_mean_x27'] = df1['x27'].expanding(2).mean()
df1['expanding_mean_x28'] = df1['x28'].expanding(2).mean()
df1['expanding_mean_x29'] = df1['x29'].expanding(2).mean()
df1['expanding_mean_x30'] = df1['x30'].expanding(2).mean()
df1['expanding_mean_x31'] = df1['x31'].expanding(2).mean()
df1['expanding_mean_x32'] = df1['x32'].expanding(2).mean()
df1['expanding_mean_x33'] = df1['x33'].expanding(2).mean()
df1['expanding_mean_x34'] = df1['x34'].expanding(2).mean()
df1['expanding_mean_x35'] = df1['x35'].expanding(2).mean()
df1['expanding_mean_x36'] = df1['x36'].expanding(2).mean()
df1['expanding_mean_x37'] = df1['x37'].expanding(2).mean()
df1['expanding_mean_x38'] = df1['x38'].expanding(2).mean()
df1['expanding_mean_x39'] = df1['x39'].expanding(2).mean()
df1['expanding_mean_x40'] = df1['x40'].expanding(2).mean()
df1['expanding_mean_x41'] = df1['x41'].expanding(2).mean()
df1['expanding_mean_x42'] = df1['x42'].expanding(2).mean()
df1['expanding_mean_x43'] = df1['x43'].expanding(2).mean()
df1['expanding_mean_x44'] = df1['x44'].expanding(2).mean()
df1['expanding_mean_x45'] = df1['x45'].expanding(2).mean()
df1['expanding_mean_x46'] = df1['x46'].expanding(2).mean()
df1['expanding_mean_x47'] = df1['x47'].expanding(2).mean()
df1['expanding_mean_x48'] = df1['x48'].expanding(2).mean()
df1['expanding_mean_x49'] = df1['x49'].expanding(2).mean()
df1['expanding_mean_x50'] = df1['x50'].expanding(2).mean()
df1['expanding_mean_x51'] = df1['x51'].expanding(2).mean()
df1['expanding_mean_x52'] = df1['x52'].expanding(2).mean()
df1['expanding_mean_x53'] = df1['x53'].expanding(2).mean()
df1['expanding_mean_x54'] = df1['x54'].expanding(2).mean()
df1['expanding_mean_x55'] = df1['x55'].expanding(2).mean()
df1['expanding_mean_x56'] = df1['x56'].expanding(2).mean()
df1['expanding_mean_x57'] = df1['x57'].expanding(2).mean()
df1['expanding_mean_x58'] = df1['x58'].expanding(2).mean()
df1['expanding_mean_x59'] = df1['x59'].expanding(2).mean()
df1['expanding_mean_x60'] = df1['x60'].expanding(2).mean()
df1['expanding_mean_x61'] = df1['x61'].expanding(2).mean()


df5 = df1[['time', 'expanding_mean_x1', 'expanding_mean_x2', 'expanding_mean_x3', 'expanding_mean_x4', 'expanding_mean_x5',
          'expanding_mean_x6', 'expanding_mean_x7', 'expanding_mean_x8', 'expanding_mean_x9', 'expanding_mean_x10',
          'expanding_mean_x11', 'expanding_mean_x12', 'expanding_mean_x13', 'expanding_mean_x14', 'expanding_mean_x15',
          'expanding_mean_x16', 'expanding_mean_x17', 'expanding_mean_x18', 'expanding_mean_x19', 'expanding_mean_x20',
          'expanding_mean_x21', 'expanding_mean_x22', 'expanding_mean_x23', 'expanding_mean_x24', 'expanding_mean_x25',
          'expanding_mean_x26', 'expanding_mean_x27', 'expanding_mean_x28', 'expanding_mean_x29', 'expanding_mean_x30',
          'expanding_mean_x31', 'expanding_mean_x32', 'expanding_mean_x33', 'expanding_mean_x34', 'expanding_mean_x35',
          'expanding_mean_x36', 'expanding_mean_x37', 'expanding_mean_x38', 'expanding_mean_x39', 'expanding_mean_x40',
          'expanding_mean_x41', 'expanding_mean_x42', 'expanding_mean_x43', 'expanding_mean_x44', 'expanding_mean_x45',
          'expanding_mean_x46', 'expanding_mean_x47', 'expanding_mean_x48', 'expanding_mean_x49', 'expanding_mean_x50',
          'expanding_mean_x51', 'expanding_mean_x52', 'expanding_mean_x53', 'expanding_mean_x54', 'expanding_mean_x55',
          'expanding_mean_x56', 'expanding_mean_x57', 'expanding_mean_x58', 'expanding_mean_x59', 'expanding_mean_x60',
          'expanding_mean_x61']]


df5.head(10)
# Out:
#           time  expanding_mean_x1  expanding_mean_x2  expanding_mean_x3  \
# 0  5/1/99 0:00                NaN                NaN                NaN
# 1  5/1/99 0:02           0.426193          -4.569468          -4.057057
# 2  5/1/99 0:04           0.405411          -4.606777          -4.155754
# 3  5/1/99 0:06           0.379456          -4.644816          -4.122718
# 4  5/1/99 0:08           0.356681          -4.665838          -4.164805
# 5  5/1/99 0:10           0.360776          -4.656823          -4.151516
# 6  5/1/99 0:12           0.353997          -4.638735          -4.147147
# 7  5/1/99 0:14           0.359298          -4.646274          -4.138027
# 8  5/1/99 0:16           0.357452          -4.635967          -4.143678
# 9  5/1/99 0:18           0.367532          -4.636326          -4.153965
#
#    expanding_mean_x4  expanding_mean_x5  expanding_mean_x6  expanding_mean_x7  \
# 0                NaN                NaN                NaN                NaN
# ...

# %%
df1
# Out:
#                 time        x1        x2        x3          x4        x5  \
# 0        5/1/99 0:00  0.376665 -4.596435 -4.095756   13.497687 -0.118830
# 1        5/1/99 0:02  0.475720 -4.542502 -4.018359   16.230659 -0.128733
# 2        5/1/99 0:04  0.363848 -4.681394 -4.353147   14.127997 -0.138636
# 3        5/1/99 0:06  0.301590 -4.758934 -4.023612   13.161566 -0.148142
# 4        5/1/99 0:08  0.265578 -4.749928 -4.333150   15.267340 -0.155314
# ...              ...       ...       ...       ...         ...       ...
# 18393  5/28/99 23:58 -0.877441  0.786430  0.406426  135.301215  0.112295
# 18394   5/29/99 0:00 -0.843988  0.633086  0.561918  133.228949  0.141332
# 18395   5/29/99 0:02 -0.826547  0.450126  0.334582  134.977973  0.170370
# 18396   5/29/99 0:04 -0.822843  0.419383  0.387263  135.658942  0.199422
# 18397   5/29/99 0:06 -0.840981  0.582710  0.593416  136.339880  0.228460
#
#               x6        x7        x8        x9  ...  expanding_mean_x52  \
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18398 entries, 0 to 18397
# Data columns (total 62 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   time                18398 non-null  object
#  1   expanding_mean_x1   18397 non-null  float64
#  2   expanding_mean_x2   18397 non-null  float64
#  3   expanding_mean_x3   18397 non-null  float64
#  4   expanding_mean_x4   18397 non-null  float64
#  5   expanding_mean_x5   18397 non-null  float64
#  6   expanding_mean_x6   18397 non-null  float64
#  7   expanding_mean_x7   18397 non-null  float64
#  8   expanding_mean_x8   18397 non-null  float64
#  9   expanding_mean_x9   18397 non-null  float64
#  10  expanding_mean_x10  18397 non-null  float64
#  11  expanding_mean_x11  18397 non-null  float64
#  12  expanding_mean_x12  18397 non-null  float64
#  13  expanding_mean_x13  18397 non-null  float64
#  14  expanding_mean_x14  18397 non-null  float64
# ...

# %%
df2
# Out:
#                 time        x1        x2        x3          x4        x5  \
# 0        5/1/99 0:00  0.376665 -4.596435 -4.095756   13.497687 -0.118830
# 1        5/1/99 0:02  0.475720 -4.542502 -4.018359   16.230659 -0.128733
# 2        5/1/99 0:04  0.363848 -4.681394 -4.353147   14.127997 -0.138636
# 3        5/1/99 0:06  0.301590 -4.758934 -4.023612   13.161566 -0.148142
# 4        5/1/99 0:08  0.265578 -4.749928 -4.333150   15.267340 -0.155314
# ...              ...       ...       ...       ...         ...       ...
# 18393  5/28/99 23:58 -0.877441  0.786430  0.406426  135.301215  0.112295
# 18394   5/29/99 0:00 -0.843988  0.633086  0.561918  133.228949  0.141332
# 18395   5/29/99 0:02 -0.826547  0.450126  0.334582  134.977973  0.170370
# 18396   5/29/99 0:04 -0.822843  0.419383  0.387263  135.658942  0.199422
# 18397   5/29/99 0:06 -0.840981  0.582710  0.593416  136.339880  0.228460
#
#               x6        x7        x8        x9  ...  expanding_mean_x52  \
# ...

# %%
df3
# Out:
#                 time  lag_1_x1  lag_1_x2  lag_1_x3    lag_1_x4  lag_1_x5  \
# 0        5/1/99 0:00       NaN       NaN       NaN         NaN       NaN
# 1        5/1/99 0:02  0.376665 -4.596435 -4.095756   13.497687 -0.118830
# 2        5/1/99 0:04  0.475720 -4.542502 -4.018359   16.230659 -0.128733
# 3        5/1/99 0:06  0.363848 -4.681394 -4.353147   14.127997 -0.138636
# 4        5/1/99 0:08  0.301590 -4.758934 -4.023612   13.161566 -0.148142
# ...              ...       ...       ...       ...         ...       ...
# 18393  5/28/99 23:58 -0.863607  0.735248  0.266091  133.555731  0.083242
# 18394   5/29/99 0:00 -0.877441  0.786430  0.406426  135.301215  0.112295
# 18395   5/29/99 0:02 -0.843988  0.633086  0.561918  133.228949  0.141332
# 18396   5/29/99 0:04 -0.826547  0.450126  0.334582  134.977973  0.170370
# 18397   5/29/99 0:06 -0.822843  0.419383  0.387263  135.658942  0.199422
#
#         lag_1_x6  lag_1_x7  lag_1_x8  lag_1_x9  ...  lag_1_x52  lag_1_x53  \
# ...

# %%
df4
# Out:
#                 time  rolling_mean_x1  rolling_mean_x2  rolling_mean_x3  \
# 0        5/1/99 0:00              NaN              NaN              NaN
# 1        5/1/99 0:02              NaN              NaN              NaN
# 2        5/1/99 0:04              NaN              NaN              NaN
# 3        5/1/99 0:06              NaN              NaN              NaN
# 4        5/1/99 0:08              NaN              NaN              NaN
# ...              ...              ...              ...              ...
# 18393  5/28/99 23:58        -0.854131         0.782411         0.081743
# 18394   5/29/99 0:00        -0.862199         0.753444         0.200429
# 18395   5/29/99 0:02        -0.859894         0.693703         0.272644
# 18396   5/29/99 0:04        -0.850673         0.645063         0.326091
# 18397   5/29/99 0:06        -0.848821         0.608606         0.393407
#
#        rolling_mean_x4  rolling_mean_x5  rolling_mean_x6  rolling_mean_x7  \
# ...

# %%
df5
# Out:
#                 time  expanding_mean_x1  expanding_mean_x2  expanding_mean_x3  \
# 0        5/1/99 0:00                NaN                NaN                NaN
# 1        5/1/99 0:02           0.426193          -4.569468          -4.057057
# 2        5/1/99 0:04           0.405411          -4.606777          -4.155754
# 3        5/1/99 0:06           0.379456          -4.644816          -4.122718
# 4        5/1/99 0:08           0.356681          -4.665838          -4.164805
# ...              ...                ...                ...                ...
# 18393  5/28/99 23:58           0.012007           0.157907           0.569321
# 18394   5/29/99 0:00           0.011961           0.157933           0.569321
# 18395   5/29/99 0:02           0.011915           0.157949           0.569308
# 18396   5/29/99 0:04           0.011870           0.157963           0.569298
# 18397   5/29/99 0:06           0.011824           0.157986           0.569300
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18398 entries, 0 to 18397
# Columns: 245 entries, time to expanding_mean_x61
# dtypes: float64(242), int64(2), object(1)
# memory usage: 34.4+ MB

# %%
df4
# Out:
#                 time  rolling_mean_x1  rolling_mean_x2  rolling_mean_x3  \
# 0        5/1/99 0:00              NaN              NaN              NaN
# 1        5/1/99 0:02              NaN              NaN              NaN
# 2        5/1/99 0:04              NaN              NaN              NaN
# 3        5/1/99 0:06              NaN              NaN              NaN
# 4        5/1/99 0:08              NaN              NaN              NaN
# ...              ...              ...              ...              ...
# 18393  5/28/99 23:58        -0.854131         0.782411         0.081743
# 18394   5/29/99 0:00        -0.862199         0.753444         0.200429
# 18395   5/29/99 0:02        -0.859894         0.693703         0.272644
# 18396   5/29/99 0:04        -0.850673         0.645063         0.326091
# 18397   5/29/99 0:06        -0.848821         0.608606         0.393407
#
#        rolling_mean_x4  rolling_mean_x5  rolling_mean_x6  rolling_mean_x7  \
# ...

# %%
df23
# Out:
#                 time        x1        x2        x3          x4        x5  \
# 0        5/1/99 0:00  0.376665 -4.596435 -4.095756   13.497687 -0.118830
# 1        5/1/99 0:02  0.475720 -4.542502 -4.018359   16.230659 -0.128733
# 2        5/1/99 0:04  0.363848 -4.681394 -4.353147   14.127997 -0.138636
# 3        5/1/99 0:06  0.301590 -4.758934 -4.023612   13.161566 -0.148142
# 4        5/1/99 0:08  0.265578 -4.749928 -4.333150   15.267340 -0.155314
# ...              ...       ...       ...       ...         ...       ...
# 18393  5/28/99 23:58 -0.877441  0.786430  0.406426  135.301215  0.112295
# 18394   5/29/99 0:00 -0.843988  0.633086  0.561918  133.228949  0.141332
# 18395   5/29/99 0:02 -0.826547  0.450126  0.334582  134.977973  0.170370
# 18396   5/29/99 0:04 -0.822843  0.419383  0.387263  135.658942  0.199422
# 18397   5/29/99 0:06 -0.840981  0.582710  0.593416  136.339880  0.228460
#
#               x6        x7        x8        x9  ...  expanding_mean_x52  \
# ...

# %%
df2_nnn=pd.concat([df1, df23], axis=1)
df2_nnn
# Out:
#                 time  y        x1        x2        x3          x4        x5  \
# 0        5/1/99 0:00  0  0.376665 -4.596435 -4.095756   13.497687 -0.118830
# 1        5/1/99 0:02  0  0.475720 -4.542502 -4.018359   16.230659 -0.128733
# 2        5/1/99 0:04  0  0.363848 -4.681394 -4.353147   14.127997 -0.138636
# 3        5/1/99 0:06  0  0.301590 -4.758934 -4.023612   13.161566 -0.148142
# 4        5/1/99 0:08  0  0.265578 -4.749928 -4.333150   15.267340 -0.155314
# ...              ... ..       ...       ...       ...         ...       ...
# 18393  5/28/99 23:58  0 -0.877441  0.786430  0.406426  135.301215  0.112295
# 18394   5/29/99 0:00  0 -0.843988  0.633086  0.561918  133.228949  0.141332
# 18395   5/29/99 0:02  0 -0.826547  0.450126  0.334582  134.977973  0.170370
# 18396   5/29/99 0:04  0 -0.822843  0.419383  0.387263  135.658942  0.199422
# 18397   5/29/99 0:06  0 -0.840981  0.582710  0.593416  136.339880  0.228460
#
# ...

# %%
df2_nnn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18398 entries, 0 to 18397
# Columns: 307 entries, time to x61_pct_change_2
# dtypes: float64(303), int64(3), object(1)
# memory usage: 43.1+ MB

# %%
df22
# Out:
#        x1_pct_change_5  x2_pct_change_5  x3_pct_change_5  x4_pct_change_5  \
# 0                  NaN              NaN              NaN              NaN
# 1                  NaN              NaN              NaN              NaN
# 2                  NaN              NaN              NaN              NaN
# 3                  NaN              NaN              NaN              NaN
# 4                  NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 18393         0.041252        -0.094298        -3.377863         0.019235
# 18394        -0.048910        -0.166841        41.776313        -0.008832
# 18395        -0.032081        -0.462800         1.737939         0.004180
# 18396        -0.050211        -0.358012         0.896924         0.011856
# 18397        -0.026199        -0.207465         1.230123         0.020846
#
#        x5_pct_change_5  x6_pct_change_5  x7_pct_change_5  x8_pct_change_5  \
# ...

# %%
df2_n=pd.concat([df2, df22], axis=1)
df2_n
# Out:
#        x1_pct_change  x2_pct_change  x3_pct_change  x4_pct_change  \
# 0                NaN            NaN            NaN            NaN
# 1           0.262979      -0.011734      -0.018897       0.202477
# 2          -0.235163       0.030576       0.083315      -0.129549
# 3          -0.171110       0.016563      -0.075700      -0.068405
# 4          -0.119407      -0.001892       0.076930       0.159994
# ...              ...            ...            ...            ...
# 18393       0.016020       0.069612       0.527394       0.013069
# 18394      -0.038127      -0.194987       0.382584      -0.015316
# 18395      -0.020664      -0.288997      -0.404571       0.013128
# 18396      -0.004483      -0.068299       0.157453       0.005045
# 18397       0.022043       0.389446       0.532333       0.005019
#
#        x5_pct_change  x6_pct_change  x7_pct_change  x8_pct_change  \
# 0                NaN            NaN            NaN            NaN
# ...

# %%
df2_nn=pd.concat([df2_n, df23], axis=1)
df2_nn
# Out:
#        x1_pct_change  x2_pct_change  x3_pct_change  x4_pct_change  \
# 0                NaN            NaN            NaN            NaN
# 1           0.262979      -0.011734      -0.018897       0.202477
# 2          -0.235163       0.030576       0.083315      -0.129549
# 3          -0.171110       0.016563      -0.075700      -0.068405
# 4          -0.119407      -0.001892       0.076930       0.159994
# ...              ...            ...            ...            ...
# 18393       0.016020       0.069612       0.527394       0.013069
# 18394      -0.038127      -0.194987       0.382584      -0.015316
# 18395      -0.020664      -0.288997      -0.404571       0.013128
# 18396      -0.004483      -0.068299       0.157453       0.005045
# 18397       0.022043       0.389446       0.532333       0.005019
#
#        x5_pct_change  x6_pct_change  x7_pct_change  x8_pct_change  \
# 0                NaN            NaN            NaN            NaN
# ...

# %%
df24
# Out:
#        x1_pct_change_3  x2_pct_change_3  x3_pct_change_3  x4_pct_change_3  \
# 0                  NaN              NaN              NaN              NaN
# 1                  NaN              NaN              NaN              NaN
# 2                  NaN              NaN              NaN              NaN
# 3            -0.199315         0.035353        -0.017614        -0.024902
# 4            -0.441734         0.045663         0.078338        -0.059352
# ...                ...              ...              ...              ...
# 18393         0.027518        -0.061440         2.325850         0.006584
# 18394        -0.025804        -0.030878         1.752434        -0.006269
# 18395        -0.042912        -0.387790         0.257397         0.010649
# 18396        -0.062225        -0.466725        -0.047150         0.002644
# 18397        -0.003563        -0.079572         0.056054         0.023350
#
#        x5_pct_change_3  x6_pct_change_3  x7_pct_change_3  x8_pct_change_3  \
# ...

# %%
df2_nnn=pd.concat([df2_nn, df24], axis=1)
df2_nnn
# Out:
#        x1_pct_change  x2_pct_change  x3_pct_change  x4_pct_change  \
# 0                NaN            NaN            NaN            NaN
# 1           0.262979      -0.011734      -0.018897       0.202477
# 2          -0.235163       0.030576       0.083315      -0.129549
# 3          -0.171110       0.016563      -0.075700      -0.068405
# 4          -0.119407      -0.001892       0.076930       0.159994
# ...              ...            ...            ...            ...
# 18393       0.016020       0.069612       0.527394       0.013069
# 18394      -0.038127      -0.194987       0.382584      -0.015316
# 18395      -0.020664      -0.288997      -0.404571       0.013128
# 18396      -0.004483      -0.068299       0.157453       0.005045
# 18397       0.022043       0.389446       0.532333       0.005019
#
#        x5_pct_change  x6_pct_change  x7_pct_change  x8_pct_change  \
# 0                NaN            NaN            NaN            NaN
# ...

# %%
df1_n=pd.concat([df1, df2_nnn], axis=1)
df1_n
# Out:
#                 time  y        x1        x2        x3          x4        x5  \
# 0        5/1/99 0:00  0  0.376665 -4.596435 -4.095756   13.497687 -0.118830
# 1        5/1/99 0:02  0  0.475720 -4.542502 -4.018359   16.230659 -0.128733
# 2        5/1/99 0:04  0  0.363848 -4.681394 -4.353147   14.127997 -0.138636
# 3        5/1/99 0:06  0  0.301590 -4.758934 -4.023612   13.161566 -0.148142
# 4        5/1/99 0:08  0  0.265578 -4.749928 -4.333150   15.267340 -0.155314
# ...              ... ..       ...       ...       ...         ...       ...
# 18393  5/28/99 23:58  0 -0.877441  0.786430  0.406426  135.301215  0.112295
# 18394   5/29/99 0:00  0 -0.843988  0.633086  0.561918  133.228949  0.141332
# 18395   5/29/99 0:02  0 -0.826547  0.450126  0.334582  134.977973  0.170370
# 18396   5/29/99 0:04  0 -0.822843  0.419383  0.387263  135.658942  0.199422
# 18397   5/29/99 0:06  0 -0.840981  0.582710  0.593416  136.339880  0.228460
#
# ...

# %%
df1_nnn=pd.concat([df1, df22], axis=1)
df1_nnn
# Out:
#                 time        x1        x2        x3          x4        x5  \
# 0        5/1/99 0:00  0.376665 -4.596435 -4.095756   13.497687 -0.118830
# 1        5/1/99 0:02  0.475720 -4.542502 -4.018359   16.230659 -0.128733
# 2        5/1/99 0:04  0.363848 -4.681394 -4.353147   14.127997 -0.138636
# 3        5/1/99 0:06  0.301590 -4.758934 -4.023612   13.161566 -0.148142
# 4        5/1/99 0:08  0.265578 -4.749928 -4.333150   15.267340 -0.155314
# ...              ...       ...       ...       ...         ...       ...
# 18393  5/28/99 23:58 -0.877441  0.786430  0.406426  135.301215  0.112295
# 18394   5/29/99 0:00 -0.843988  0.633086  0.561918  133.228949  0.141332
# 18395   5/29/99 0:02 -0.826547  0.450126  0.334582  134.977973  0.170370
# 18396   5/29/99 0:04 -0.822843  0.419383  0.387263  135.658942  0.199422
# 18397   5/29/99 0:06 -0.840981  0.582710  0.593416  136.339880  0.228460
#
#               x6        x7        x8        x9  ...  x52_pct_change_5  \
# ...

# %%
df1_nnn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18398 entries, 0 to 18397
# Columns: 306 entries, time to x61_pct_change_5
# dtypes: float64(303), int64(2), object(1)
# memory usage: 43.0+ MB

# %%
from tsaug import TimeWarp, Crop, Quantize, Drift, Reverse

my_augmenter = (
Reverse() @ 0.5  # with 50% probability, reverse the sequence
)

#rev series
df1=df
df1['rev_x1'] = my_augmenter.augment(df1.x1.to_numpy())
df1['rev_x2'] = my_augmenter.augment(df1.x2.to_numpy())
df1['rev_x3'] = my_augmenter.augment(df1.x3.to_numpy())
df1['rev_x4'] = my_augmenter.augment(df1.x4.to_numpy())
df1['rev_x5'] = my_augmenter.augment(df1.x5.to_numpy())
df1['rev_x6'] = my_augmenter.augment(df1.x6.to_numpy())
df1['rev_x7'] = my_augmenter.augment(df1.x7.to_numpy())
df1['rev_x8'] = my_augmenter.augment(df1.x8.to_numpy())
df1['rev_x9'] = my_augmenter.augment(df1.x9.to_numpy())
df1['rev_x10'] = my_augmenter.augment(df1.x10.to_numpy())
df1['rev_x11'] = my_augmenter.augment(df1.x11.to_numpy())
df1['rev_x12'] = my_augmenter.augment(df1.x12.to_numpy())
df1['rev_x13'] = my_augmenter.augment(df1.x13.to_numpy())
df1['rev_x14'] = my_augmenter.augment(df1.x14.to_numpy())
df1['rev_x15'] = my_augmenter.augment(df1.x15.to_numpy())
df1['rev_x16'] = my_augmenter.augment(df1.x16.to_numpy())
df1['rev_x17'] = my_augmenter.augment(df1.x17.to_numpy())
df1['rev_x18'] = my_augmenter.augment(df1.x18.to_numpy())
df1['rev_x19'] = my_augmenter.augment(df1.x19.to_numpy())
df1['rev_x20'] = my_augmenter.augment(df1.x20.to_numpy())
df1['rev_x21'] = my_augmenter.augment(df1.x21.to_numpy())
df1['rev_x22'] = my_augmenter.augment(df1.x21.to_numpy())
df1['rev_x23'] = my_augmenter.augment(df1.x23.to_numpy())
df1['rev_x24'] = my_augmenter.augment(df1.x24.to_numpy())
df1['rev_x25'] = my_augmenter.augment(df1.x25.to_numpy())
df1['rev_x26'] = my_augmenter.augment(df1.x26.to_numpy())
df1['rev_x27'] = my_augmenter.augment(df1.x27.to_numpy())
df1['rev_x28'] = my_augmenter.augment(df1.x28.to_numpy())
df1['rev_x29'] = my_augmenter.augment(df1.x29.to_numpy())
df1['rev_x30'] = my_augmenter.augment(df1.x30.to_numpy())
df1['rev_x31'] = my_augmenter.augment(df1.x31.to_numpy())
df1['rev_x32'] = my_augmenter.augment(df1.x32.to_numpy())
df1['rev_x33'] = my_augmenter.augment(df1.x33.to_numpy())
df1['rev_x34'] = my_augmenter.augment(df1.x34.to_numpy())
df1['rev_x35'] = my_augmenter.augment(df1.x35.to_numpy())
df1['rev_x36'] = my_augmenter.augment(df1.x36.to_numpy())
df1['rev_x37'] = my_augmenter.augment(df1.x37.to_numpy())
df1['rev_x38'] = my_augmenter.augment(df1.x38.to_numpy())
df1['rev_x39'] =my_augmenter.augment(df1.x39.to_numpy())
df1['rev_x40'] = my_augmenter.augment(df1.x40.to_numpy())
df1['rev_x41'] = my_augmenter.augment(df1.x41.to_numpy())
df1['rev_x42'] = my_augmenter.augment(df1.x42.to_numpy())
df1['rev_x43'] = my_augmenter.augment(df1.x43.to_numpy())
df1['rev_x44'] = my_augmenter.augment(df1.x44.to_numpy())
df1['rev_x45'] = my_augmenter.augment(df1.x45.to_numpy())
df1['rev_x46'] = my_augmenter.augment(df1.x46.to_numpy())
df1['rev_x47'] = my_augmenter.augment(df1.x47.to_numpy())
df1['rev_x48'] = my_augmenter.augment(df1.x48.to_numpy())
df1['rev_x49'] = my_augmenter.augment(df1.x49.to_numpy())
df1['rev_x50'] = my_augmenter.augment(df1.x50.to_numpy())
df1['rev_x51'] = my_augmenter.augment(df1.x51.to_numpy())
df1['rev_x52'] = my_augmenter.augment(df1.x52.to_numpy())
df1['rev_x53'] = my_augmenter.augment(df1.x53.to_numpy())
df1['rev_x54'] =my_augmenter.augment(df1.x54.to_numpy())
df1['rev_x55'] = my_augmenter.augment(df1.x55.to_numpy())
df1['rev_x56'] = my_augmenter.augment(df1.x56.to_numpy())
df1['rev_x57'] = my_augmenter.augment(df1.x57.to_numpy())
df1['rev_x58'] = my_augmenter.augment(df1.x58.to_numpy())
df1['rev_x59'] = my_augmenter.augment(df1.x59.to_numpy())
df1['rev_x60'] = my_augmenter.augment(df1.x60.to_numpy())
df1['rev_x61'] = my_augmenter.augment(df1.x61.to_numpy())


df3 = df1[['time', 'rev_x1', 'rev_x2', 'rev_x3', 'rev_x4', 'rev_x5',
          'rev_x6', 'rev_x7', 'rev_x8', 'rev_x9', 'rev_x10',
          'rev_x11', 'rev_x12', 'rev_x13', 'rev_x14', 'rev_x15',
          'rev_x16', 'rev_x17', 'rev_x18', 'rev_x19', 'rev_x20',
          'rev_x21', 'rev_x22', 'rev_x23', 'rev_x24', 'rev_x25',
          'rev_x26', 'rev_x27', 'rev_x28', 'rev_x29', 'rev_x30',
          'rev_x31', 'rev_x32', 'rev_x33', 'rev_x34', 'rev_x35',
          'rev_x36', 'rev_x37', 'rev_x38', 'rev_x39', 'rev_x40',
          'rev_x41', 'rev_x42', 'rev_x43', 'rev_x44', 'rev_x45',
          'rev_x46', 'rev_x47', 'rev_x48', 'rev_x49', 'rev_x50',
          'rev_x51', 'rev_x52', 'rev_x53', 'rev_x54', 'rev_x55',
          'rev_x56', 'rev_x57', 'rev_x58', 'rev_x59', 'rev_x60',
          'rev_x61']]
df3.head(10)
# Out:
#           time    rev_x1    rev_x2    rev_x3      rev_x4    rev_x5     rev_x6  \
# 0  5/1/99 0:00 -0.840981 -4.596435  0.593416  136.339880 -0.118830 -20.669883
# 1  5/1/99 0:02 -0.822843 -4.542502  0.387263  135.658942 -0.128733 -18.758079
# 2  5/1/99 0:04 -0.826547 -4.681394  0.334582  134.977973 -0.138636 -17.836632
# 3  5/1/99 0:06 -0.843988 -4.758934  0.561918  133.228949 -0.148142 -18.517601
# 4  5/1/99 0:08 -0.877441 -4.749928  0.406426  135.301215 -0.155314 -17.505913
# 5  5/1/99 0:10 -0.863607 -4.611746  0.266091  133.555731 -0.162501 -16.494255
# 6  5/1/99 0:12 -0.866343 -4.530210  0.204153  134.069434 -0.169672 -15.329521
# 7  5/1/99 0:14 -0.853943 -4.699047  0.122202  134.416174 -0.176859 -13.937523
# 8  5/1/99 0:16 -0.887390 -4.553506  0.013136  134.416174 -0.184046 -13.630058
# 9  5/1/99 0:18 -0.842680 -4.639561 -0.170921  132.747839 -0.191218 -11.910331
#
#      rev_x7    rev_x8    rev_x9  ...    rev_x52   rev_x53   rev_x54  \
# ...

# %%
df1_nnnn=pd.concat([df1, df3], axis=1)
df1_nnnn
# Out:
#                 time        x1        x2        x3          x4        x5  \
# 0        5/1/99 0:00  0.376665 -4.596435 -4.095756   13.497687 -0.118830
# 1        5/1/99 0:02  0.475720 -4.542502 -4.018359   16.230659 -0.128733
# 2        5/1/99 0:04  0.363848 -4.681394 -4.353147   14.127997 -0.138636
# 3        5/1/99 0:06  0.301590 -4.758934 -4.023612   13.161566 -0.148142
# 4        5/1/99 0:08  0.265578 -4.749928 -4.333150   15.267340 -0.155314
# ...              ...       ...       ...       ...         ...       ...
# 18393  5/28/99 23:58 -0.877441  0.786430  0.406426  135.301215  0.112295
# 18394   5/29/99 0:00 -0.843988  0.633086  0.561918  133.228949  0.141332
# 18395   5/29/99 0:02 -0.826547  0.450126  0.334582  134.977973  0.170370
# 18396   5/29/99 0:04 -0.822843  0.419383  0.387263  135.658942  0.199422
# 18397   5/29/99 0:06 -0.840981  0.582710  0.593416  136.339880  0.228460
#
#               x6        x7        x8        x9  ...    rev_x52   rev_x53  \
# ...

# %%
df1_nnnn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18398 entries, 0 to 18397
# Columns: 368 entries, time to rev_x61
# dtypes: float64(360), int64(6), object(2)
# memory usage: 51.7+ MB

# %%
df1
# Out:
#                 time  y        x1        x2        x3          x4        x5  \
# 0        5/1/99 0:00  0  0.376665 -4.596435 -4.095756   13.497687 -0.118830
# 1        5/1/99 0:02  0  0.475720 -4.542502 -4.018359   16.230659 -0.128733
# 2        5/1/99 0:04  0  0.363848 -4.681394 -4.353147   14.127997 -0.138636
# 3        5/1/99 0:06  0  0.301590 -4.758934 -4.023612   13.161566 -0.148142
# 4        5/1/99 0:08  0  0.265578 -4.749928 -4.333150   15.267340 -0.155314
# ...              ... ..       ...       ...       ...         ...       ...
# 18393  5/28/99 23:58  0 -0.877441  0.786430  0.406426  135.301215  0.112295
# 18394   5/29/99 0:00  0 -0.843988  0.633086  0.561918  133.228949  0.141332
# 18395   5/29/99 0:02  0 -0.826547  0.450126  0.334582  134.977973  0.170370
# 18396   5/29/99 0:04  0 -0.822843  0.419383  0.387263  135.658942  0.199422
# 18397   5/29/99 0:06  0 -0.840981  0.582710  0.593416  136.339880  0.228460
#
# ...

# %%
df22
# Out:
#        x1_pct_change_5  x2_pct_change_5  x3_pct_change_5  x4_pct_change_5  \
# 0                  NaN              NaN              NaN              NaN
# 1                  NaN              NaN              NaN              NaN
# 2                  NaN              NaN              NaN              NaN
# 3                  NaN              NaN              NaN              NaN
# 4                  NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 18393         0.041252        -0.094298        -3.377863         0.019235
# 18394        -0.048910        -0.166841        41.776313        -0.008832
# 18395        -0.032081        -0.462800         1.737939         0.004180
# 18396        -0.050211        -0.358012         0.896924         0.011856
# 18397        -0.026199        -0.207465         1.230123         0.020846
#
#        x5_pct_change_5  x6_pct_change_5  x7_pct_change_5  x8_pct_change_5  \
# ...

# %%
df1_nn=pd.concat([df1, df2], axis=1)
df1_nn
# Out:
#                 time  y        x1        x2        x3          x4        x5  \
# 0        5/1/99 0:00  0  0.376665 -4.596435 -4.095756   13.497687 -0.118830
# 1        5/1/99 0:02  0  0.475720 -4.542502 -4.018359   16.230659 -0.128733
# 2        5/1/99 0:04  0  0.363848 -4.681394 -4.353147   14.127997 -0.138636
# 3        5/1/99 0:06  0  0.301590 -4.758934 -4.023612   13.161566 -0.148142
# 4        5/1/99 0:08  0  0.265578 -4.749928 -4.333150   15.267340 -0.155314
# ...              ... ..       ...       ...       ...         ...       ...
# 18393  5/28/99 23:58  0 -0.877441  0.786430  0.406426  135.301215  0.112295
# 18394   5/29/99 0:00  0 -0.843988  0.633086  0.561918  133.228949  0.141332
# 18395   5/29/99 0:02  0 -0.826547  0.450126  0.334582  134.977973  0.170370
# 18396   5/29/99 0:04  0 -0.822843  0.419383  0.387263  135.658942  0.199422
# 18397   5/29/99 0:06  0 -0.840981  0.582710  0.593416  136.339880  0.228460
#
# ...

# %%
dd=pd.concat([df1, df2], axis=1)
dd
# Out:
#                 time  y        x3        x2       x18       x17       x16  \
# 0        5/1/99 0:00  0 -4.095756 -4.596435 -0.944167 -2.327329  0.199901
# 1        5/1/99 0:02  0 -4.018359 -4.542502 -0.939994 -2.340627  0.304313
# 2        5/1/99 0:04  0 -4.353147 -4.681394 -0.935824 -2.353925  0.252839
# 3        5/1/99 0:06  0 -4.023612 -4.758934 -0.931651 -2.367223  0.072873
# 4        5/1/99 0:08  0 -4.333150 -4.749928 -0.927478 -2.380521  0.171033
# ...              ... ..       ...       ...       ...       ...       ...
# 18393  5/28/99 23:58  0  0.406426  0.786430 -0.559565 -0.527784 -0.209548
# 18394   5/29/99 0:00  0  0.561918  0.633086 -0.567920 -0.527784 -0.098630
# 18395   5/29/99 0:02  0  0.334582  0.450126 -0.576274 -0.527784 -0.092927
# 18396   5/29/99 0:04  0  0.387263  0.419383 -0.584628 -0.527784 -0.053735
# 18397   5/29/99 0:06  0  0.593416  0.582710 -0.592982 -0.527784 -0.062127
#
#             x12       x19       x54  ...  x12_pct_change  x19_pct_change  \
# ...

# %%
df3 = df3.drop(['time'], axis=1)
ddd=pd.concat([dd, df3], axis=1)
ddd
# Out:
#                 time  y        x3        x2       x18       x17       x16  \
# 0        5/1/99 0:00  0 -4.095756 -4.596435 -0.944167 -2.327329  0.199901
# 1        5/1/99 0:02  0 -4.018359 -4.542502 -0.939994 -2.340627  0.304313
# 2        5/1/99 0:04  0 -4.353147 -4.681394 -0.935824 -2.353925  0.252839
# 3        5/1/99 0:06  0 -4.023612 -4.758934 -0.931651 -2.367223  0.072873
# 4        5/1/99 0:08  0 -4.333150 -4.749928 -0.927478 -2.380521  0.171033
# ...              ... ..       ...       ...       ...       ...       ...
# 18393  5/28/99 23:58  0  0.406426  0.786430 -0.559565 -0.527784 -0.209548
# 18394   5/29/99 0:00  0  0.561918  0.633086 -0.567920 -0.527784 -0.098630
# 18395   5/29/99 0:02  0  0.334582  0.450126 -0.576274 -0.527784 -0.092927
# 18396   5/29/99 0:04  0  0.387263  0.419383 -0.584628 -0.527784 -0.053735
# 18397   5/29/99 0:06  0  0.593416  0.582710 -0.592982 -0.527784 -0.062127
#
#             x12       x19       x54  ...  lag_1_x12  lag_1_x19  lag_1_x54  \
# ...

# %%
df4 = df4.drop(['time'], axis=1)
dddd=pd.concat([ddd, df4], axis=1)
dddd
# Out:
#                 time  y        x3        x2       x18       x17       x16  \
# 0        5/1/99 0:00  0 -4.095756 -4.596435 -0.944167 -2.327329  0.199901
# 1        5/1/99 0:02  0 -4.018359 -4.542502 -0.939994 -2.340627  0.304313
# 2        5/1/99 0:04  0 -4.353147 -4.681394 -0.935824 -2.353925  0.252839
# 3        5/1/99 0:06  0 -4.023612 -4.758934 -0.931651 -2.367223  0.072873
# 4        5/1/99 0:08  0 -4.333150 -4.749928 -0.927478 -2.380521  0.171033
# ...              ... ..       ...       ...       ...       ...       ...
# 18393  5/28/99 23:58  0  0.406426  0.786430 -0.559565 -0.527784 -0.209548
# 18394   5/29/99 0:00  0  0.561918  0.633086 -0.567920 -0.527784 -0.098630
# 18395   5/29/99 0:02  0  0.334582  0.450126 -0.576274 -0.527784 -0.092927
# 18396   5/29/99 0:04  0  0.387263  0.419383 -0.584628 -0.527784 -0.053735
# 18397   5/29/99 0:06  0  0.593416  0.582710 -0.592982 -0.527784 -0.062127
#
#             x12       x19       x54  ...  rolling_mean_x12  rolling_mean_x19  \
# ...

# %%
dddd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18398 entries, 0 to 18397
# Data columns (total 62 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   time              18398 non-null  object
#  1   y                 18398 non-null  int64
#  2   x3                18398 non-null  float64
#  3   x2                18398 non-null  float64
#  4   x18               18398 non-null  float64
#  5   x17               18398 non-null  float64
#  6   x16               18398 non-null  float64
#  7   x12               18398 non-null  float64
#  8   x19               18398 non-null  float64
#  9   x54               18398 non-null  float64
#  10  x40               18398 non-null  float64
#  11  x45               18398 non-null  float64
#  12  x6                18398 non-null  float64
#  13  x11               18398 non-null  float64
#  14  x29               18398 non-null  float64
#  15  x32               18398 non-null  float64
# ...

# %%
df5 = df5.drop(['time'], axis=1)
ddddd=pd.concat([dddd, df5], axis=1)
ddddd
# Out:
#                 time  y        x3        x2       x18       x17       x16  \
# 0        5/1/99 0:00  0 -4.095756 -4.596435 -0.944167 -2.327329  0.199901
# 1        5/1/99 0:02  0 -4.018359 -4.542502 -0.939994 -2.340627  0.304313
# 2        5/1/99 0:04  0 -4.353147 -4.681394 -0.935824 -2.353925  0.252839
# 3        5/1/99 0:06  0 -4.023612 -4.758934 -0.931651 -2.367223  0.072873
# 4        5/1/99 0:08  0 -4.333150 -4.749928 -0.927478 -2.380521  0.171033
# ...              ... ..       ...       ...       ...       ...       ...
# 18393  5/28/99 23:58  0  0.406426  0.786430 -0.559565 -0.527784 -0.209548
# 18394   5/29/99 0:00  0  0.561918  0.633086 -0.567920 -0.527784 -0.098630
# 18395   5/29/99 0:02  0  0.334582  0.450126 -0.576274 -0.527784 -0.092927
# 18396   5/29/99 0:04  0  0.387263  0.419383 -0.584628 -0.527784 -0.053735
# 18397   5/29/99 0:06  0  0.593416  0.582710 -0.592982 -0.527784 -0.062127
#
#             x12       x19       x54  ...  expanding_mean_x12  \
# ...

# %%
dddddd=pd.concat([ddddd, df22], axis=1)
dddddd
# Out:
#                 time  y        x3        x2       x18       x17       x16  \
# 0        5/1/99 0:00  0 -4.095756 -4.596435 -0.944167 -2.327329  0.199901
# 1        5/1/99 0:02  0 -4.018359 -4.542502 -0.939994 -2.340627  0.304313
# 2        5/1/99 0:04  0 -4.353147 -4.681394 -0.935824 -2.353925  0.252839
# 3        5/1/99 0:06  0 -4.023612 -4.758934 -0.931651 -2.367223  0.072873
# 4        5/1/99 0:08  0 -4.333150 -4.749928 -0.927478 -2.380521  0.171033
# ...              ... ..       ...       ...       ...       ...       ...
# 18393  5/28/99 23:58  0  0.406426  0.786430 -0.559565 -0.527784 -0.209548
# 18394   5/29/99 0:00  0  0.561918  0.633086 -0.567920 -0.527784 -0.098630
# 18395   5/29/99 0:02  0  0.334582  0.450126 -0.576274 -0.527784 -0.092927
# 18396   5/29/99 0:04  0  0.387263  0.419383 -0.584628 -0.527784 -0.053735
# 18397   5/29/99 0:06  0  0.593416  0.582710 -0.592982 -0.527784 -0.062127
#
#             x12       x19       x54  ...  x12_pct_change_5  x19_pct_change_5  \
# ...

# %%
ddddddd=pd.concat([dddddd, df23], axis=1)
ddddddd
# Out:
#                 time  y        x3        x2       x18       x17       x16  \
# 0        5/1/99 0:00  0 -4.095756 -4.596435 -0.944167 -2.327329  0.199901
# 1        5/1/99 0:02  0 -4.018359 -4.542502 -0.939994 -2.340627  0.304313
# 2        5/1/99 0:04  0 -4.353147 -4.681394 -0.935824 -2.353925  0.252839
# 3        5/1/99 0:06  0 -4.023612 -4.758934 -0.931651 -2.367223  0.072873
# 4        5/1/99 0:08  0 -4.333150 -4.749928 -0.927478 -2.380521  0.171033
# ...              ... ..       ...       ...       ...       ...       ...
# 18393  5/28/99 23:58  0  0.406426  0.786430 -0.559565 -0.527784 -0.209548
# 18394   5/29/99 0:00  0  0.561918  0.633086 -0.567920 -0.527784 -0.098630
# 18395   5/29/99 0:02  0  0.334582  0.450126 -0.576274 -0.527784 -0.092927
# 18396   5/29/99 0:04  0  0.387263  0.419383 -0.584628 -0.527784 -0.053735
# 18397   5/29/99 0:06  0  0.593416  0.582710 -0.592982 -0.527784 -0.062127
#
#             x12       x19       x54  ...  x12_pct_change_2  x19_pct_change_2  \
# ...

# %%
dddddddd=pd.concat([ddddddd, df24], axis=1)
dddddddd
# Out:
#                 time  y        x3        x2       x18       x17       x16  \
# 0        5/1/99 0:00  0 -4.095756 -4.596435 -0.944167 -2.327329  0.199901
# 1        5/1/99 0:02  0 -4.018359 -4.542502 -0.939994 -2.340627  0.304313
# 2        5/1/99 0:04  0 -4.353147 -4.681394 -0.935824 -2.353925  0.252839
# 3        5/1/99 0:06  0 -4.023612 -4.758934 -0.931651 -2.367223  0.072873
# 4        5/1/99 0:08  0 -4.333150 -4.749928 -0.927478 -2.380521  0.171033
# ...              ... ..       ...       ...       ...       ...       ...
# 18393  5/28/99 23:58  0  0.406426  0.786430 -0.559565 -0.527784 -0.209548
# 18394   5/29/99 0:00  0  0.561918  0.633086 -0.567920 -0.527784 -0.098630
# 18395   5/29/99 0:02  0  0.334582  0.450126 -0.576274 -0.527784 -0.092927
# 18396   5/29/99 0:04  0  0.387263  0.419383 -0.584628 -0.527784 -0.053735
# 18397   5/29/99 0:06  0  0.593416  0.582710 -0.592982 -0.527784 -0.062127
#
#             x12       x19       x54  ...  x12_pct_change_3  x19_pct_change_3  \
# ...

# %%
import matplotlib.pyplot as plt4
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from matplotlib import pyplot

# %%
# random forest to check feature importance 
# Separate input features (X) and target variable (y)
y = dddddddd.y
X = dddddddd.drop(['y','time'], axis=1)

# %%
X1=X.fillna(0)
X1
# Out:
#              x3        x2       x18       x17       x16       x12       x19  \
# 0     -4.095756 -4.596435 -0.944167 -2.327329  0.199901 -0.052959  3.075199
# 1     -4.018359 -4.542502 -0.939994 -2.340627  0.304313 -0.014244  3.075199
# 2     -4.353147 -4.681394 -0.935824 -2.353925  0.252839  0.065150  3.075199
# 3     -4.023612 -4.758934 -0.931651 -2.367223  0.072873 -0.067199  3.075199
# 4     -4.333150 -4.749928 -0.927478 -2.380521  0.171033 -0.018472  3.075199
# ...         ...       ...       ...       ...       ...       ...       ...
# 18393  0.406426  0.786430 -0.559565 -0.527784 -0.209548 -0.013282 -3.926967
# 18394  0.561918  0.633086 -0.567920 -0.527784 -0.098630 -0.087923 -3.926967
# 18395  0.334582  0.450126 -0.576274 -0.527784 -0.092927 -0.019256 -3.926967
# 18396  0.387263  0.419383 -0.584628 -0.527784 -0.053735  0.029572 -3.926967
# 18397  0.593416  0.582710 -0.592982 -0.527784 -0.062127  0.016245 -3.926967
#
# ...

# %%
X1
# Out:
#              x3        x2       x18       x17       x16       x12       x19  \
# 0     -4.095756 -4.596435 -0.944167 -2.327329  0.199901 -0.052959  3.075199
# 1     -4.018359 -4.542502 -0.939994 -2.340627  0.304313 -0.014244  3.075199
# 2     -4.353147 -4.681394 -0.935824 -2.353925  0.252839  0.065150  3.075199
# 3     -4.023612 -4.758934 -0.931651 -2.367223  0.072873 -0.067199  3.075199
# 4     -4.333150 -4.749928 -0.927478 -2.380521  0.171033 -0.018472  3.075199
# ...         ...       ...       ...       ...       ...       ...       ...
# 18393  0.406426  0.786430 -0.559565 -0.527784 -0.209548 -0.013282 -3.926967
# 18394  0.561918  0.633086 -0.567920 -0.527784 -0.098630 -0.087923 -3.926967
# 18395  0.334582  0.450126 -0.576274 -0.527784 -0.092927 -0.019256 -3.926967
# 18396  0.387263  0.419383 -0.584628 -0.527784 -0.053735  0.029572 -3.926967
# 18397  0.593416  0.582710 -0.592982 -0.527784 -0.062127  0.016245 -3.926967
#
# ...

# %%
# define the model
model = RandomForestClassifier()
# fit the model
model.fit(X1, y)
# get importance
importance = model.feature_importances_

# %%
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.savefig('feature_importance.png')
pyplot.show()
# Out:
# Feature: 0, Score: 0.07967
# Feature: 1, Score: 0.02658
# Feature: 2, Score: 0.02200
# Feature: 3, Score: 0.02108
# Feature: 4, Score: 0.01669
# Feature: 5, Score: 0.00384
# Feature: 6, Score: 0.01403
# Feature: 7, Score: 0.00815
# Feature: 8, Score: 0.02482
# Feature: 9, Score: 0.00949
# Feature: 10, Score: 0.00691
# Feature: 11, Score: 0.00776
# Feature: 12, Score: 0.01076
# Feature: 13, Score: 0.00950
# Feature: 14, Score: 0.00651
# Feature: 15, Score: 0.01885
# Feature: 16, Score: 0.01403
# Feature: 17, Score: 0.00946
# Feature: 18, Score: 0.00544
# Feature: 19, Score: 0.00513
# Feature: 20, Score: 0.00404
# Feature: 21, Score: 0.01476
# Feature: 22, Score: 0.00310
# Feature: 23, Score: 0.01146
# Feature: 24, Score: 0.00645
# Feature: 25, Score: 0.00374
# Feature: 26, Score: 0.00843
# Feature: 27, Score: 0.00517
# Feature: 28, Score: 0.00438
# Feature: 29, Score: 0.00264
# Feature: 30, Score: 0.01399
# Feature: 31, Score: 0.01706
# Feature: 32, Score: 0.00336
# ...

# %%
(pd.Series(model.feature_importances_, index=X.columns)
   .nlargest(20)
   .plot(kind='barh'))
# Out:
# <AxesSubplot:>

# %%
df1
# Out:
#                 time  y        x1        x2        x3          x4        x5  \
# 0        5/1/99 0:00  0  0.376665 -4.596435 -4.095756   13.497687 -0.118830
# 1        5/1/99 0:02  0  0.475720 -4.542502 -4.018359   16.230659 -0.128733
# 2        5/1/99 0:04  0  0.363848 -4.681394 -4.353147   14.127997 -0.138636
# 3        5/1/99 0:06  0  0.301590 -4.758934 -4.023612   13.161566 -0.148142
# 4        5/1/99 0:08  0  0.265578 -4.749928 -4.333150   15.267340 -0.155314
# ...              ... ..       ...       ...       ...         ...       ...
# 18393  5/28/99 23:58  0 -0.877441  0.786430  0.406426  135.301215  0.112295
# 18394   5/29/99 0:00  0 -0.843988  0.633086  0.561918  133.228949  0.141332
# 18395   5/29/99 0:02  0 -0.826547  0.450126  0.334582  134.977973  0.170370
# 18396   5/29/99 0:04  0 -0.822843  0.419383  0.387263  135.658942  0.199422
# 18397   5/29/99 0:06  0 -0.840981  0.582710  0.593416  136.339880  0.228460
#
# ...

# %%
from pyHSICLasso import HSICLasso

# %%
hsic_lasso = HSICLasso()

# %%
hsic_lasso

# %%
hsic_lasso.input("processminer-rare-event-data-Copy1.csv")
# Out:
# True

# %%
hsic_lasso.input([[1, 1, 1], [2, 2, 2]], [0, 1])
# Out:
# True

# %%
hsic_lasso

# %%
import numpy as np

# %%
hsic_lasso.input(np.array([[1, 1, 1], [2, 2, 2]]), np.array([0, 1]))
# Out:
# True

# %%
hsic_lasso.regression(5)

# %%
hsic_lasso.dump()

# %%
hsic_lasso.classification(10)

# %%
from pyHSICLasso import HSICLasso
hsic_lasso = HSICLasso()

hsic_lasso.input("data.csv")
# Out:
# True

# %%
hsic_lasso.input([[1, 1, 1,1, 1, 1,1, 1, 1,3], [2, 2, 2,2, 2, 2,2, 2, 2,8]], [0, 1])
# Out:
# True

# %%
hsic_lasso.input(np.array([[1, 1, 1], [2, 2, 2]]), np.array([0, 1]))
# Out:
# True

# %%
hsic_lasso.regression(5)

# %%
hsic_lasso.classification(10)

# %%
hsic_lasso.get_features
# Out:
# <bound method HSICLasso.get_features of <pyHSICLasso.api.HSICLasso object at 0x7fbe2d1ec3a0>>

# %%
hsic_lasso.plot

# %%
from pyHSICLasso import HSICLasso
hsic_lasso = HSICLasso()

hsic_lasso.input("processminer-rare-event-data-Copy1.csv")
# Out:
# True

# %%
import pandas as pd
df = pd.read_csv("processminer-rare-event-data-Copy1.csv")

# %%
X = df['X'].transpose()
Y = df['Y'][0]
featname = [ 'Feat%d' % x for x in range(1, X.shape[1] + 1) ]

# %%
X = df.drop(['y'], axis=1)

y = df['y']

# %%
featname = [ 'Feat%d' % x for x in range(1, X.shape[1] + 1) ]

# %%
hsic_lasso.input(X,y,featname=featname)
hsic_lasso.regression(5)
hsic_lasso.dump()
hsic_lasso.plot_path()

#Save parameters
hsic_lasso.save_param()

# %%
df = pd.read_csv("processed_data10.csv") 
df.head(n=5)  # visualize the data.
# Out:
#    Unnamed: 0         time  y        x1        x2        x3         x4  \
# 0           0  5/1/99 0:00  0  0.376665 -4.596435 -4.095756  13.497687
# 1           1  5/1/99 0:02  0  0.475720 -4.542502 -4.018359  16.230659
# 2           2  5/1/99 0:04  0  0.363848 -4.681394 -4.353147  14.127997
# 3           3  5/1/99 0:06  0  0.301590 -4.758934 -4.023612  13.161566
# 4           4  5/1/99 0:08  0  0.265578 -4.749928 -4.333150  15.267340
#
#          x5         x6        x7  ...  x52_pct_change_5  x53_pct_change_5  \
# 0 -0.118830 -20.669883  0.000732  ...               NaN               NaN
# 1 -0.128733 -18.758079  0.000732  ...               NaN               NaN
# 2 -0.138636 -17.836632  0.010803  ...               NaN               NaN
# 3 -0.148142 -18.517601  0.002075  ...               NaN               NaN
# 4 -0.155314 -17.505913  0.000732  ...               NaN               NaN
#
#    x54_pct_change_5  x55_pct_change_5  x56_pct_change_5  x57_pct_change_5  \
# ...

# %%
from tsaug import TimeWarp, Crop, Quantize, Drift, Reverse
my_augmenter = (
    Quantize(n_levels=[10, 20, 30])  # random quantize to 10-, 20-, or 30- level sets
)

# %%
#lag features
df1=df
df1['qnt_x1'] = my_augmenter.augment(df1.x1.to_numpy())
df1['qnt_x2'] = my_augmenter.augment(df1.x2.to_numpy())
df1['qnt_x3'] = my_augmenter.augment(df1.x3.to_numpy())
df1['qnt_x4'] = my_augmenter.augment(df1.x4.to_numpy())
df1['qnt_x5'] = my_augmenter.augment(df1.x5.to_numpy())
df1['qnt_x6'] = my_augmenter.augment(df1.x6.to_numpy())
df1['qnt_x7'] = my_augmenter.augment(df1.x7.to_numpy())
df1['qnt_x8'] = my_augmenter.augment(df1.x8.to_numpy())
df1['qnt_x9'] = my_augmenter.augment(df1.x9.to_numpy())
df1['qnt_x10'] = my_augmenter.augment(df1.x10.to_numpy())
df1['qnt_x11'] = my_augmenter.augment(df1.x11.to_numpy())
df1['qnt_x12'] = my_augmenter.augment(df1.x12.to_numpy())
df1['qnt_x13'] = my_augmenter.augment(df1.x13.to_numpy())
df1['qnt_x14'] = my_augmenter.augment(df1.x14.to_numpy())
df1['qnt_x15'] = my_augmenter.augment(df1.x15.to_numpy())
df1['qnt_x16'] = my_augmenter.augment(df1.x16.to_numpy())
df1['qnt_x17'] = my_augmenter.augment(df1.x17.to_numpy())
df1['qnt_x18'] = my_augmenter.augment(df1.x18.to_numpy())
df1['qnt_x19'] = my_augmenter.augment(df1.x19.to_numpy())
df1['qnt_x20'] = my_augmenter.augment(df1.x20.to_numpy())
df1['qnt_x21'] = my_augmenter.augment(df1.x21.to_numpy())
df1['qnt_x22'] = my_augmenter.augment(df1.x21.to_numpy())
df1['qnt_x23'] = my_augmenter.augment(df1.x23.to_numpy())
df1['qnt_x24'] = my_augmenter.augment(df1.x24.to_numpy())
df1['qnt_x25'] = my_augmenter.augment(df1.x25.to_numpy())
df1['qnt_x26'] = my_augmenter.augment(df1.x26.to_numpy())
df1['qnt_x27'] = my_augmenter.augment(df1.x27.to_numpy())
df1['qnt_x28'] = my_augmenter.augment(df1.x28.to_numpy())
df1['qnt_x29'] = my_augmenter.augment(df1.x29.to_numpy())
df1['qnt_x30'] = my_augmenter.augment(df1.x30.to_numpy())
df1['qnt_x31'] = my_augmenter.augment(df1.x31.to_numpy())
df1['qnt_x32'] = my_augmenter.augment(df1.x32.to_numpy())
df1['qnt_x33'] = my_augmenter.augment(df1.x33.to_numpy())
df1['qnt_x34'] = my_augmenter.augment(df1.x34.to_numpy())
df1['qnt_x35'] = my_augmenter.augment(df1.x35.to_numpy())
df1['qnt_x36'] = my_augmenter.augment(df1.x36.to_numpy())
df1['qnt_x37'] = my_augmenter.augment(df1.x37.to_numpy())
df1['qnt_x38'] = my_augmenter.augment(df1.x38.to_numpy())
df1['qnt_x39'] =my_augmenter.augment(df1.x39.to_numpy())
df1['qnt_x40'] = my_augmenter.augment(df1.x40.to_numpy())
df1['qnt_x41'] = my_augmenter.augment(df1.x41.to_numpy())
df1['qnt_x42'] = my_augmenter.augment(df1.x42.to_numpy())
df1['qnt_x43'] = my_augmenter.augment(df1.x43.to_numpy())
df1['qnt_x44'] = my_augmenter.augment(df1.x44.to_numpy())
df1['qnt_x45'] = my_augmenter.augment(df1.x45.to_numpy())
df1['qnt_x46'] = my_augmenter.augment(df1.x46.to_numpy())
df1['qnt_x47'] = my_augmenter.augment(df1.x47.to_numpy())
df1['qnt_x48'] = my_augmenter.augment(df1.x48.to_numpy())
df1['qnt_x49'] = my_augmenter.augment(df1.x49.to_numpy())
df1['qnt_x50'] = my_augmenter.augment(df1.x50.to_numpy())
df1['qnt_x51'] = my_augmenter.augment(df1.x51.to_numpy())
df1['qnt_x52'] = my_augmenter.augment(df1.x52.to_numpy())
df1['qnt_x53'] = my_augmenter.augment(df1.x53.to_numpy())
df1['qnt_x54'] =my_augmenter.augment(df1.x54.to_numpy())
df1['qnt_x55'] = my_augmenter.augment(df1.x55.to_numpy())
df1['qnt_x56'] = my_augmenter.augment(df1.x56.to_numpy())
df1['qnt_x57'] = my_augmenter.augment(df1.x57.to_numpy())
df1['qnt_x58'] = my_augmenter.augment(df1.x58.to_numpy())
df1['qnt_x59'] = my_augmenter.augment(df1.x59.to_numpy())
df1['qnt_x60'] = my_augmenter.augment(df1.x60.to_numpy())
df1['qnt_x61'] = my_augmenter.augment(df1.x61.to_numpy())


df3 = df1[['time', 'qnt_x1', 'qnt_x2', 'qnt_x3', 'qnt_x4', 'qnt_x5',
          'qnt_x6', 'qnt_x7', 'qnt_x8', 'qnt_x9', 'qnt_x10',
          'qnt_x11', 'qnt_x12', 'qnt_x13', 'qnt_x14', 'qnt_x15',
          'qnt_x16', 'qnt_x17', 'qnt_x18', 'qnt_x19', 'qnt_x20',
          'qnt_x21', 'qnt_x22', 'qnt_x23', 'qnt_x24', 'qnt_x25',
          'qnt_x26', 'qnt_x27', 'qnt_x28', 'qnt_x29', 'qnt_x30',
          'qnt_x31', 'qnt_x32', 'qnt_x33', 'qnt_x34', 'qnt_x35',
          'qnt_x36', 'qnt_x37', 'qnt_x38', 'qnt_x39', 'qnt_x40',
          'qnt_x41', 'qnt_x42', 'qnt_x43', 'qnt_x44', 'qnt_x45',
          'qnt_x46', 'qnt_x47', 'qnt_x48', 'qnt_x49', 'qnt_x50',
          'qnt_x51', 'qnt_x52', 'qnt_x53', 'qnt_x54', 'qnt_x55',
          'qnt_x56', 'qnt_x57', 'qnt_x58', 'qnt_x59', 'qnt_x60',
          'qnt_x61']]
df3.head(10)
# Out:
#           time    qnt_x1    qnt_x2    qnt_x3     qnt_x4    qnt_x5    qnt_x6  \
# 0  5/1/99 0:00  0.488618 -1.990155 -2.854128  22.393137  0.428193  2.193466
# 1  5/1/99 0:02  0.488618 -1.990155 -2.854128  22.393137  0.428193  2.193466
# 2  5/1/99 0:04  0.488618 -1.990155 -2.854128  22.393137  0.428193  2.193466
# 3  5/1/99 0:06  0.488618 -1.990155 -2.854128  22.393137  0.428193  2.193466
# 4  5/1/99 0:08  0.488618 -1.990155 -2.854128  22.393137  0.428193  2.193466
# 5  5/1/99 0:10  0.488618 -1.990155 -2.854128  22.393137 -0.158144  2.193466
# 6  5/1/99 0:12  0.488618 -1.990155 -2.854128  22.393137 -0.158144  2.193466
# 7  5/1/99 0:14  0.488618 -1.990155 -2.854128  22.393137 -0.158144  2.193466
# 8  5/1/99 0:16  0.488618 -1.990155 -2.854128  55.266922 -0.158144  2.193466
# 9  5/1/99 0:18  0.488618 -1.990155 -2.854128  55.266922 -0.158144  2.193466
#
#      qnt_x7    qnt_x8    qnt_x9  ...    qnt_x52    qnt_x53   qnt_x54  \
# ...

# %%
dff=pd.merge(df, df3, how='inner', on=None, left_on=None, right_on=None)

# %%
dff
# Out:
#        Unnamed: 0           time  y        x1        x2        x3          x4  \
# 0               0    5/1/99 0:00  0  0.376665 -4.596435 -4.095756   13.497687
# 1               1    5/1/99 0:02  0  0.475720 -4.542502 -4.018359   16.230659
# 2               2    5/1/99 0:04  0  0.363848 -4.681394 -4.353147   14.127997
# 3               3    5/1/99 0:06  0  0.301590 -4.758934 -4.023612   13.161566
# 4               4    5/1/99 0:08  0  0.265578 -4.749928 -4.333150   15.267340
# ...           ...            ... ..       ...       ...       ...         ...
# 18393       18393  5/28/99 23:58  0 -0.877441  0.786430  0.406426  135.301215
# 18394       18394   5/29/99 0:00  0 -0.843988  0.633086  0.561918  133.228949
# 18395       18395   5/29/99 0:02  0 -0.826547  0.450126  0.334582  134.977973
# 18396       18396   5/29/99 0:04  0 -0.822843  0.419383  0.387263  135.658942
# 18397       18397   5/29/99 0:06  0 -0.840981  0.582710  0.593416  136.339880
#
# ...

# %%
# Remove time column 
dff = dff.drop(['Unnamed: 0'], axis=1)
dff
# Out:
#                 time  y        x1        x2        x3          x4        x5  \
# 0        5/1/99 0:00  0  0.376665 -4.596435 -4.095756   13.497687 -0.118830
# 1        5/1/99 0:02  0  0.475720 -4.542502 -4.018359   16.230659 -0.128733
# 2        5/1/99 0:04  0  0.363848 -4.681394 -4.353147   14.127997 -0.138636
# 3        5/1/99 0:06  0  0.301590 -4.758934 -4.023612   13.161566 -0.148142
# 4        5/1/99 0:08  0  0.265578 -4.749928 -4.333150   15.267340 -0.155314
# ...              ... ..       ...       ...       ...         ...       ...
# 18393  5/28/99 23:58  0 -0.877441  0.786430  0.406426  135.301215  0.112295
# 18394   5/29/99 0:00  0 -0.843988  0.633086  0.561918  133.228949  0.141332
# 18395   5/29/99 0:02  0 -0.826547  0.450126  0.334582  134.977973  0.170370
# 18396   5/29/99 0:04  0 -0.822843  0.419383  0.387263  135.658942  0.199422
# 18397   5/29/99 0:06  0 -0.840981  0.582710  0.593416  136.339880  0.228460
#
# ...

# %%
dff.to_csv('processed_data12.csv')
