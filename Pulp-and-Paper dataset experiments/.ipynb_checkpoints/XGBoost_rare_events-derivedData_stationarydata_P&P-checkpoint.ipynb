# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import numpy as np
from pylab import rcParams

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import recall_score, classification_report, auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, f1_score

from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from numpy import mean

from sklearn.metrics import accuracy_score

from numpy.random import seed
seed(7)

from sklearn.model_selection import train_test_split

SEED = 123 #used to help randomly select the data points
DATA_SPLIT_PCT = 0.2

rcParams['figure.figsize'] = 8, 6
LABELS = ["Normal","Break"]

# %%
df = pd.read_csv("processed_data5.csv") 
df.head(n=5)  # visualize the data.
# Out:
#    Unnamed: 0         time  y        x3        x2       x18       x17  \
# 0           0  5/1/99 0:00  0 -4.095756 -4.596435 -0.944167 -2.327329
# 1           1  5/1/99 0:02  0 -4.018359 -4.542502 -0.939994 -2.340627
# 2           2  5/1/99 0:04  0 -4.353147 -4.681394 -0.935824 -2.353925
# 3           3  5/1/99 0:06  0 -4.023612 -4.758934 -0.931651 -2.367223
# 4           4  5/1/99 0:08  0 -4.333150 -4.749928 -0.927478 -2.380521
#
#         x16       x12       x19  ...  expanding_mean_x12  expanding_mean_x19  \
# 0  0.199901 -0.052959  3.075199  ...                 NaN                 NaN
# 1  0.304313 -0.014244  3.075199  ...           -0.033601            3.075199
# 2  0.252839  0.065150  3.075199  ...           -0.000684            3.075199
# 3  0.072873 -0.067199  3.075199  ...           -0.017313            3.075199
# 4  0.171033 -0.018472  3.075199  ...           -0.017545            3.075199
#
#    expanding_mean_x54  expanding_mean_x40  expanding_mean_x45  \
# ...

# %%
df.y.value_counts()
# Out:
# 0    18274
# 1      124
# Name: y, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18398 entries, 0 to 18397
# Data columns (total 78 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          18398 non-null  int64
#  1   time                18398 non-null  object
#  2   y                   18398 non-null  int64
#  3   x3                  18398 non-null  float64
#  4   x2                  18398 non-null  float64
#  5   x18                 18398 non-null  float64
#  6   x17                 18398 non-null  float64
#  7   x16                 18398 non-null  float64
#  8   x12                 18398 non-null  float64
#  9   x19                 18398 non-null  float64
#  10  x54                 18398 non-null  float64
#  11  x40                 18398 non-null  float64
#  12  x45                 18398 non-null  float64
#  13  x6                  18398 non-null  float64
#  14  x11                 18398 non-null  float64
# ...

# %%
#rolling average transform
x3_rolling=df.x3.rolling(window=1500)
x3_rolling_mean=x3_rolling.mean()
x3_rolling_mean
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 18393    0.622620
# 18394    0.624486
# 18395    0.626209
# 18396    0.627967
# 18397    0.629819
# Name: x3, Length: 18398, dtype: float64

# %%
from matplotlib import pyplot
x3_rolling_mean.plot(color='red')
pyplot.show()

# %%
#rolling average transform for all real variables 
df['x3_rolling_mean']=df.x3.rolling(window=2000).mean()
df['x2_rolling_mean']=df.x2.rolling(window=2000).mean()
df['x18_rolling_mean']=df.x18.rolling(window=2000).mean()
df['x17_rolling_mean']=df.x17.rolling(window=2000).mean()
df['x16_rolling_mean']=df.x16.rolling(window=2000).mean()
df['x12_rolling_mean']=df.x12.rolling(window=2000).mean()
df['x19_rolling_mean']=df.x19.rolling(window=2000).mean()
df['x54_rolling_mean']=df.x54.rolling(window=2000).mean()
df['x40_rolling_mean']=df.x40.rolling(window=2000).mean()
df['x45_rolling_mean']=df.x45.rolling(window=2000).mean()
df['x6_rolling_mean']=df.x6.rolling(window=2000).mean()
df['x11_rolling_mean']=df.x11.rolling(window=2000).mean()
df['x29_rolling_mean']=df.x29.rolling(window=2000).mean()
df['x32_rolling_mean']=df.x32.rolling(window=2000).mean()
df['x15_rolling_mean']=df.x15.rolling(window=2000).mean()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18398 entries, 0 to 18397
# Data columns (total 93 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          18398 non-null  int64
#  1   time                18398 non-null  object
#  2   y                   18398 non-null  int64
#  3   x3                  18398 non-null  float64
#  4   x2                  18398 non-null  float64
#  5   x18                 18398 non-null  float64
#  6   x17                 18398 non-null  float64
#  7   x16                 18398 non-null  float64
#  8   x12                 18398 non-null  float64
#  9   x19                 18398 non-null  float64
#  10  x54                 18398 non-null  float64
#  11  x40                 18398 non-null  float64
#  12  x45                 18398 non-null  float64
#  13  x6                  18398 non-null  float64
#  14  x11                 18398 non-null  float64
# ...

# %%
df = df.drop(['Unnamed: 0'], axis=1)
df
# Out:
#                 time  y        x3        x2       x18       x17       x16  \
# 0        5/1/99 0:00  0 -4.095756 -4.596435 -0.944167 -2.327329  0.199901
# 1        5/1/99 0:02  0 -4.018359 -4.542502 -0.939994 -2.340627  0.304313
# 2        5/1/99 0:04  0 -4.353147 -4.681394 -0.935824 -2.353925  0.252839
# 3        5/1/99 0:06  0 -4.023612 -4.758934 -0.931651 -2.367223  0.072873
# 4        5/1/99 0:08  0 -4.333150 -4.749928 -0.927478 -2.380521  0.171033
# ...              ... ..       ...       ...       ...       ...       ...
# 18393  5/28/99 23:58  0  0.406426  0.786430 -0.559565 -0.527784 -0.209548
# 18394   5/29/99 0:00  0  0.561918  0.633086 -0.567920 -0.527784 -0.098630
# 18395   5/29/99 0:02  0  0.334582  0.450126 -0.576274 -0.527784 -0.092927
# 18396   5/29/99 0:04  0  0.387263  0.419383 -0.584628 -0.527784 -0.053735
# 18397   5/29/99 0:06  0  0.593416  0.582710 -0.592982 -0.527784 -0.062127
#
#             x12       x19       x54  ...  x12_rolling_mean  x19_rolling_mean  \
# ...

# %%
sign = lambda x: (1, -1)[x < 0]

def curve_shift(df, shift_by):
    '''
    This function will shift the binary labels in a dataframe.
    The curve shift will be with respect to the 1s. 
    For example, if shift is -2, the following process
    will happen: if row n is labeled as 1, then
    - Make row (n+shift_by):(n+shift_by-1) = 1.
    - Remove row n.
    i.e. the labels will be shifted up to 2 rows up.
    
    Inputs:
    df       A pandas dataframe with a binary labeled column. 
             This labeled column should be named as 'y'.
    shift_by An integer denoting the number of rows to shift.
    
    Output
    df       A dataframe with the binary labels shifted by shift.
    '''

    vector = df['y'].copy()
    for s in range(abs(shift_by)):
        tmp = vector.shift(sign(shift_by))
        tmp = tmp.fillna(0)
        vector += tmp
    labelcol = 'y'
    # Add vector to the df
    df.insert(loc=0, column=labelcol+'tmp', value=vector)
    # Remove the rows with labelcol == 1.
    df = df.drop(df[df[labelcol] == 1].index)
    # Drop labelcol and rename the tmp col as labelcol
    df = df.drop(labelcol, axis=1)
    df = df.rename(columns={labelcol+'tmp': labelcol})
    # Make the labelcol binary
    df.loc[df[labelcol] > 0, labelcol] = 1

    return df

# %%
'''
Shift the data by 2 units, equal to 4 minutes.

Test: Testing whether the shift happened correctly.
'''
print('Before shifting')  # Positive labeled rows before shifting.
one_indexes = df.index[df['y'] == 1]
display(df.iloc[(one_indexes[0]-3):(one_indexes[0]+2), 0:5].head(n=5))

# Shift the response column y by 2 rows to do a 4-min ahead prediction.
df = curve_shift(df, shift_by = -2)

print('After shifting')  # Validating if the shift happened correctly.
display(df.iloc[(one_indexes[0]-4):(one_indexes[0]+1), 0:5].head(n=5))
# Out:
# Before shifting
#              time  y         x3         x2        x18
# 256   5/1/99 8:32  0  -1.097158  -4.058394  -2.261420
# 257   5/1/99 8:34  0  -1.074373  -3.876199  -2.279643
# 258   5/1/99 8:36  0  -1.249954  -3.868467  -2.297866
# 259   5/1/99 8:38  1 -10.006578 -13.332664 -10.918982
# 260  5/1/99 10:50  0  -1.248529  -3.987897  -4.511733
# After shifting
#        y          time        x3        x2       x18
# 255  0.0   5/1/99 8:30 -1.133779 -3.865720 -2.243193
# 256  0.0   5/1/99 8:32 -1.097158 -4.058394 -2.261420
# 257  1.0   5/1/99 8:34 -1.074373 -3.876199 -2.279643
# 258  1.0   5/1/99 8:36 -1.249954 -3.868467 -2.297866
# 260  0.0  5/1/99 10:50 -1.248529 -3.987897 -4.511733

# %%
# Remove time column
df = df.drop(['time'], axis=1)

# %%
X = df.drop(['y'], axis=1)
y = df['y']

# %%
X = X.drop(['x3','x2','x18','x17','x16','x12','x19','x54','x40','x45','x6','x11','x29','x32','x15'], axis=1)

# %%
X=X.fillna(0)
X
# Out:
#        x3_pct_change  x2_pct_change  x18_pct_change  x17_pct_change  \
# 0           0.000000       0.000000        0.000000        0.000000
# 1          -0.018897      -0.011734       -0.004420        0.005714
# 2           0.083315       0.030576       -0.004436        0.005681
# 3          -0.075700       0.016563       -0.004459        0.005649
# 4           0.076930      -0.001892       -0.004479        0.005618
# ...              ...            ...             ...             ...
# 18393       0.527394       0.069612        0.015156        0.000000
# 18394       0.382584      -0.194987        0.014931        0.000000
# 18395      -0.404571      -0.288997        0.014710        0.000000
# 18396       0.157453      -0.068299        0.014497        0.000000
# 18397       0.532333       0.389446        0.014289        0.000000
#
#        x16_pct_change  x12_pct_change  x19_pct_change  x54_pct_change  \
# 0            0.000000        0.000000             0.0        0.000000
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18274 entries, 0 to 18397
# Data columns (total 75 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   x3_pct_change       18274 non-null  float64
#  1   x2_pct_change       18274 non-null  float64
#  2   x18_pct_change      18274 non-null  float64
#  3   x17_pct_change      18274 non-null  float64
#  4   x16_pct_change      18274 non-null  float64
#  5   x12_pct_change      18274 non-null  float64
#  6   x19_pct_change      18274 non-null  float64
#  7   x54_pct_change      18274 non-null  float64
#  8   x40_pct_change      18274 non-null  float64
#  9   x45_pct_change      18274 non-null  float64
#  10  x6_pct_change       18274 non-null  float64
#  11  x11_pct_change      18274 non-null  float64
#  12  x29_pct_change      18274 non-null  float64
#  13  x32_pct_change      18274 non-null  float64
#  14  x15_pct_change      18274 non-null  float64
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
X_train.shape, X_test.shape
# Out:
# ((14619, 75), (3655, 75))

# %%
# Feature scaling

# %%
cols = X_train.columns

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

X_train = pd.DataFrame(X_train, columns=[cols])
X_test = pd.DataFrame(X_test, columns=[cols])

# %%
# define model
model = XGBClassifier()
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: %.5f' % mean(scores))
# Out:
# Mean ROC AUC: 0.89330

# %%
model = XGBClassifier()

clf_0 = model.fit(X_train, y_train)

# %%
pred_y_0 = clf_0.predict(X_test)

print(accuracy_score(pred_y_0, y_test))
# Out:
# 0.986046511627907

# %%
target_names = ['class 0', 'class 1']
print(classification_report(y_test, pred_y_0, target_names=target_names))

# View confusion matrix for test data and predictions
confusion_matrix(y_test, pred_y_0)
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.99      1.00      0.99      3608
#      class 1       0.17      0.02      0.04        47
#
#     accuracy                           0.99      3655
#    macro avg       0.58      0.51      0.52      3655
# weighted avg       0.98      0.99      0.98      3655
# array([[3603,    5],
#        [  46,    1]])

# %% [markdown]
# # Weighted XGBoost for Class Imbalance

# %%
# define model
model = XGBClassifier(scale_pos_weight=90)

# %%
clf_1 = model.fit(X_train, y_train)
pred_y_1 = clf_1.predict(X_test)

print(accuracy_score(pred_y_1, y_test))
# Out:
# 0.9854993160054719

# %%
target_names = ['class 0', 'class 1']
print(classification_report(y_test, pred_y_1, target_names=target_names))

# View confusion matrix for test data and predictions
confusion_matrix(y_test, pred_y_1)
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.99      1.00      0.99      3608
#      class 1       0.33      0.13      0.18        47
#
#     accuracy                           0.99      3655
#    macro avg       0.66      0.56      0.59      3655
# weighted avg       0.98      0.99      0.98      3655
# array([[3596,   12],
#        [  41,    6]])

# %% [markdown]
# # Tune with GridSearch CV

# %%
# define grid
weights = [1, 10, 25, 50, 75, 99, 100, 1000]
param_grid = dict(scale_pos_weight=weights)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# define grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='roc_auc')

# %%
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.882671 using {'scale_pos_weight': 10}
# 0.880937 (0.056083) with: {'scale_pos_weight': 1}
# 0.882671 (0.053016) with: {'scale_pos_weight': 10}
# 0.881284 (0.051012) with: {'scale_pos_weight': 25}
# 0.859759 (0.053204) with: {'scale_pos_weight': 50}
# 0.870135 (0.046907) with: {'scale_pos_weight': 75}
# 0.860704 (0.054972) with: {'scale_pos_weight': 99}
# 0.867059 (0.053862) with: {'scale_pos_weight': 100}
# 0.842909 (0.063232) with: {'scale_pos_weight': 1000}

# %%
# define model
model = XGBClassifier(scale_pos_weight=350)

# %%
clf_2 = model.fit(X_train, y_train)
pred_y_2 = clf_2.predict(X_test)

print(accuracy_score(pred_y_2, y_test))
# Out:
# 0.9849521203830369

# %%
target_names = ['class 0', 'class 1']
print(classification_report(y_test, pred_y_2, target_names=target_names))

# View confusion matrix for test data and predictions
confusion_matrix(y_test, pred_y_2)
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.99      0.99      0.99      3608
#      class 1       0.38      0.28      0.32        47
#
#     accuracy                           0.98      3655
#    macro avg       0.69      0.64      0.66      3655
# weighted avg       0.98      0.98      0.98      3655
# array([[3587,   21],
#        [  34,   13]])
