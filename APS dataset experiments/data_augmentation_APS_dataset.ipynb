# %%
import matplotlib.pyplot as plt4
import numpy as np
import pandas as pd
from matplotlib import pyplot

import tsaug
from tsaug import AddNoise, Convolve, Crop, Drift, Pool, Quantize, Resize, Reverse, TimeWarp

# %%
df = pd.read_csv("APS_selected_without_null.csv") 
df
# Out:
#        Unnamed: 0     bj_000      ci_000    ay_002    ag_001         ay_005  \
# 0               0   799478.0  5245752.00  2198.356   828.488  469014.000000
# 1               1   392208.0  2291079.36     0.000     0.000   71510.000000
# 2               2   139730.0  2322692.16     0.000     0.000  202696.500000
# 3               3     3090.0     2135.04     0.000     0.000  181363.333333
# 4               4   399410.0  3565684.80     0.000     0.000  372236.000000
# ...           ...        ...         ...       ...       ...            ...
# 59995       59995   678792.0  8289544.32  5757.992  1061.362   45114.000000
# 59996       59996     9572.0   123344.64  5757.992  1061.362    4610.000000
# 59997       59997     6224.0     7518.72  5757.992  1061.362  137882.849000
# 59998       59998  1032454.0  4776505.92  5757.992  1061.362  119742.000000
# 59999       59999   260378.0  2480113.92     0.000     0.000  105702.000000
#
#          ag_002        am_0        ay_006    ee_003  ...    cs_002     aq_000  \
# 0      8571.650  107278.622  4.239660e+06  493384.0  ...  267998.0  1132040.0
# 1         0.000       0.000  7.727200e+05  178064.0  ...  164860.0   338544.0
# 2         0.000     486.750  8.704560e+05  159812.0  ...   56362.0   153698.0
# 3         0.000    3894.000  1.781648e+06      46.0  ...      24.0     1014.0
# 4         0.000     811.250  2.128914e+06  229790.0  ...   80950.0   551022.0
# ...         ...         ...           ...       ...  ...       ...        ...
# 59995  6691.674    2114.000  2.533260e+06  566884.0  ...  138036.0   776370.0
# 59996  6691.674   76769.085  9.912000e+04    6760.0  ...    3606.0    11622.0
# 59997  6691.674   76768.344  1.062160e+06     386.0  ...      72.0      874.0
# 59998  6691.558   76758.797  4.445146e+06  222654.0  ...  333922.0  1214970.0
# 59999     0.000       0.000  1.433988e+06  183200.0  ...   81228.0   334864.0
#
#            bf_000     at_000     ee_005      bb_000         bl_000     ee_000  \
# 0       50.000000   6709.982   469792.0   6700214.0  353400.000000   965866.0
# 1      350.000000      0.000   245416.0   3646660.0  359780.000000   664504.0
# 2        4.000000      0.000   409564.0   2673338.0  130640.000000   262032.0
# 3      107.933333      0.000       44.0     21614.0  253274.666667     5670.0
# 4        2.000000      0.000   347188.0   4289260.0  282560.000000   404740.0
# ...           ...        ...        ...         ...            ...        ...
# 59995   14.000000   1574.588  1218244.0  10845228.0  221620.000000  1608808.0
# 59996   66.645000   1574.588    68424.0    147638.0  163342.460000    13934.0
# 59997   66.671000   1603.238      144.0     43738.0  163508.610000    15876.0
# 59998   70.000000  57300.000   225724.0   6159728.0  332300.000000  1180714.0
# 59999    2.000000      0.000   254068.0   3076406.0  268280.000000   409798.0
#
#           bo_000     bk_000
# 0      283680.00  330760.00
# 1      189120.00  341420.00
# 2      106380.00  137160.00
# 3       75648.00  246502.00
# 4       59100.00  306780.00
# ...          ...        ...
# 59995  152420.00  263320.00
# 59996   99662.58  160036.47
# 59997   99843.76  160040.61
# 59998  362360.00  302700.00
# 59999       0.00  191320.00
#
# [60000 rows x 59 columns]

# %%
df=df.drop('Unnamed: 0', axis=1)
df
# Out:
#           bj_000      ci_000    ay_002    ag_001         ay_005    ag_002  \
# 0       799478.0  5245752.00  2198.356   828.488  469014.000000  8571.650
# 1       392208.0  2291079.36     0.000     0.000   71510.000000     0.000
# 2       139730.0  2322692.16     0.000     0.000  202696.500000     0.000
# 3         3090.0     2135.04     0.000     0.000  181363.333333     0.000
# 4       399410.0  3565684.80     0.000     0.000  372236.000000     0.000
# ...          ...         ...       ...       ...            ...       ...
# 59995   678792.0  8289544.32  5757.992  1061.362   45114.000000  6691.674
# 59996     9572.0   123344.64  5757.992  1061.362    4610.000000  6691.674
# 59997     6224.0     7518.72  5757.992  1061.362  137882.849000  6691.674
# 59998  1032454.0  4776505.92  5757.992  1061.362  119742.000000  6691.558
# 59999   260378.0  2480113.92     0.000     0.000  105702.000000     0.000
#
#              am_0        ay_006    ee_003     ay_001  ...    cs_002  \
# 0      107278.622  4.239660e+06  493384.0   3798.284  ...  267998.0
# 1           0.000  7.727200e+05  178064.0      0.000  ...  164860.0
# 2         486.750  8.704560e+05  159812.0      0.000  ...   56362.0
# 3        3894.000  1.781648e+06      46.0      0.000  ...      24.0
# 4         811.250  2.128914e+06  229790.0      0.000  ...   80950.0
# ...           ...           ...       ...        ...  ...       ...
# 59995    2114.000  2.533260e+06  566884.0  13500.280  ...  138036.0
# 59996   76769.085  9.912000e+04    6760.0  13500.280  ...    3606.0
# 59997   76768.344  1.062160e+06     386.0  13500.280  ...      72.0
# 59998   76758.797  4.445146e+06  222654.0  13500.280  ...  333922.0
# 59999       0.000  1.433988e+06  183200.0      0.000  ...   81228.0
#
#           aq_000      bf_000     at_000     ee_005      bb_000         bl_000  \
# 0      1132040.0   50.000000   6709.982   469792.0   6700214.0  353400.000000
# 1       338544.0  350.000000      0.000   245416.0   3646660.0  359780.000000
# 2       153698.0    4.000000      0.000   409564.0   2673338.0  130640.000000
# 3         1014.0  107.933333      0.000       44.0     21614.0  253274.666667
# 4       551022.0    2.000000      0.000   347188.0   4289260.0  282560.000000
# ...          ...         ...        ...        ...         ...            ...
# 59995   776370.0   14.000000   1574.588  1218244.0  10845228.0  221620.000000
# 59996    11622.0   66.645000   1574.588    68424.0    147638.0  163342.460000
# 59997      874.0   66.671000   1603.238      144.0     43738.0  163508.610000
# 59998  1214970.0   70.000000  57300.000   225724.0   6159728.0  332300.000000
# 59999   334864.0    2.000000      0.000   254068.0   3076406.0  268280.000000
#
#           ee_000     bo_000     bk_000
# 0       965866.0  283680.00  330760.00
# 1       664504.0  189120.00  341420.00
# 2       262032.0  106380.00  137160.00
# 3         5670.0   75648.00  246502.00
# 4       404740.0   59100.00  306780.00
# ...          ...        ...        ...
# 59995  1608808.0  152420.00  263320.00
# 59996    13934.0   99662.58  160036.47
# 59997    15876.0   99843.76  160040.61
# 59998  1180714.0  362360.00  302700.00
# 59999   409798.0       0.00  191320.00
#
# [60000 rows x 58 columns]

# %%
#feature_drift_percentage 
# find the percentage change with the previous row
df2= df
df2=df2.pct_change()
df2=df2.rename(columns=
{              
'bj_000': 'bj_000_pct_change', 
'ci_000': 'ci_000_pct_change', 
'ay_002': 'ay_002_pct_change', 
'ag_001': 'ag_001_pct_change', 
'ay_005': 'ay_005_pct_change', 
'ag_002': 'ag_002_pct_change', 
'am_0': 'am_0_pct_change', 
'ay_006': 'ay_006_pct_change', 
'ee_003': 'ee_003_pct_change', 
'ay_001': 'ay_001_pct_change', 
'cl_000': 'cl_000_pct_change',  
'cd_000': 'cd_000_pct_change', 
'ee_007': 'ee_007_pct_change',    
'ba_004': 'ba_004_pct_change',  
'ay_008': 'ay_008_pct_change',  
'by_000': 'by_000_pct_change',   
'al_000': 'al_000_pct_change',   
'cn_007': 'cn_007_pct_change',    
'ay_009': 'ay_009_pct_change',   
'az_003': 'az_003_pct_change',   
'ay_003': 'ay_003_pct_change',   
'dg_000': 'dg_000_pct_change',    
'ay_000': 'ay_000_pct_change',  
'dc_000': 'dc_000_pct_change',    
'az_002': 'az_002_pct_change',    
'dx_000': 'dx_000_pct_change',   
'cs_004': 'cs_004_pct_change',   
'eb_000': 'eb_000_pct_change',  
'cs_009': 'cs_009_pct_change',   
'ee_008': 'ee_008_pct_change',  
'ag_006': 'ag_006_pct_change',    
'cn_002': 'cn_002_pct_change',  
'cs_005': 'cs_005_pct_change',   
'br_000': 'br_000_pct_change',  
'cj_000': 'cj_000_pct_change',   
'bi_000': 'bi_000_pct_change',  
'do_000': 'do_000_pct_change',  
'di_000': 'di_000_pct_change', 
'an_000': 'an_000_pct_change',   
'du_000': 'du_000_pct_change',  
'ao_000': 'ao_000_pct_change',   
'cm_000': 'cm_000_pct_change', 
'cs_006': 'cs_006_pct_change',  
'ee_001': 'ee_001_pct_change', 
'ba_002': 'ba_002_pct_change',  
'ca_000': 'ca_000_pct_change', 
'be_000': 'be_000_pct_change', 
'ck_000': 'ck_000_pct_change', 
'cs_002': 'cs_002_pct_change',   
'aq_000': 'aq_000_pct_change', 
'bf_000': 'bf_000_pct_change',  
'at_000': 'at_000_pct_change', 
'ee_005': 'ee_005_pct_change', 
'bb_000': 'bb_000_pct_change', 
'bl_000': 'bl_000_pct_change', 
'ee_000': 'ee_000_pct_change', 
'bo_000': 'bo_000_pct_change', 
'bk_000': 'bk_000_pct_change'})
df2
# Out:
#        bj_000_pct_change  ci_000_pct_change  ay_002_pct_change  \
# 0                    NaN                NaN                NaN
# 1              -0.509420          -0.563251               -1.0
# 2              -0.643735           0.013798                NaN
# 3              -0.977886          -0.999081                NaN
# 4             128.258900        1669.078687                NaN
# ...                  ...                ...                ...
# 59995         478.372881        2991.010395                0.0
# 59996          -0.985898          -0.985120                0.0
# 59997          -0.349770          -0.939043                0.0
# 59998         164.882712         634.281793                0.0
# 59999          -0.747807          -0.480768               -1.0
#
#        ag_001_pct_change  ay_005_pct_change  ag_002_pct_change  \
# 0                    NaN                NaN                NaN
# 1                   -1.0          -0.847531          -1.000000
# 2                    NaN           1.834520                NaN
# 3                    NaN          -0.105247                NaN
# 4                    NaN           1.052433                NaN
# ...                  ...                ...                ...
# 59995                0.0          -0.672751           0.000000
# 59996                0.0          -0.897814           0.000000
# 59997                0.0          28.909512           0.000000
# 59998                0.0          -0.131567          -0.000017
# 59999               -1.0          -0.117252          -1.000000
#
#        am_0_pct_change  ay_006_pct_change  ee_003_pct_change  \
# 0                  NaN                NaN                NaN
# 1            -1.000000          -0.817740          -0.639097
# 2                  inf           0.126483          -0.102502
# 3             7.000000           1.046798          -0.999712
# 4            -0.791667           0.194913        4994.434783
# ...                ...                ...                ...
# 59995        -0.972463           1.390626        5783.530612
# 59996        35.314610          -0.960873          -0.988075
# 59997        -0.000010           9.715904          -0.942899
# 59998        -0.000124           3.185004         575.823834
# 59999        -1.000000          -0.677404          -0.177199
#
#        ay_001_pct_change  ...  cs_002_pct_change  aq_000_pct_change  \
# 0                    NaN  ...                NaN                NaN
# 1                   -1.0  ...          -0.384846          -0.700943
# 2                    NaN  ...          -0.658122          -0.546003
# 3                    NaN  ...          -0.999574          -0.993403
# 4                    NaN  ...        3371.916667         542.414201
# ...                  ...  ...                ...                ...
# 59995                0.0  ...       17253.500000        1117.688761
# 59996                0.0  ...          -0.973876          -0.985030
# 59997                0.0  ...          -0.980033          -0.924798
# 59998                0.0  ...        4636.805556        1389.125858
# 59999               -1.0  ...          -0.756746          -0.724385
#
#        bf_000_pct_change  at_000_pct_change  ee_005_pct_change  \
# 0                    NaN                NaN                NaN
# 1               6.000000          -1.000000          -0.477607
# 2              -0.988571                NaN           0.668856
# 3              25.983333                NaN          -0.999893
# 4              -0.981470                NaN        7889.636364
# ...                  ...                ...                ...
# 59995          -0.789979           0.000000        7337.819277
# 59996           3.760357           0.000000          -0.943834
# 59997           0.000390           0.018195          -0.997895
# 59998           0.049932          34.740171        1566.527778
# 59999          -0.971429          -1.000000           0.125569
#
#        bb_000_pct_change  bl_000_pct_change  ee_000_pct_change  \
# 0                    NaN                NaN                NaN
# 1              -0.455740           0.018053          -0.312012
# 2              -0.266908          -0.636889          -0.605673
# 3              -0.991915           0.938722          -0.978361
# 4             197.448228           0.115627          70.382716
# ...                  ...                ...                ...
# 59995         188.595259           0.352273         254.447444
# 59996          -0.986387          -0.262962          -0.991339
# 59997          -0.703748           0.001017           0.139371
# 59998         139.832411           1.032309          73.371000
# 59999          -0.500561          -0.192657          -0.652924
#
#        bo_000_pct_change  bk_000_pct_change
# 0                    NaN                NaN
# 1              -0.333333           0.032229
# 2              -0.437500          -0.598266
# 3              -0.288889           0.797186
# 4              -0.218750           0.244534
# ...                  ...                ...
# 59995           0.520525           0.644216
# 59996          -0.346132          -0.392236
# 59997           0.001818           0.000026
# 59998           2.629270           0.891395
# 59999          -1.000000          -0.367955
#
# [60000 rows x 58 columns]

# %%
df_new=df.join(df2)
df_new
# Out:
#           bj_000      ci_000    ay_002    ag_001         ay_005    ag_002  \
# 0       799478.0  5245752.00  2198.356   828.488  469014.000000  8571.650
# 1       392208.0  2291079.36     0.000     0.000   71510.000000     0.000
# 2       139730.0  2322692.16     0.000     0.000  202696.500000     0.000
# 3         3090.0     2135.04     0.000     0.000  181363.333333     0.000
# 4       399410.0  3565684.80     0.000     0.000  372236.000000     0.000
# ...          ...         ...       ...       ...            ...       ...
# 59995   678792.0  8289544.32  5757.992  1061.362   45114.000000  6691.674
# 59996     9572.0   123344.64  5757.992  1061.362    4610.000000  6691.674
# 59997     6224.0     7518.72  5757.992  1061.362  137882.849000  6691.674
# 59998  1032454.0  4776505.92  5757.992  1061.362  119742.000000  6691.558
# 59999   260378.0  2480113.92     0.000     0.000  105702.000000     0.000
#
#              am_0        ay_006    ee_003     ay_001  ...  cs_002_pct_change  \
# 0      107278.622  4.239660e+06  493384.0   3798.284  ...                NaN
# 1           0.000  7.727200e+05  178064.0      0.000  ...          -0.384846
# 2         486.750  8.704560e+05  159812.0      0.000  ...          -0.658122
# 3        3894.000  1.781648e+06      46.0      0.000  ...          -0.999574
# 4         811.250  2.128914e+06  229790.0      0.000  ...        3371.916667
# ...           ...           ...       ...        ...  ...                ...
# 59995    2114.000  2.533260e+06  566884.0  13500.280  ...       17253.500000
# 59996   76769.085  9.912000e+04    6760.0  13500.280  ...          -0.973876
# 59997   76768.344  1.062160e+06     386.0  13500.280  ...          -0.980033
# 59998   76758.797  4.445146e+06  222654.0  13500.280  ...        4636.805556
# 59999       0.000  1.433988e+06  183200.0      0.000  ...          -0.756746
#
#        aq_000_pct_change  bf_000_pct_change  at_000_pct_change  \
# 0                    NaN                NaN                NaN
# 1              -0.700943           6.000000          -1.000000
# 2              -0.546003          -0.988571                NaN
# 3              -0.993403          25.983333                NaN
# 4             542.414201          -0.981470                NaN
# ...                  ...                ...                ...
# 59995        1117.688761          -0.789979           0.000000
# 59996          -0.985030           3.760357           0.000000
# 59997          -0.924798           0.000390           0.018195
# 59998        1389.125858           0.049932          34.740171
# 59999          -0.724385          -0.971429          -1.000000
#
#        ee_005_pct_change  bb_000_pct_change  bl_000_pct_change  \
# 0                    NaN                NaN                NaN
# 1              -0.477607          -0.455740           0.018053
# 2               0.668856          -0.266908          -0.636889
# 3              -0.999893          -0.991915           0.938722
# 4            7889.636364         197.448228           0.115627
# ...                  ...                ...                ...
# 59995        7337.819277         188.595259           0.352273
# 59996          -0.943834          -0.986387          -0.262962
# 59997          -0.997895          -0.703748           0.001017
# 59998        1566.527778         139.832411           1.032309
# 59999           0.125569          -0.500561          -0.192657
#
#        ee_000_pct_change  bo_000_pct_change  bk_000_pct_change
# 0                    NaN                NaN                NaN
# 1              -0.312012          -0.333333           0.032229
# 2              -0.605673          -0.437500          -0.598266
# 3              -0.978361          -0.288889           0.797186
# 4              70.382716          -0.218750           0.244534
# ...                  ...                ...                ...
# 59995         254.447444           0.520525           0.644216
# 59996          -0.991339          -0.346132          -0.392236
# 59997           0.139371           0.001818           0.000026
# 59998          73.371000           2.629270           0.891395
# 59999          -0.652924          -1.000000          -0.367955
#
# [60000 rows x 116 columns]

# %%
#lag features
df_new['bj_000_lag'] = df_new['bj_000'].shift(1) 
df_new['ci_000_lag'] = df_new['ci_000'].shift(1) 
df_new['ay_002_lag'] = df_new['ay_002'].shift(1) 
df_new['ag_001_lag'] = df_new['ag_001'].shift(1) 
df_new['ay_005_lag'] = df_new['ay_005'].shift(1) 
df_new['ag_002_lag'] = df_new['ag_002'].shift(1) 
df_new['am_0_lag'] = df_new['am_0'].shift(1) 
df_new['ay_006_lag'] = df_new['ay_006'].shift(1) 
df_new['ee_003_lag'] = df_new['ee_003'].shift(1) 
df_new['ay_001_lag'] = df_new['ay_001'].shift(1) 
df_new['cl_000_lag'] = df_new['cl_000'].shift(1)  
df_new['cd_000_lag'] = df_new['cd_000'].shift(1) 
df_new['ee_007_lag'] = df_new['ee_007'].shift(1)    
df_new['ba_004_lag'] = df_new['ba_004'].shift(1)  
df_new['ay_008_lag'] = df_new['ay_008'].shift(1)  
df_new['by_000_lag'] = df_new['by_000'].shift(1)   
df_new['al_000_lag'] = df_new['al_000'].shift(1)   
df_new['cn_007_lag'] = df_new['cn_007'].shift(1)    
df_new['ay_009_lag'] = df_new['ay_009'].shift(1)   
df_new['az_003_lag'] = df_new['az_003'].shift(1)   
df_new['ay_003_lag'] = df_new['ay_003'].shift(1)   
df_new['dg_000_lag'] = df_new['dg_000'].shift(1)    
df_new['ay_000_lag'] = df_new['ay_000'].shift(1)  
df_new['dc_000_lag'] = df_new['dc_000'].shift(1)    
df_new['az_002_lag'] = df_new['az_002'].shift(1)    
df_new['dx_000_lag'] = df_new['dx_000'].shift(1)   
df_new['cs_004_lag'] = df_new['cs_004'].shift(1)   
df_new['eb_000_lag'] = df_new['eb_000'].shift(1)  
df_new['cs_009_lag'] = df_new['cs_009'].shift(1)   
df_new['ee_008_lag'] = df_new['ee_008'].shift(1)  
df_new['ag_006_lag'] = df_new['ag_006'].shift(1)    
df_new['cn_002_lag'] = df_new['cn_002'].shift(1)  
df_new['cs_005_lag'] = df_new['cs_005'].shift(1)   
df_new['br_000_lag'] = df_new['br_000'].shift(1)  
df_new['cj_000_lag'] = df_new['cj_000'].shift(1)   
df_new['bi_000_lag'] = df_new['bi_000'].shift(1)  
df_new['do_000_lag'] = df_new['do_000'].shift(1)  
df_new['di_000_lag'] = df_new['di_000'].shift(1) 
df_new['an_000_lag'] = df_new['an_000'].shift(1)   
df_new['du_000_lag'] = df_new['du_000'].shift(1)  
df_new['ao_000_lag'] = df_new['ao_000'].shift(1)   
df_new['cm_000_lag'] = df_new['cm_000'].shift(1) 
df_new['cs_006_lag'] = df_new['cs_006'].shift(1)  
df_new['ee_001_lag'] = df_new['ee_001'].shift(1) 
df_new['ba_002_lag'] = df_new['ba_002'].shift(1)  
df_new['ca_000_lag'] = df_new['ca_000'].shift(1) 
df_new['be_000_lag'] = df_new['be_000'].shift(1) 
df_new['ck_000_lag'] = df_new['ck_000'].shift(1) 
df_new['cs_002_lag'] = df_new['cs_002'].shift(1)   
df_new['aq_000_lag'] = df_new['aq_000'].shift(1) 
df_new['bf_000_lag'] = df_new['bf_000'].shift(1)  
df_new['at_000_lag'] = df_new['at_000'].shift(1) 
df_new['ee_005_lag'] = df_new['ee_005'].shift(1) 
df_new['bb_000_lag'] = df_new['bb_000'].shift(1) 
df_new['bl_000_lag'] = df_new['bl_000'].shift(1) 
df_new['ee_000_lag'] = df_new['ee_000'].shift(1) 
df_new['bo_000_lag'] = df_new['bo_000'].shift(1) 
df_new['bk_000_lag'] = df_new['bk_000'].shift(1) 
df_new
# Out:
#           bj_000      ci_000    ay_002    ag_001         ay_005    ag_002  \
# 0       799478.0  5245752.00  2198.356   828.488  469014.000000  8571.650
# 1       392208.0  2291079.36     0.000     0.000   71510.000000     0.000
# 2       139730.0  2322692.16     0.000     0.000  202696.500000     0.000
# 3         3090.0     2135.04     0.000     0.000  181363.333333     0.000
# 4       399410.0  3565684.80     0.000     0.000  372236.000000     0.000
# ...          ...         ...       ...       ...            ...       ...
# 59995   678792.0  8289544.32  5757.992  1061.362   45114.000000  6691.674
# 59996     9572.0   123344.64  5757.992  1061.362    4610.000000  6691.674
# 59997     6224.0     7518.72  5757.992  1061.362  137882.849000  6691.674
# 59998  1032454.0  4776505.92  5757.992  1061.362  119742.000000  6691.558
# 59999   260378.0  2480113.92     0.000     0.000  105702.000000     0.000
#
#              am_0        ay_006    ee_003     ay_001  ...  cs_002_lag  \
# 0      107278.622  4.239660e+06  493384.0   3798.284  ...         NaN
# 1           0.000  7.727200e+05  178064.0      0.000  ...    267998.0
# 2         486.750  8.704560e+05  159812.0      0.000  ...    164860.0
# 3        3894.000  1.781648e+06      46.0      0.000  ...     56362.0
# 4         811.250  2.128914e+06  229790.0      0.000  ...        24.0
# ...           ...           ...       ...        ...  ...         ...
# 59995    2114.000  2.533260e+06  566884.0  13500.280  ...         8.0
# 59996   76769.085  9.912000e+04    6760.0  13500.280  ...    138036.0
# 59997   76768.344  1.062160e+06     386.0  13500.280  ...      3606.0
# 59998   76758.797  4.445146e+06  222654.0  13500.280  ...        72.0
# 59999       0.000  1.433988e+06  183200.0      0.000  ...    333922.0
#
#        aq_000_lag  bf_000_lag  at_000_lag  ee_005_lag  bb_000_lag  \
# 0             NaN         NaN         NaN         NaN         NaN
# 1       1132040.0   50.000000    6709.982    469792.0   6700214.0
# 2        338544.0  350.000000       0.000    245416.0   3646660.0
# 3        153698.0    4.000000       0.000    409564.0   2673338.0
# 4          1014.0  107.933333       0.000        44.0     21614.0
# ...           ...         ...         ...         ...         ...
# 59995       694.0   66.660000    1574.588       166.0     57202.0
# 59996    776370.0   14.000000    1574.588   1218244.0  10845228.0
# 59997     11622.0   66.645000    1574.588     68424.0    147638.0
# 59998       874.0   66.671000    1603.238       144.0     43738.0
# 59999   1214970.0   70.000000   57300.000    225724.0   6159728.0
#
#           bl_000_lag  ee_000_lag  bo_000_lag  bk_000_lag
# 0                NaN         NaN         NaN         NaN
# 1      353400.000000    965866.0   283680.00   330760.00
# 2      359780.000000    664504.0   189120.00   341420.00
# 3      130640.000000    262032.0   106380.00   137160.00
# 4      253274.666667      5670.0    75648.00   246502.00
# ...              ...         ...         ...         ...
# 59995  163887.000000      6298.0   100241.72   160149.30
# 59996  221620.000000   1608808.0   152420.00   263320.00
# 59997  163342.460000     13934.0    99662.58   160036.47
# 59998  163508.610000     15876.0    99843.76   160040.61
# 59999  332300.000000   1180714.0   362360.00   302700.00
#
# [60000 rows x 174 columns]

# %%
#rolling window
df_new['bj_000_rolling_window'] = df_new['bj_000'].rolling(window=7).mean()
df_new['ci_000_rolling_window'] = df_new['ci_000'].rolling(window=7).mean()
df_new['ay_002_rolling_window'] = df_new['ay_002'].rolling(window=7).mean()
df_new['ag_001_rolling_window'] = df_new['ag_001'].rolling(window=7).mean()
df_new['ay_005_rolling_window'] = df_new['ay_005'].rolling(window=7).mean()
df_new['ag_002_rolling_window'] = df_new['ag_002'].rolling(window=7).mean()
df_new['am_0_rolling_window'] = df_new['am_0'].rolling(window=7).mean()
df_new['ay_006_rolling_window'] = df_new['ay_006'].rolling(window=7).mean()
df_new['ee_003_rolling_window'] = df_new['ee_003'].rolling(window=7).mean()
df_new['ay_001_rolling_window'] = df_new['ay_001'].rolling(window=7).mean()
df_new['cl_000_rolling_window'] = df_new['cl_000'].rolling(window=7).mean() 
df_new['cd_000_rolling_window'] = df_new['cd_000'].rolling(window=7).mean()
df_new['ee_007_rolling_window'] = df_new['ee_007'].rolling(window=7).mean()   
df_new['ba_004_rolling_window'] = df_new['ba_004'].rolling(window=7).mean() 
df_new['ay_008_rolling_window'] = df_new['ay_008'].rolling(window=7).mean() 
df_new['by_000_rolling_window'] = df_new['by_000'].rolling(window=7).mean()  
df_new['al_000_rolling_window'] = df_new['al_000'].rolling(window=7).mean()  
df_new['cn_007_rolling_window'] = df_new['cn_007'].rolling(window=7).mean()   
df_new['ay_009_rolling_window'] = df_new['ay_009'].rolling(window=7).mean()  
df_new['az_003_rolling_window'] = df_new['az_003'].rolling(window=7).mean()  
df_new['ay_003_rolling_window'] = df_new['ay_003'].rolling(window=7).mean()  
df_new['dg_000_rolling_window'] = df_new['dg_000'].rolling(window=7).mean()   
df_new['ay_000_rolling_window'] = df_new['ay_000'].rolling(window=7).mean() 
df_new['dc_000_rolling_window'] = df_new['dc_000'].rolling(window=7).mean()   
df_new['az_002_rolling_window'] = df_new['az_002'].rolling(window=7).mean()   
df_new['dx_000_rolling_window'] = df_new['dx_000'].rolling(window=7).mean()  
df_new['cs_004_rolling_window'] = df_new['cs_004'].rolling(window=7).mean()  
df_new['eb_000_rolling_window'] = df_new['eb_000'].rolling(window=7).mean() 
df_new['cs_009_rolling_window'] = df_new['cs_009'].rolling(window=7).mean()  
df_new['ee_008_rolling_window'] = df_new['ee_008'].rolling(window=7).mean() 
df_new['ag_006_rolling_window'] = df_new['ag_006'].rolling(window=7).mean()   
df_new['cn_002_rolling_window'] = df_new['cn_002'].rolling(window=7).mean() 
df_new['cs_005_rolling_window'] = df_new['cs_005'].rolling(window=7).mean()  
df_new['br_000_rolling_window'] = df_new['br_000'].rolling(window=7).mean() 
df_new['cj_000_rolling_window'] = df_new['cj_000'].rolling(window=7).mean()  
df_new['bi_000_rolling_window'] = df_new['bi_000'].rolling(window=7).mean() 
df_new['do_000_rolling_window'] = df_new['do_000'].rolling(window=7).mean() 
df_new['di_000_rolling_window'] = df_new['di_000'].rolling(window=7).mean()
df_new['an_000_rolling_window'] = df_new['an_000'].rolling(window=7).mean()  
df_new['du_000_rolling_window'] = df_new['du_000'].rolling(window=7).mean() 
df_new['ao_000_rolling_window'] = df_new['ao_000'].rolling(window=7).mean()  
df_new['cm_000_rolling_window'] = df_new['cm_000'].rolling(window=7).mean()
df_new['cs_006_rolling_window'] = df_new['cs_006'].rolling(window=7).mean() 
df_new['ee_001_rolling_window'] = df_new['ee_001'].rolling(window=7).mean()
df_new['ba_002_rolling_window'] = df_new['ba_002'].rolling(window=7).mean() 
df_new['ca_000_rolling_window'] = df_new['ca_000'].rolling(window=7).mean()
df_new['be_000_rolling_window'] = df_new['be_000'].rolling(window=7).mean()
df_new['ck_000_rolling_window'] = df_new['ck_000'].rolling(window=7).mean()
df_new['cs_002_rolling_window'] = df_new['cs_002'].rolling(window=7).mean()  
df_new['aq_000_rolling_window'] = df_new['aq_000'].rolling(window=7).mean()
df_new['bf_000_rolling_window'] = df_new['bf_000'].rolling(window=7).mean() 
df_new['at_000_rolling_window'] = df_new['at_000'].rolling(window=7).mean()
df_new['ee_005_rolling_window'] = df_new['ee_005'].rolling(window=7).mean()
df_new['bb_000_rolling_window'] = df_new['bb_000'].rolling(window=7).mean()
df_new['bl_000_rolling_window'] = df_new['bl_000'].rolling(window=7).mean()
df_new['ee_000_rolling_window'] = df_new['ee_000'].rolling(window=7).mean()
df_new['bo_000_rolling_window'] = df_new['bo_000'].rolling(window=7).mean()
df_new['bk_000_rolling_window'] = df_new['bk_000'].rolling(window=7).mean()
df_new
# Out:
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/3798249284.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ao_000_rolling_window'] = df_new['ao_000'].rolling(window=7).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/3798249284.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cm_000_rolling_window'] = df_new['cm_000'].rolling(window=7).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/3798249284.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_006_rolling_window'] = df_new['cs_006'].rolling(window=7).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/3798249284.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_001_rolling_window'] = df_new['ee_001'].rolling(window=7).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/3798249284.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ba_002_rolling_window'] = df_new['ba_002'].rolling(window=7).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/3798249284.py:47: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ca_000_rolling_window'] = df_new['ca_000'].rolling(window=7).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/3798249284.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['be_000_rolling_window'] = df_new['be_000'].rolling(window=7).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/3798249284.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ck_000_rolling_window'] = df_new['ck_000'].rolling(window=7).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/3798249284.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_002_rolling_window'] = df_new['cs_002'].rolling(window=7).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/3798249284.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['aq_000_rolling_window'] = df_new['aq_000'].rolling(window=7).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/3798249284.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bf_000_rolling_window'] = df_new['bf_000'].rolling(window=7).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/3798249284.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['at_000_rolling_window'] = df_new['at_000'].rolling(window=7).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/3798249284.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_005_rolling_window'] = df_new['ee_005'].rolling(window=7).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/3798249284.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bb_000_rolling_window'] = df_new['bb_000'].rolling(window=7).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/3798249284.py:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bl_000_rolling_window'] = df_new['bl_000'].rolling(window=7).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/3798249284.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_000_rolling_window'] = df_new['ee_000'].rolling(window=7).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/3798249284.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bo_000_rolling_window'] = df_new['bo_000'].rolling(window=7).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/3798249284.py:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bk_000_rolling_window'] = df_new['bk_000'].rolling(window=7).mean()
#           bj_000      ci_000    ay_002    ag_001         ay_005    ag_002  \
# 0       799478.0  5245752.00  2198.356   828.488  469014.000000  8571.650
# 1       392208.0  2291079.36     0.000     0.000   71510.000000     0.000
# 2       139730.0  2322692.16     0.000     0.000  202696.500000     0.000
# 3         3090.0     2135.04     0.000     0.000  181363.333333     0.000
# 4       399410.0  3565684.80     0.000     0.000  372236.000000     0.000
# ...          ...         ...       ...       ...            ...       ...
# 59995   678792.0  8289544.32  5757.992  1061.362   45114.000000  6691.674
# 59996     9572.0   123344.64  5757.992  1061.362    4610.000000  6691.674
# 59997     6224.0     7518.72  5757.992  1061.362  137882.849000  6691.674
# 59998  1032454.0  4776505.92  5757.992  1061.362  119742.000000  6691.558
# 59999   260378.0  2480113.92     0.000     0.000  105702.000000     0.000
#
#              am_0        ay_006    ee_003     ay_001  ...  \
# 0      107278.622  4.239660e+06  493384.0   3798.284  ...
# 1           0.000  7.727200e+05  178064.0      0.000  ...
# 2         486.750  8.704560e+05  159812.0      0.000  ...
# 3        3894.000  1.781648e+06      46.0      0.000  ...
# 4         811.250  2.128914e+06  229790.0      0.000  ...
# ...           ...           ...       ...        ...  ...
# 59995    2114.000  2.533260e+06  566884.0  13500.280  ...
# 59996   76769.085  9.912000e+04    6760.0  13500.280  ...
# 59997   76768.344  1.062160e+06     386.0  13500.280  ...
# 59998   76758.797  4.445146e+06  222654.0  13500.280  ...
# 59999       0.000  1.433988e+06  183200.0      0.000  ...
#
#        cs_002_rolling_window  aq_000_rolling_window  bf_000_rolling_window  \
# 0                        NaN                    NaN                    NaN
# 1                        NaN                    NaN                    NaN
# 2                        NaN                    NaN                    NaN
# 3                        NaN                    NaN                    NaN
# 4                        NaN                    NaN                    NaN
# ...                      ...                    ...                    ...
# 59995           47559.142857          334316.103429              45.238000
# 59996           41731.428571          272154.960571              53.044429
# 59997           27200.571429          210401.817714              59.140286
# 59998           67955.142857          343936.389143              59.616000
# 59999           79557.142857          391736.960571              50.377714
#
#        at_000_rolling_window  ee_005_rolling_window  bb_000_rolling_window  \
# 0                        NaN                    NaN                    NaN
# 1                        NaN                    NaN                    NaN
# 2                        NaN                    NaN                    NaN
# 3                        NaN                    NaN                    NaN
# 4                        NaN                    NaN                    NaN
# ...                      ...                    ...                    ...
# 59995            1435.895429          493692.018000           3.286736e+06
# 59996            1435.935571          426896.875143           2.694091e+06
# 59997            1440.025429          279026.589429           1.947148e+06
# 59998            9539.454000          269508.589429           2.469058e+06
# 59999            9314.512857          305796.589429           2.906176e+06
#
#        bl_000_rolling_window  ee_000_rolling_window  bo_000_rolling_window  \
# 0                        NaN                    NaN                    NaN
# 1                        NaN                    NaN                    NaN
# 2                        NaN                    NaN                    NaN
# 3                        NaN                    NaN                    NaN
# 4                        NaN                    NaN                    NaN
# ...                      ...                    ...                    ...
# 59995          183358.748571          419812.857143          108197.660000
# 59996          180830.528571          360180.571429          107988.077143
# 59997          183854.615714          272998.285714          107826.434286
# 59998          196248.901429          404722.857143          145167.111429
# 59999          211068.598571          462601.428571          130764.131429
#
#        bk_000_rolling_window
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 59995          183275.260000
# 59996          181266.184286
# 59997          182320.557143
# 59998          195237.700000
# 59999          199682.162857
#
# [60000 rows x 232 columns]

# %%
df_new['bj_000_expanding_window'] = df_new['bj_000'].expanding(2).mean()
df_new['ci_000_expanding_window'] = df_new['ci_000'].expanding(2).mean()
df_new['ay_002_expanding_window'] = df_new['ay_002'].expanding(2).mean()
df_new['ag_001_expanding_window'] = df_new['ag_001'].expanding(2).mean()
df_new['ay_005_expanding_window'] = df_new['ay_005'].expanding(2).mean()
df_new['ag_002_expanding_window'] = df_new['ag_002'].expanding(2).mean()
df_new['am_0_expanding_window'] = df_new['am_0'].expanding(2).mean()
df_new['ay_006_expanding_window'] = df_new['ay_006'].expanding(2).mean()
df_new['ee_003_expanding_window'] = df_new['ee_003'].expanding(2).mean()
df_new['ay_001_expanding_window'] = df_new['ay_001'].expanding(2).mean()
df_new['cl_000_expanding_window'] = df_new['cl_000'].expanding(2).mean()
df_new['cd_000_expanding_window'] = df_new['cd_000'].expanding(2).mean()
df_new['ee_007_expanding_window'] = df_new['ee_007'].expanding(2).mean()  
df_new['ba_004_expanding_window'] = df_new['ba_004'].expanding(2).mean()
df_new['ay_008_expanding_window'] = df_new['ay_008'].expanding(2).mean()
df_new['by_000_expanding_window'] = df_new['by_000'].expanding(2).mean() 
df_new['al_000_expanding_window'] = df_new['al_000'].expanding(2).mean() 
df_new['cn_007_expanding_window'] = df_new['cn_007'].expanding(2).mean()  
df_new['ay_009_expanding_window'] = df_new['ay_009'].expanding(2).mean() 
df_new['az_003_expanding_window'] = df_new['az_003'].expanding(2).mean() 
df_new['ay_003_expanding_window'] = df_new['ay_003'].expanding(2).mean() 
df_new['dg_000_expanding_window'] = df_new['dg_000'].expanding(2).mean()  
df_new['ay_000_expanding_window'] = df_new['ay_000'].expanding(2).mean()
df_new['dc_000_expanding_window'] = df_new['dc_000'].expanding(2).mean()  
df_new['az_002_expanding_window'] = df_new['az_002'].expanding(2).mean()  
df_new['dx_000_expanding_window'] = df_new['dx_000'].expanding(2).mean() 
df_new['cs_004_expanding_window'] = df_new['cs_004'].expanding(2).mean() 
df_new['eb_000_expanding_window'] = df_new['eb_000'].expanding(2).mean()
df_new['cs_009_expanding_window'] = df_new['cs_009'].expanding(2).mean() 
df_new['ee_008_expanding_window'] = df_new['ee_008'].expanding(2).mean()
df_new['ag_006_expanding_window'] = df_new['ag_006'].expanding(2).mean()  
df_new['cn_002_expanding_window'] = df_new['cn_002'].expanding(2).mean()
df_new['cs_005_expanding_window'] = df_new['cs_005'].expanding(2).mean() 
df_new['br_000_expanding_window'] = df_new['br_000'].expanding(2).mean()
df_new['cj_000_expanding_window'] = df_new['cj_000'].expanding(2).mean() 
df_new['bi_000_expanding_window'] = df_new['bi_000'].expanding(2).mean()
df_new['do_000_expanding_window'] = df_new['do_000'].expanding(2).mean()
df_new['di_000_expanding_window'] = df_new['di_000'].expanding(2).mean()
df_new['an_000_expanding_window'] = df_new['an_000'].expanding(2).mean() 
df_new['du_000_expanding_window'] = df_new['du_000'].expanding(2).mean()
df_new['ao_000_expanding_window'] = df_new['ao_000'].expanding(2).mean() 
df_new['cm_000_expanding_window'] = df_new['cm_000'].expanding(2).mean()
df_new['cs_006_expanding_window'] = df_new['cs_006'].expanding(2).mean()
df_new['ee_001_expanding_window'] = df_new['ee_001'].expanding(2).mean()
df_new['ba_002_expanding_window'] = df_new['ba_002'].expanding(2).mean()
df_new['ca_000_expanding_window'] = df_new['ca_000'].expanding(2).mean()
df_new['be_000_expanding_window'] = df_new['be_000'].expanding(2).mean()
df_new['ck_000_expanding_window'] = df_new['ck_000'].expanding(2).mean()
df_new['cs_002_expanding_window'] = df_new['cs_002'].expanding(2).mean() 
df_new['aq_000_expanding_window'] = df_new['aq_000'].expanding(2).mean()
df_new['bf_000_expanding_window'] = df_new['bf_000'].expanding(2).mean()
df_new['at_000_expanding_window'] = df_new['at_000'].expanding(2).mean()
df_new['ee_005_expanding_window'] = df_new['ee_005'].expanding(2).mean()
df_new['bb_000_expanding_window'] = df_new['bb_000'].expanding(2).mean()
df_new['bl_000_expanding_window'] = df_new['bl_000'].expanding(2).mean()
df_new['ee_000_expanding_window'] = df_new['ee_000'].expanding(2).mean()
df_new['bo_000_expanding_window'] = df_new['bo_000'].expanding(2).mean()
df_new['bk_000_expanding_window'] = df_new['bk_000'].expanding(2).mean()
df_new
# Out:
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bj_000_expanding_window'] = df_new['bj_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ci_000_expanding_window'] = df_new['ci_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_002_expanding_window'] = df_new['ay_002'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ag_001_expanding_window'] = df_new['ag_001'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_005_expanding_window'] = df_new['ay_005'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ag_002_expanding_window'] = df_new['ag_002'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['am_0_expanding_window'] = df_new['am_0'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_006_expanding_window'] = df_new['ay_006'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_003_expanding_window'] = df_new['ee_003'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_001_expanding_window'] = df_new['ay_001'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cl_000_expanding_window'] = df_new['cl_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cd_000_expanding_window'] = df_new['cd_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_007_expanding_window'] = df_new['ee_007'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ba_004_expanding_window'] = df_new['ba_004'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_008_expanding_window'] = df_new['ay_008'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['by_000_expanding_window'] = df_new['by_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['al_000_expanding_window'] = df_new['al_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cn_007_expanding_window'] = df_new['cn_007'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_009_expanding_window'] = df_new['ay_009'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['az_003_expanding_window'] = df_new['az_003'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_003_expanding_window'] = df_new['ay_003'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['dg_000_expanding_window'] = df_new['dg_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_000_expanding_window'] = df_new['ay_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['dc_000_expanding_window'] = df_new['dc_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['az_002_expanding_window'] = df_new['az_002'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['dx_000_expanding_window'] = df_new['dx_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_004_expanding_window'] = df_new['cs_004'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['eb_000_expanding_window'] = df_new['eb_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_009_expanding_window'] = df_new['cs_009'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_008_expanding_window'] = df_new['ee_008'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ag_006_expanding_window'] = df_new['ag_006'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cn_002_expanding_window'] = df_new['cn_002'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_005_expanding_window'] = df_new['cs_005'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['br_000_expanding_window'] = df_new['br_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cj_000_expanding_window'] = df_new['cj_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bi_000_expanding_window'] = df_new['bi_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['do_000_expanding_window'] = df_new['do_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:38: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['di_000_expanding_window'] = df_new['di_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['an_000_expanding_window'] = df_new['an_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['du_000_expanding_window'] = df_new['du_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:41: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ao_000_expanding_window'] = df_new['ao_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cm_000_expanding_window'] = df_new['cm_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_006_expanding_window'] = df_new['cs_006'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_001_expanding_window'] = df_new['ee_001'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ba_002_expanding_window'] = df_new['ba_002'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ca_000_expanding_window'] = df_new['ca_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:47: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['be_000_expanding_window'] = df_new['be_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ck_000_expanding_window'] = df_new['ck_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_002_expanding_window'] = df_new['cs_002'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['aq_000_expanding_window'] = df_new['aq_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bf_000_expanding_window'] = df_new['bf_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['at_000_expanding_window'] = df_new['at_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_005_expanding_window'] = df_new['ee_005'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bb_000_expanding_window'] = df_new['bb_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bl_000_expanding_window'] = df_new['bl_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_000_expanding_window'] = df_new['ee_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bo_000_expanding_window'] = df_new['bo_000'].expanding(2).mean()
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/120244024.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bk_000_expanding_window'] = df_new['bk_000'].expanding(2).mean()
#           bj_000      ci_000    ay_002    ag_001         ay_005    ag_002  \
# 0       799478.0  5245752.00  2198.356   828.488  469014.000000  8571.650
# 1       392208.0  2291079.36     0.000     0.000   71510.000000     0.000
# 2       139730.0  2322692.16     0.000     0.000  202696.500000     0.000
# 3         3090.0     2135.04     0.000     0.000  181363.333333     0.000
# 4       399410.0  3565684.80     0.000     0.000  372236.000000     0.000
# ...          ...         ...       ...       ...            ...       ...
# 59995   678792.0  8289544.32  5757.992  1061.362   45114.000000  6691.674
# 59996     9572.0   123344.64  5757.992  1061.362    4610.000000  6691.674
# 59997     6224.0     7518.72  5757.992  1061.362  137882.849000  6691.674
# 59998  1032454.0  4776505.92  5757.992  1061.362  119742.000000  6691.558
# 59999   260378.0  2480113.92     0.000     0.000  105702.000000     0.000
#
#              am_0        ay_006    ee_003     ay_001  ...  \
# 0      107278.622  4.239660e+06  493384.0   3798.284  ...
# 1           0.000  7.727200e+05  178064.0      0.000  ...
# 2         486.750  8.704560e+05  159812.0      0.000  ...
# 3        3894.000  1.781648e+06      46.0      0.000  ...
# 4         811.250  2.128914e+06  229790.0      0.000  ...
# ...           ...           ...       ...        ...  ...
# 59995    2114.000  2.533260e+06  566884.0  13500.280  ...
# 59996   76769.085  9.912000e+04    6760.0  13500.280  ...
# 59997   76768.344  1.062160e+06     386.0  13500.280  ...
# 59998   76758.797  4.445146e+06  222654.0  13500.280  ...
# 59999       0.000  1.433988e+06  183200.0      0.000  ...
#
#        cs_002_expanding_window  aq_000_expanding_window  \
# 0                          NaN                      NaN
# 1                216429.000000            735292.000000
# 2                163073.333333            541427.333333
# 3                122311.000000            406324.000000
# 4                114038.800000            435263.600000
# ...                        ...                      ...
# 59995            243395.597698            444036.331479
# 59996            243391.601005            444029.124213
# 59997            243387.545543            444021.738048
# 59998            243389.054476            444034.587400
# 59999            243386.351792            444032.767890
#
#        bf_000_expanding_window  at_000_expanding_window  \
# 0                          NaN                      NaN
# 1                   200.000000              3354.991000
# 2                   134.666667              2236.660667
# 3                   127.983333              1677.495500
# 4                   102.786667              1341.996400
# ...                        ...                      ...
# 59995               105.041843              9552.294642
# 59996               105.041203              9552.161673
# 59997               105.040564              9552.029187
# 59998               105.039980              9552.824999
# 59999               105.038263              9552.665786
#
#        ee_005_expanding_window  bb_000_expanding_window  \
# 0                          NaN                      NaN
# 1                357604.000000             5.173437e+06
# 2                374924.000000             4.340071e+06
# 3                281204.000000             3.260456e+06
# 4                294400.800000             3.466217e+06
# ...                        ...                      ...
# 59995            412203.343674             4.533945e+06
# 59996            412197.613732             4.533872e+06
# 59997            412190.745943             4.533797e+06
# 59998            412187.638112             4.533824e+06
# 59999            412185.002785             4.533800e+06
#
#        bl_000_expanding_window  ee_000_expanding_window  \
# 0                          NaN                      NaN
# 1                356590.000000            815185.000000
# 2                281273.333333            630800.666667
# 3                274273.666667            474518.000000
# 4                275930.933333            460562.400000
# ...                        ...                      ...
# 59995            257932.867515            746481.130175
# 59996            257931.290929            746468.920446
# 59997            257929.717166            746456.743491
# 59998            257930.956691            746463.981233
# 59999            257931.129175            746458.370133
#
#        bo_000_expanding_window  bk_000_expanding_window
# 0                          NaN                      NaN
# 1                236400.000000            336090.000000
# 2                193060.000000            269780.000000
# 3                163707.000000            263960.500000
# 4                142785.600000            272524.400000
# ...                        ...                      ...
# 59995            210080.179798            240518.741691
# 59996            210078.339412            240517.400253
# 59997            210076.502108            240516.058929
# 59998            210079.040209            240517.095345
# 59999            210075.538891            240516.275393
#
# [60000 rows x 290 columns]

# %%
df_new.to_csv('APS_augmented_stage1.csv')

# %%
#Convolve
df_new['bj_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.bj_000.to_numpy())
df_new['ci_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ci_000.to_numpy())
df_new['ay_002_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ay_002.to_numpy())
df_new['ag_001_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ag_001.to_numpy())
df_new['ay_005_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ay_005.to_numpy())
df_new['ag_002_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ag_002.to_numpy())
df_new['am_0_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.am_0.to_numpy())
df_new['ay_006_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ay_006.to_numpy())
df_new['ee_003_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ee_003.to_numpy())
df_new['ay_001_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ay_001.to_numpy())
df_new['cl_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.cl_000.to_numpy())
df_new['cd_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.cd_000.to_numpy())
df_new['ee_007_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ee_007.to_numpy())  
df_new['ba_004_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ba_004.to_numpy())
df_new['ay_008_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ay_008.to_numpy())
df_new['by_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.by_000.to_numpy()) 
df_new['al_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.al_000.to_numpy()) 
df_new['cn_007_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.cn_007.to_numpy())  
df_new['ay_009_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ay_009.to_numpy()) 
df_new['az_003_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.az_003.to_numpy()) 
df_new['ay_003_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ay_003.to_numpy()) 
df_new['dg_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.dg_000.to_numpy())  
df_new['ay_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ay_000.to_numpy())
df_new['dc_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.dc_000.to_numpy())  
df_new['az_002_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.az_002.to_numpy())  
df_new['dx_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.dx_000.to_numpy()) 
df_new['cs_004_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.cs_004.to_numpy()) 
df_new['eb_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.eb_000.to_numpy())
df_new['cs_009_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.cs_009.to_numpy()) 
df_new['ee_008_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ee_008.to_numpy())
df_new['ag_006_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ag_006.to_numpy())  
df_new['cn_002_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.cn_002.to_numpy())
df_new['cs_005_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.cs_005.to_numpy()) 
df_new['br_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.br_000.to_numpy())
df_new['cj_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.cj_000.to_numpy()) 
df_new['bi_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.bi_000.to_numpy())
df_new['do_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.do_000.to_numpy())
df_new['di_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.di_000.to_numpy())
df_new['an_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.an_000.to_numpy()) 
df_new['du_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.du_000.to_numpy())
df_new['ao_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ao_000.to_numpy()) 
df_new['cm_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.cm_000.to_numpy())
df_new['cs_006_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.cs_006.to_numpy())
df_new['ee_001_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ee_001.to_numpy())
df_new['ba_002_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ba_002.to_numpy())
df_new['ca_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ca_000.to_numpy())
df_new['be_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.be_000.to_numpy())
df_new['ck_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ck_000.to_numpy())
df_new['cs_002_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.cs_002.to_numpy()) 
df_new['aq_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.aq_000.to_numpy())
df_new['bf_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.bf_000.to_numpy())
df_new['at_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.at_000.to_numpy())
df_new['ee_005_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ee_005.to_numpy())
df_new['bb_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.bb_000.to_numpy())
df_new['bl_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.bl_000.to_numpy())
df_new['ee_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ee_000.to_numpy())
df_new['bo_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.bo_000.to_numpy())
df_new['bk_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.bk_000.to_numpy())
df_new
# Out:
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bj_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.bj_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ci_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ci_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_002_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ay_002.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ag_001_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ag_001.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_005_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ay_005.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ag_002_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ag_002.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['am_0_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.am_0.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_006_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ay_006.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_003_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ee_003.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_001_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ay_001.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cl_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.cl_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cd_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.cd_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_007_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ee_007.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ba_004_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ba_004.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_008_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ay_008.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['by_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.by_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['al_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.al_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cn_007_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.cn_007.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_009_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ay_009.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['az_003_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.az_003.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_003_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ay_003.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['dg_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.dg_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ay_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['dc_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.dc_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['az_002_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.az_002.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['dx_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.dx_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_004_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.cs_004.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['eb_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.eb_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_009_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.cs_009.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_008_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ee_008.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ag_006_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ag_006.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cn_002_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.cn_002.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_005_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.cs_005.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['br_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.br_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cj_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.cj_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bi_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.bi_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:38: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['do_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.do_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['di_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.di_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['an_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.an_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:41: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['du_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.du_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ao_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ao_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cm_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.cm_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_006_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.cs_006.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_001_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ee_001.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ba_002_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ba_002.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:47: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ca_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ca_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['be_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.be_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ck_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ck_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_002_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.cs_002.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['aq_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.aq_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bf_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.bf_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['at_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.at_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_005_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ee_005.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bb_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.bb_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bl_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.bl_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.ee_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bo_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.bo_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/599626772.py:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bk_000_cnv'] = tsaug.Convolve(window="flat", size=10).augment(df_new.bk_000.to_numpy())
#           bj_000      ci_000    ay_002    ag_001         ay_005    ag_002  \
# 0       799478.0  5245752.00  2198.356   828.488  469014.000000  8571.650
# 1       392208.0  2291079.36     0.000     0.000   71510.000000     0.000
# 2       139730.0  2322692.16     0.000     0.000  202696.500000     0.000
# 3         3090.0     2135.04     0.000     0.000  181363.333333     0.000
# 4       399410.0  3565684.80     0.000     0.000  372236.000000     0.000
# ...          ...         ...       ...       ...            ...       ...
# 59995   678792.0  8289544.32  5757.992  1061.362   45114.000000  6691.674
# 59996     9572.0   123344.64  5757.992  1061.362    4610.000000  6691.674
# 59997     6224.0     7518.72  5757.992  1061.362  137882.849000  6691.674
# 59998  1032454.0  4776505.92  5757.992  1061.362  119742.000000  6691.558
# 59999   260378.0  2480113.92     0.000     0.000  105702.000000     0.000
#
#              am_0        ay_006    ee_003     ay_001  ...     cs_002_cnv  \
# 0      107278.622  4.239660e+06  493384.0   3798.284  ...  218191.690079
# 1           0.000  7.727200e+05  178064.0      0.000  ...  110631.171692
# 2         486.750  8.704560e+05  159812.0      0.000  ...   35001.781352
# 3        3894.000  1.781648e+06      46.0      0.000  ...   39768.994870
# 4         811.250  2.128914e+06  229790.0      0.000  ...   60515.603060
# ...           ...           ...       ...        ...  ...            ...
# 59995    2114.000  2.533260e+06  566884.0  13500.280  ...   50027.213720
# 59996   76769.085  9.912000e+04    6760.0  13500.280  ...   46003.363405
# 59997   76768.344  1.062160e+06     386.0  13500.280  ...  145762.571126
# 59998   76758.797  4.445146e+06  222654.0  13500.280  ...  179241.091693
# 59999       0.000  1.433988e+06  183200.0      0.000  ...  140332.928158
#
#           aq_000_cnv  bf_000_cnv    at_000_cnv     ee_005_cnv    bb_000_cnv  \
# 0      765542.801633  166.708431   3669.052666  391034.599862  5.352510e+06
# 1      266568.195226  167.957529    442.808243  303897.441757  3.032037e+06
# 2       94185.513808   82.553772   -312.605196  209634.297143  1.594955e+06
# 3      266289.977386   33.975349    -71.234128  201902.825290  2.195378e+06
# 4      363263.102056    5.606273     -1.456470  221856.960002  2.673221e+06
# ...              ...         ...           ...            ...           ...
# 59995  288357.426819   43.805765   -422.204705  547657.120250  4.641231e+06
# 59996  188956.104551   64.630207   7342.691894  162254.923837  1.675809e+06
# 59997  523053.627723   65.752304  25680.753851   77667.248385  2.519173e+06
# 59998  670924.659767   33.216923  23476.415530  215972.710804  4.083888e+06
# 59999  545429.740403    9.866215  11560.524461  270096.534695  3.983562e+06
#
#           bl_000_cnv     ee_000_cnv     bo_000_cnv     bk_000_cnv
# 0      339970.558084  819116.195912  238745.471902  320693.029669
# 1      250896.601230  451532.988470  153190.117901  243137.745604
# 2      209519.772190  172083.626499   90625.635734  212425.207891
# 3      248062.162267  199505.154203   61078.910885  253578.145846
# 4      254413.695663  258957.840280   44248.487829  246870.458781
# ...              ...            ...            ...            ...
# 59995  182024.485604  676490.803726  114694.497099  200456.397731
# 59996  181677.592411  278685.825931  136529.586568  183675.222781
# 59997  241591.975582  489930.585975  205320.287406  220311.862426
# 59998  289140.063704  690542.558383  151929.179856  234337.499732
# 59999  291149.222623  603568.667190   64687.491171  216965.265880
#
# [60000 rows x 348 columns]

# %%
df_new['bj_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.bj_000.to_numpy())
df_new['ci_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ci_000.to_numpy())
df_new['ay_002_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ay_002.to_numpy())
df_new['ag_001_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ag_001.to_numpy())
df_new['ay_005_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ay_005.to_numpy())
df_new['ag_002_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ag_002.to_numpy())
df_new['am_0_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.am_0.to_numpy())
df_new['ay_006_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ay_006.to_numpy())
df_new['ee_003_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ee_003.to_numpy())
df_new['ay_001_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ay_001.to_numpy())
df_new['cl_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.cl_000.to_numpy())
df_new['cd_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.cd_000.to_numpy())
df_new['ee_007_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ee_007.to_numpy())  
df_new['ba_004_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ba_004.to_numpy())
df_new['ay_008_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ay_008.to_numpy())
df_new['by_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.by_000.to_numpy()) 
df_new['al_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.al_000.to_numpy()) 
df_new['cn_007_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.cn_007.to_numpy())  
df_new['ay_009_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ay_009.to_numpy()) 
df_new['az_003_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.az_003.to_numpy()) 
df_new['ay_003_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ay_003.to_numpy()) 
df_new['dg_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.dg_000.to_numpy())  
df_new['ay_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ay_000.to_numpy())
df_new['dc_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.dc_000.to_numpy())  
df_new['az_002_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.az_002.to_numpy())  
df_new['dx_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.dx_000.to_numpy()) 
df_new['cs_004_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.cs_004.to_numpy()) 
df_new['eb_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.eb_000.to_numpy())
df_new['cs_009_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.cs_009.to_numpy()) 
df_new['ee_008_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ee_008.to_numpy())
df_new['ag_006_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ag_006.to_numpy())  
df_new['cn_002_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.cn_002.to_numpy())
df_new['cs_005_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.cs_005.to_numpy()) 
df_new['br_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.br_000.to_numpy())
df_new['cj_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.cj_000.to_numpy()) 
df_new['bi_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.bi_000.to_numpy())
df_new['do_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.do_000.to_numpy())
df_new['di_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.di_000.to_numpy())
df_new['an_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.an_000.to_numpy()) 
df_new['du_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.du_000.to_numpy())
df_new['ao_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ao_000.to_numpy()) 
df_new['cm_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.cm_000.to_numpy())
df_new['cs_006_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.cs_006.to_numpy())
df_new['ee_001_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ee_001.to_numpy())
df_new['ba_002_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ba_002.to_numpy())
df_new['ca_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ca_000.to_numpy())
df_new['be_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.be_000.to_numpy())
df_new['ck_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ck_000.to_numpy())
df_new['cs_002_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.cs_002.to_numpy()) 
df_new['aq_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.aq_000.to_numpy())
df_new['bf_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.bf_000.to_numpy())
df_new['at_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.at_000.to_numpy())
df_new['ee_005_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ee_005.to_numpy())
df_new['bb_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.bb_000.to_numpy())
df_new['bl_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.bl_000.to_numpy())
df_new['ee_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ee_000.to_numpy())
df_new['bo_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.bo_000.to_numpy())
df_new['bk_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.bk_000.to_numpy())

df_new
# Out:
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bj_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.bj_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ci_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ci_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_002_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ay_002.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ag_001_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ag_001.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_005_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ay_005.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ag_002_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ag_002.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['am_0_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.am_0.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_006_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ay_006.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_003_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ee_003.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_001_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ay_001.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cl_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.cl_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cd_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.cd_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_007_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ee_007.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ba_004_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ba_004.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_008_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ay_008.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['by_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.by_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['al_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.al_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cn_007_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.cn_007.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_009_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ay_009.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['az_003_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.az_003.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_003_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ay_003.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['dg_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.dg_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ay_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['dc_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.dc_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['az_002_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.az_002.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['dx_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.dx_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_004_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.cs_004.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['eb_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.eb_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_009_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.cs_009.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_008_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ee_008.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ag_006_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ag_006.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cn_002_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.cn_002.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_005_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.cs_005.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['br_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.br_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cj_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.cj_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bi_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.bi_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['do_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.do_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:38: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['di_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.di_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['an_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.an_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['du_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.du_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:41: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ao_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ao_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cm_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.cm_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_006_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.cs_006.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_001_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ee_001.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ba_002_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ba_002.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ca_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ca_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:47: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['be_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.be_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ck_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ck_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_002_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.cs_002.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['aq_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.aq_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bf_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.bf_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['at_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.at_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_005_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ee_005.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bb_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.bb_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bl_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.bl_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.ee_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bo_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.bo_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_5835/1408039449.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bk_000_tw'] = tsaug.TimeWarp(n_speed_change=2, max_speed_ratio=5).augment(df_new.bk_000.to_numpy())
#           bj_000      ci_000    ay_002    ag_001         ay_005    ag_002  \
# 0       799478.0  5245752.00  2198.356   828.488  469014.000000  8571.650
# 1       392208.0  2291079.36     0.000     0.000   71510.000000     0.000
# 2       139730.0  2322692.16     0.000     0.000  202696.500000     0.000
# 3         3090.0     2135.04     0.000     0.000  181363.333333     0.000
# 4       399410.0  3565684.80     0.000     0.000  372236.000000     0.000
# ...          ...         ...       ...       ...            ...       ...
# 59995   678792.0  8289544.32  5757.992  1061.362   45114.000000  6691.674
# 59996     9572.0   123344.64  5757.992  1061.362    4610.000000  6691.674
# 59997     6224.0     7518.72  5757.992  1061.362  137882.849000  6691.674
# 59998  1032454.0  4776505.92  5757.992  1061.362  119742.000000  6691.558
# 59999   260378.0  2480113.92     0.000     0.000  105702.000000     0.000
#
#              am_0        ay_006    ee_003     ay_001  ...      cs_002_tw  \
# 0      107278.622  4.239660e+06  493384.0   3798.284  ...  267998.000000
# 1           0.000  7.727200e+05  178064.0      0.000  ...  135454.382072
# 2         486.750  8.704560e+05  159812.0      0.000  ...   25823.783970
# 3        3894.000  1.781648e+06      46.0      0.000  ...   65823.900324
# 4         811.250  2.128914e+06  229790.0      0.000  ...   67082.463539
# ...           ...           ...       ...        ...  ...            ...
# 59995    2114.000  2.533260e+06  566884.0  13500.280  ...   81303.679173
# 59996   76769.085  9.912000e+04    6760.0  13500.280  ...   81270.570070
# 59997   76768.344  1.062160e+06     386.0  13500.280  ...   81246.920265
# 59998   76758.797  4.445146e+06  222654.0  13500.280  ...   81232.730126
# 59999       0.000  1.433988e+06  183200.0      0.000  ...   81228.000000
#
#           aq_000_tw   bf_000_tw    at_000_tw      ee_005_tw     bb_000_tw  \
# 0      1.132040e+06   50.000000  6709.982000  469792.000000  6.700214e+06
# 1      9.203947e+05  341.782786   927.390001  350254.119206  5.647877e+06
# 2      7.087370e+05    8.938555     0.000000  333640.393329  4.595517e+06
# 3      4.970669e+05  100.380057     0.000000  457075.171764  3.613661e+06
# 4      3.261604e+05    2.190212     0.000000  439219.652397  3.278206e+06
# ...             ...         ...          ...            ...           ...
# 59995  2.335140e+05    2.021925    19.335729  247020.793401  1.174965e+06
# 59996  2.429570e+05    2.012333    10.876483  248784.353283  3.646554e+06
# 59997  9.904666e+04    2.005481     4.834053  250546.741047  3.049564e+04
# 59998  7.562738e+03    2.001370     1.208529  252307.956637  1.272845e+05
# 59999  3.348640e+05    2.000000     0.000000  254068.000000  3.076406e+06
#
#            bl_000_tw      ee_000_tw      bo_000_tw      bk_000_tw
# 0      353400.000000  965866.000000  283680.000000  330760.000000
# 1      356069.162824  965859.751183  165639.643379  338691.617538
# 2      358738.330805  965841.005085   88937.328702  241720.822059
# 3      301327.609103  965809.762236   61559.591107  162542.169099
# 4      205463.108302  965766.023164   49837.238838  243895.594242
# ...              ...            ...            ...            ...
# 59995  198145.503781    3711.648113     108.094108  166247.064331
# 59996  149727.564273  208741.152539      60.803696  194245.635296
# 59997  164510.874546  411259.257641      27.024202  160181.112212
# 59998  163346.419787  453191.881176       6.756136  160037.432457
# 59999  268280.000000  409798.000000      -0.000003  191320.000001
#
# [60000 rows x 348 columns]

# %%
df_new['bj_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.bj_000.to_numpy())
df_new['ci_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ci_000.to_numpy())
df_new['ay_002_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ay_002.to_numpy())
df_new['ag_001_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ag_001.to_numpy())
df_new['ay_005_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ay_005.to_numpy())
df_new['ag_002_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ag_002.to_numpy())
df_new['am_0_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.am_0.to_numpy())
df_new['ay_006_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ay_006.to_numpy())
df_new['ee_003_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ee_003.to_numpy())
df_new['ay_001_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ay_001.to_numpy())
df_new['cl_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.cl_000.to_numpy())
df_new['cd_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.cd_000.to_numpy())
df_new['ee_007_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ee_007.to_numpy())  
df_new['ba_004_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ba_004.to_numpy())
df_new['ay_008_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ay_008.to_numpy())
df_new['by_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.by_000.to_numpy()) 
df_new['al_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.al_000.to_numpy()) 
df_new['cn_007_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.cn_007.to_numpy())  
df_new['ay_009_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ay_009.to_numpy()) 
df_new['az_003_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.az_003.to_numpy()) 
df_new['ay_003_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ay_003.to_numpy()) 
df_new['dg_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.dg_000.to_numpy())  
df_new['ay_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ay_000.to_numpy())
df_new['dc_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.dc_000.to_numpy())  
df_new['az_002_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.az_002.to_numpy())  
df_new['dx_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.dx_000.to_numpy()) 
df_new['cs_004_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.cs_004.to_numpy()) 
df_new['eb_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.eb_000.to_numpy())
df_new['cs_009_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.cs_009.to_numpy()) 
df_new['ee_008_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ee_008.to_numpy())
df_new['ag_006_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ag_006.to_numpy())  
df_new['cn_002_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.cn_002.to_numpy())
df_new['cs_005_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.cs_005.to_numpy()) 
df_new['br_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.br_000.to_numpy())
df_new['cj_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.cj_000.to_numpy()) 
df_new['bi_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.bi_000.to_numpy())
df_new['do_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.do_000.to_numpy())
df_new['di_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.di_000.to_numpy())
df_new['an_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.an_000.to_numpy()) 
df_new['du_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.du_000.to_numpy())
df_new['ao_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ao_000.to_numpy()) 
df_new['cm_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.cm_000.to_numpy())
df_new['cs_006_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.cs_006.to_numpy())
df_new['ee_001_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ee_001.to_numpy())
df_new['ba_002_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ba_002.to_numpy())
df_new['ca_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ca_000.to_numpy())
df_new['be_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.be_000.to_numpy())
df_new['ck_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ck_000.to_numpy())
df_new['cs_002_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.cs_002.to_numpy()) 
df_new['aq_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.aq_000.to_numpy())
df_new['bf_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.bf_000.to_numpy())
df_new['at_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.at_000.to_numpy())
df_new['ee_005_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ee_005.to_numpy())
df_new['bb_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.bb_000.to_numpy())
df_new['bl_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.bl_000.to_numpy())
df_new['ee_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ee_000.to_numpy())
df_new['bo_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.bo_000.to_numpy())
df_new['bk_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.bk_000.to_numpy())

df_new
# Out:
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bj_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.bj_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ci_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ci_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_002_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ay_002.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ag_001_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ag_001.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_005_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ay_005.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ag_002_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ag_002.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['am_0_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.am_0.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_006_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ay_006.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_003_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ee_003.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_001_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ay_001.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cl_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.cl_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cd_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.cd_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_007_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ee_007.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ba_004_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ba_004.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_008_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ay_008.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['by_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.by_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['al_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.al_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cn_007_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.cn_007.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_009_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ay_009.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['az_003_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.az_003.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_003_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ay_003.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['dg_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.dg_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ay_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ay_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['dc_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.dc_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['az_002_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.az_002.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['dx_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.dx_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_004_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.cs_004.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['eb_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.eb_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_009_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.cs_009.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_008_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ee_008.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ag_006_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ag_006.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cn_002_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.cn_002.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_005_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.cs_005.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['br_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.br_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cj_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.cj_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bi_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.bi_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['do_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.do_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:38: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['di_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.di_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['an_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.an_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['du_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.du_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:41: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ao_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ao_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cm_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.cm_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_006_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.cs_006.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_001_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ee_001.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ba_002_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ba_002.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ca_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ca_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:47: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['be_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.be_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ck_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ck_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_002_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.cs_002.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['aq_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.aq_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bf_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.bf_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['at_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.at_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_005_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ee_005.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bb_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.bb_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bl_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.bl_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.ee_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bo_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.bo_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/3906196881.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bk_000_drift'] = tsaug.Drift(max_drift=0.3, n_drift_points=5).augment(df_new.bk_000.to_numpy())
#           bj_000      ci_000    ay_002    ag_001         ay_005    ag_002  \
# 0       799478.0  5245752.00  2198.356   828.488  469014.000000  8571.650
# 1       392208.0  2291079.36     0.000     0.000   71510.000000     0.000
# 2       139730.0  2322692.16     0.000     0.000  202696.500000     0.000
# 3         3090.0     2135.04     0.000     0.000  181363.333333     0.000
# 4       399410.0  3565684.80     0.000     0.000  372236.000000     0.000
# ...          ...         ...       ...       ...            ...       ...
# 59995   678792.0  8289544.32  5757.992  1061.362   45114.000000  6691.674
# 59996     9572.0   123344.64  5757.992  1061.362    4610.000000  6691.674
# 59997     6224.0     7518.72  5757.992  1061.362  137882.849000  6691.674
# 59998  1032454.0  4776505.92  5757.992  1061.362  119742.000000  6691.558
# 59999   260378.0  2480113.92     0.000     0.000  105702.000000     0.000
#
#              am_0        ay_006    ee_003     ay_001  ...  cs_002_drift  \
# 0      107278.622  4.239660e+06  493384.0   3798.284  ...  2.679980e+05
# 1           0.000  7.727200e+05  178064.0      0.000  ...  1.671542e+05
# 2         486.750  8.704560e+05  159812.0      0.000  ...  6.095003e+04
# 3        3894.000  1.781648e+06      46.0      0.000  ...  6.905385e+03
# 4         811.250  2.128914e+06  229790.0      0.000  ...  9.012431e+04
# ...           ...           ...       ...        ...  ...           ...
# 59995    2114.000  2.533260e+06  566884.0  13500.280  ... -2.214486e+06
# 59996   76769.085  9.912000e+04    6760.0  13500.280  ... -2.349320e+06
# 59997   76768.344  1.062160e+06     386.0  13500.280  ... -2.353260e+06
# 59998   76758.797  4.445146e+06  222654.0  13500.280  ... -2.019815e+06
# 59999       0.000  1.433988e+06  183200.0      0.000  ... -2.272914e+06
#
#        aq_000_drift  bf_000_drift  at_000_drift  ee_005_drift  bb_000_drift  \
# 0      1.132040e+06     50.000000  6.709982e+03  4.697920e+05  6.700214e+06
# 1      3.398168e+05    351.543819  1.581534e+01  2.422678e+05  3.651830e+06
# 2      1.562435e+05      7.087430  3.162919e+01  4.032684e+05  2.683677e+06
# 3      4.832011e+03    112.564166  4.744157e+01 -9.398195e+03  3.712018e+04
# 4      5.561124e+05      8.174027  6.325246e+01  3.346000e+05  4.309932e+06
# ...             ...           ...           ...           ...           ...
# 59995  2.768310e+06  15327.671798  3.121335e+06 -7.006321e+06 -3.251247e+07
# 59996  2.003754e+06  15380.498831  3.121432e+06 -8.157388e+06 -4.321134e+07
# 59997  1.993199e+06  15380.706876  3.121559e+06 -8.226914e+06 -4.331653e+07
# 59998  3.207487e+06  15384.217932  3.177353e+06 -8.002581e+06 -3.720182e+07
# 59999  2.327574e+06  15316.400000  3.120151e+06 -7.975483e+06 -4.028643e+07
#
#         bl_000_drift  ee_000_drift   bo_000_drift   bk_000_drift
# 0      353400.000000  9.658660e+05  283680.000000  330760.000000
# 1      359757.806213  6.666289e+05  189183.449319  341386.235455
# 2      130595.616498  2.662809e+05  106506.887947  137092.474386
# 3      253208.097523  1.204208e+04   75838.315883  246400.716792
# 4      282471.249287  4.132344e+05   59353.733129  306644.962672
# ...              ...           ...            ...            ...
# 59995  522283.306656  1.136134e+07  539045.151399   58621.092292
# 59996  463991.790533  9.766089e+06  486342.011105  -44599.484737
# 59997  464143.959132  9.767659e+06  486577.469501  -44532.379429
# 59998  632921.362455  1.093212e+07  749147.986587   98189.988217
# 59999  568887.370500  1.016083e+07  386842.262361  -13127.021798
#
# [60000 rows x 464 columns]

# %%
df_new=df_new.fillna(0)
df_new
# Out:
#           bj_000      ci_000    ay_002    ag_001         ay_005    ag_002  \
# 0       799478.0  5245752.00  2198.356   828.488  469014.000000  8571.650
# 1       392208.0  2291079.36     0.000     0.000   71510.000000     0.000
# 2       139730.0  2322692.16     0.000     0.000  202696.500000     0.000
# 3         3090.0     2135.04     0.000     0.000  181363.333333     0.000
# 4       399410.0  3565684.80     0.000     0.000  372236.000000     0.000
# ...          ...         ...       ...       ...            ...       ...
# 59995   678792.0  8289544.32  5757.992  1061.362   45114.000000  6691.674
# 59996     9572.0   123344.64  5757.992  1061.362    4610.000000  6691.674
# 59997     6224.0     7518.72  5757.992  1061.362  137882.849000  6691.674
# 59998  1032454.0  4776505.92  5757.992  1061.362  119742.000000  6691.558
# 59999   260378.0  2480113.92     0.000     0.000  105702.000000     0.000
#
#              am_0        ay_006    ee_003     ay_001  ...      cs_002_tw  \
# 0      107278.622  4.239660e+06  493384.0   3798.284  ...  267998.000000
# 1           0.000  7.727200e+05  178064.0      0.000  ...  135454.382072
# 2         486.750  8.704560e+05  159812.0      0.000  ...   25823.783970
# 3        3894.000  1.781648e+06      46.0      0.000  ...   65823.900324
# 4         811.250  2.128914e+06  229790.0      0.000  ...   67082.463539
# ...           ...           ...       ...        ...  ...            ...
# 59995    2114.000  2.533260e+06  566884.0  13500.280  ...   81303.679173
# 59996   76769.085  9.912000e+04    6760.0  13500.280  ...   81270.570070
# 59997   76768.344  1.062160e+06     386.0  13500.280  ...   81246.920265
# 59998   76758.797  4.445146e+06  222654.0  13500.280  ...   81232.730126
# 59999       0.000  1.433988e+06  183200.0      0.000  ...   81228.000000
#
#           aq_000_tw   bf_000_tw    at_000_tw      ee_005_tw     bb_000_tw  \
# 0      1.132040e+06   50.000000  6709.982000  469792.000000  6.700214e+06
# 1      9.203947e+05  341.782786   927.390001  350254.119206  5.647877e+06
# 2      7.087370e+05    8.938555     0.000000  333640.393329  4.595517e+06
# 3      4.970669e+05  100.380057     0.000000  457075.171764  3.613661e+06
# 4      3.261604e+05    2.190212     0.000000  439219.652397  3.278206e+06
# ...             ...         ...          ...            ...           ...
# 59995  2.335140e+05    2.021925    19.335729  247020.793401  1.174965e+06
# 59996  2.429570e+05    2.012333    10.876483  248784.353283  3.646554e+06
# 59997  9.904666e+04    2.005481     4.834053  250546.741047  3.049564e+04
# 59998  7.562738e+03    2.001370     1.208529  252307.956637  1.272845e+05
# 59999  3.348640e+05    2.000000     0.000000  254068.000000  3.076406e+06
#
#            bl_000_tw      ee_000_tw      bo_000_tw      bk_000_tw
# 0      353400.000000  965866.000000  283680.000000  330760.000000
# 1      356069.162824  965859.751183  165639.643379  338691.617538
# 2      358738.330805  965841.005085   88937.328702  241720.822059
# 3      301327.609103  965809.762236   61559.591107  162542.169099
# 4      205463.108302  965766.023164   49837.238838  243895.594242
# ...              ...            ...            ...            ...
# 59995  198145.503781    3711.648113     108.094108  166247.064331
# 59996  149727.564273  208741.152539      60.803696  194245.635296
# 59997  164510.874546  411259.257641      27.024202  160181.112212
# 59998  163346.419787  453191.881176       6.756136  160037.432457
# 59999  268280.000000  409798.000000      -0.000003  191320.000001
#
# [60000 rows x 348 columns]

# %%
#STD-trend-seasonal
from statsmodels.tsa.seasonal import seasonal_decompose
df_new['bj_000_trend'] = seasonal_decompose(x=df_new['bj_000'], model='additive', period=2).seasonal
df_new['ci_000_trend'] = seasonal_decompose(x=df_new['ci_000'], model='additive', period=2).seasonal
df_new['ay_002_trend'] = seasonal_decompose(x=df_new['ay_002'], model='additive', period=2).seasonal
df_new['ag_001_trend'] = seasonal_decompose(x=df_new['ag_001'], model='additive', period=2).seasonal
df_new['ay_005_trend'] = seasonal_decompose(x=df_new['ay_005'], model='additive', period=2).seasonal
df_new['ag_002_trend'] = seasonal_decompose(x=df_new['ag_002'], model='additive', period=2).seasonal
df_new['am_0_trend'] = seasonal_decompose(x=df_new['am_0'], model='additive', period=2).seasonal
df_new['ay_006_trend'] = seasonal_decompose(x=df_new['ay_006'], model='additive', period=2).seasonal
df_new['ee_003_trend'] = seasonal_decompose(x=df_new['ee_003'], model='additive', period=2).seasonal
df_new['ay_001_trend'] = seasonal_decompose(x=df_new['ay_001'], model='additive', period=2).seasonal
df_new['cl_000_trend'] = seasonal_decompose(x=df_new['cl_000'], model='additive', period=2).seasonal
df_new['cd_000_trend'] = seasonal_decompose(x=df_new['cd_000'], model='additive', period=2).seasonal
df_new['ee_007_trend'] = seasonal_decompose(x=df_new['ee_007'], model='additive', period=2).seasonal  
df_new['ba_004_trend'] = seasonal_decompose(x=df_new['ba_004'], model='additive', period=2).seasonal
df_new['ay_008_trend'] = seasonal_decompose(x=df_new['ay_008'], model='additive', period=2).seasonal
df_new['by_000_trend'] = seasonal_decompose(x=df_new['by_000'], model='additive', period=2).seasonal 
df_new['al_000_trend'] = seasonal_decompose(x=df_new['al_000'], model='additive', period=2).seasonal 
df_new['cn_007_trend'] = seasonal_decompose(x=df_new['cn_007'], model='additive', period=2).seasonal  
df_new['ay_009_trend'] = seasonal_decompose(x=df_new['ay_009'], model='additive', period=2).seasonal 
df_new['az_003_trend'] = seasonal_decompose(x=df_new['az_003'], model='additive', period=2).seasonal 
df_new['ay_003_trend'] = seasonal_decompose(x=df_new['ay_003'], model='additive', period=2).seasonal 
df_new['dg_000_trend'] = seasonal_decompose(x=df_new['dg_000'], model='additive', period=2).seasonal  
df_new['ay_000_trend'] = seasonal_decompose(x=df_new['ay_000'], model='additive', period=2).seasonal
df_new['dc_000_trend'] = seasonal_decompose(x=df_new['dc_000'], model='additive', period=2).seasonal  
df_new['az_002_trend'] = seasonal_decompose(x=df_new['az_002'], model='additive', period=2).seasonal  
df_new['dx_000_trend'] = seasonal_decompose(x=df_new['dx_000'], model='additive', period=2).seasonal 
df_new['cs_004_trend'] = seasonal_decompose(x=df_new['cs_004'], model='additive', period=2).seasonal 
df_new['eb_000_trend'] = seasonal_decompose(x=df_new['eb_000'], model='additive', period=2).seasonal
df_new['cs_009_trend'] = seasonal_decompose(x=df_new['cs_009'], model='additive', period=2).seasonal 
df_new['ee_008_trend'] = seasonal_decompose(x=df_new['ee_008'], model='additive', period=2).seasonal
df_new['ag_006_trend'] = seasonal_decompose(x=df_new['ag_006'], model='additive', period=2).seasonal  
df_new['cn_002_trend'] = seasonal_decompose(x=df_new['cn_002'], model='additive', period=2).seasonal
df_new['cs_005_trend'] = seasonal_decompose(x=df_new['cs_005'], model='additive', period=2).seasonal 
df_new['br_000_trend'] = seasonal_decompose(x=df_new['br_000'], model='additive', period=2).seasonal
df_new['cj_000_trend'] = seasonal_decompose(x=df_new['cj_000'], model='additive', period=2).seasonal 
df_new['bi_000_trend'] = seasonal_decompose(x=df_new['bi_000'], model='additive', period=2).seasonal
df_new['do_000_trend'] = seasonal_decompose(x=df_new['do_000'], model='additive', period=2).seasonal
df_new['di_000_trend'] = seasonal_decompose(x=df_new['di_000'], model='additive', period=2).seasonal
df_new['an_000_trend'] = seasonal_decompose(x=df_new['an_000'], model='additive', period=2).seasonal 
df_new['du_000_trend'] = seasonal_decompose(x=df_new['du_000'], model='additive', period=2).seasonal
df_new['ao_000_trend'] = seasonal_decompose(x=df_new['ao_000'], model='additive', period=2).seasonal 
df_new['cm_000_trend'] = seasonal_decompose(x=df_new['cm_000'], model='additive', period=2).seasonal
df_new['cs_006_trend'] = seasonal_decompose(x=df_new['cs_006'], model='additive', period=2).seasonal
df_new['ee_001_trend'] = seasonal_decompose(x=df_new['ee_001'], model='additive', period=2).seasonal
df_new['ba_002_trend'] = seasonal_decompose(x=df_new['ba_002'], model='additive', period=2).seasonal
df_new['ca_000_trend'] = seasonal_decompose(x=df_new['ca_000'], model='additive', period=2).seasonal
df_new['be_000_trend'] = seasonal_decompose(x=df_new['be_000'], model='additive', period=2).seasonal
df_new['ck_000_trend'] = seasonal_decompose(x=df_new['ck_000'], model='additive', period=2).seasonal
df_new['cs_002_trend'] = seasonal_decompose(x=df_new['cs_002'], model='additive', period=2).seasonal 
df_new['aq_000_trend'] = seasonal_decompose(x=df_new['aq_000'], model='additive', period=2).seasonal
df_new['bf_000_trend'] = seasonal_decompose(x=df_new['bf_000'], model='additive', period=2).seasonal
df_new['at_000_trend'] = seasonal_decompose(x=df_new['at_000'], model='additive', period=2).seasonal
df_new['ee_005_trend'] = seasonal_decompose(x=df_new['ee_005'], model='additive', period=2).seasonal
df_new['bb_000_trend'] = seasonal_decompose(x=df_new['bb_000'], model='additive', period=2).seasonal
df_new['bl_000_trend'] = seasonal_decompose(x=df_new['bl_000'], model='additive', period=2).seasonal
df_new['ee_000_trend'] = seasonal_decompose(x=df_new['ee_000'], model='additive', period=2).seasonal
df_new['bo_000_trend'] = seasonal_decompose(x=df_new['bo_000'], model='additive', period=2).seasonal
df_new['bk_000_trend'] = seasonal_decompose(x=df_new['bk_000'], model='additive', period=2).seasonal



df_new
# Out:
#           bj_000      ci_000    ay_002    ag_001         ay_005    ag_002  \
# 0       799478.0  5245752.00  2198.356   828.488  469014.000000  8571.650
# 1       392208.0  2291079.36     0.000     0.000   71510.000000     0.000
# 2       139730.0  2322692.16     0.000     0.000  202696.500000     0.000
# 3         3090.0     2135.04     0.000     0.000  181363.333333     0.000
# 4       399410.0  3565684.80     0.000     0.000  372236.000000     0.000
# ...          ...         ...       ...       ...            ...       ...
# 59995   678792.0  8289544.32  5757.992  1061.362   45114.000000  6691.674
# 59996     9572.0   123344.64  5757.992  1061.362    4610.000000  6691.674
# 59997     6224.0     7518.72  5757.992  1061.362  137882.849000  6691.674
# 59998  1032454.0  4776505.92  5757.992  1061.362  119742.000000  6691.558
# 59999   260378.0  2480113.92     0.000     0.000  105702.000000     0.000
#
#              am_0        ay_006    ee_003     ay_001  ...  cs_002_trend  \
# 0      107278.622  4.239660e+06  493384.0   3798.284  ...     56.581429
# 1           0.000  7.727200e+05  178064.0      0.000  ...    -56.581429
# 2         486.750  8.704560e+05  159812.0      0.000  ...     56.581429
# 3        3894.000  1.781648e+06      46.0      0.000  ...    -56.581429
# 4         811.250  2.128914e+06  229790.0      0.000  ...     56.581429
# ...           ...           ...       ...        ...  ...           ...
# 59995    2114.000  2.533260e+06  566884.0  13500.280  ...    -56.581429
# 59996   76769.085  9.912000e+04    6760.0  13500.280  ...     56.581429
# 59997   76768.344  1.062160e+06     386.0  13500.280  ...    -56.581429
# 59998   76758.797  4.445146e+06  222654.0  13500.280  ...     56.581429
# 59999       0.000  1.433988e+06  183200.0      0.000  ...    -56.581429
#
#        aq_000_trend  bf_000_trend  at_000_trend  ee_005_trend  bb_000_trend  \
# 0      -3057.309798      -1.39349   -736.004956  -2949.371061  -14658.05445
# 1       3057.309798       1.39349    736.004956   2949.371061   14658.05445
# 2      -3057.309798      -1.39349   -736.004956  -2949.371061  -14658.05445
# 3       3057.309798       1.39349    736.004956   2949.371061   14658.05445
# 4      -3057.309798      -1.39349   -736.004956  -2949.371061  -14658.05445
# ...             ...           ...           ...           ...           ...
# 59995   3057.309798       1.39349    736.004956   2949.371061   14658.05445
# 59996  -3057.309798      -1.39349   -736.004956  -2949.371061  -14658.05445
# 59997   3057.309798       1.39349    736.004956   2949.371061   14658.05445
# 59998  -3057.309798      -1.39349   -736.004956  -2949.371061  -14658.05445
# 59999   3057.309798       1.39349    736.004956   2949.371061   14658.05445
#
#        bl_000_trend  ee_000_trend  bo_000_trend  bk_000_trend
# 0       -739.774844   3559.368812  -1397.791862   -458.398378
# 1        739.774844  -3559.368812   1397.791862    458.398378
# 2       -739.774844   3559.368812  -1397.791862   -458.398378
# 3        739.774844  -3559.368812   1397.791862    458.398378
# 4       -739.774844   3559.368812  -1397.791862   -458.398378
# ...             ...           ...           ...           ...
# 59995    739.774844  -3559.368812   1397.791862    458.398378
# 59996   -739.774844   3559.368812  -1397.791862   -458.398378
# 59997    739.774844  -3559.368812   1397.791862    458.398378
# 59998   -739.774844   3559.368812  -1397.791862   -458.398378
# 59999    739.774844  -3559.368812   1397.791862    458.398378
#
# [60000 rows x 406 columns]

# %%
#pooling
df_new['bj_000_pool'] = tsaug.Pool(size=2).augment(df_new.bj_000.to_numpy())
df_new['ci_000_pool'] = tsaug.Pool(size=2).augment(df_new.ci_000.to_numpy())
df_new['ay_002_pool'] = tsaug.Pool(size=2).augment(df_new.ay_002.to_numpy())
df_new['ag_001_pool'] = tsaug.Pool(size=2).augment(df_new.ag_001.to_numpy())
df_new['ay_005_pool'] = tsaug.Pool(size=2).augment(df_new.ay_005.to_numpy())
df_new['ag_002_pool'] = tsaug.Pool(size=2).augment(df_new.ag_002.to_numpy())
df_new['am_0_pool'] = tsaug.Pool(size=2).augment(df_new.am_0.to_numpy())
df_new['ay_006_pool'] = tsaug.Pool(size=2).augment(df_new.ay_006.to_numpy())
df_new['ee_003_pool'] = tsaug.Pool(size=2).augment(df_new.ee_003.to_numpy())
df_new['ay_001_pool'] = tsaug.Pool(size=2).augment(df_new.ay_001.to_numpy())
df_new['cl_000_pool'] = tsaug.Pool(size=2).augment(df_new.cl_000.to_numpy())
df_new['cd_000_pool'] = tsaug.Pool(size=2).augment(df_new.cd_000.to_numpy())
df_new['ee_007_pool'] = tsaug.Pool(size=2).augment(df_new.ee_007.to_numpy())  
df_new['ba_004_pool'] = tsaug.Pool(size=2).augment(df_new.ba_004.to_numpy())
df_new['ay_008_pool'] = tsaug.Pool(size=2).augment(df_new.ay_008.to_numpy())
df_new['by_000_pool'] = tsaug.Pool(size=2).augment(df_new.by_000.to_numpy()) 
df_new['al_000_pool'] = tsaug.Pool(size=2).augment(df_new.al_000.to_numpy()) 
df_new['cn_007_pool'] = tsaug.Pool(size=2).augment(df_new.cn_007.to_numpy())  
df_new['ay_009_pool'] = tsaug.Pool(size=2).augment(df_new.ay_009.to_numpy()) 
df_new['az_003_pool'] = tsaug.Pool(size=2).augment(df_new.az_003.to_numpy()) 
df_new['ay_003_pool'] = tsaug.Pool(size=2).augment(df_new.ay_003.to_numpy()) 
df_new['dg_000_pool'] = tsaug.Pool(size=2).augment(df_new.dg_000.to_numpy())  
df_new['ay_000_pool'] = tsaug.Pool(size=2).augment(df_new.ay_000.to_numpy())
df_new['dc_000_pool'] = tsaug.Pool(size=2).augment(df_new.dc_000.to_numpy())  
df_new['az_002_pool'] = tsaug.Pool(size=2).augment(df_new.az_002.to_numpy())  
df_new['dx_000_pool'] = tsaug.Pool(size=2).augment(df_new.dx_000.to_numpy()) 
df_new['cs_004_pool'] = tsaug.Pool(size=2).augment(df_new.cs_004.to_numpy()) 
df_new['eb_000_pool'] = tsaug.Pool(size=2).augment(df_new.eb_000.to_numpy())
df_new['cs_009_pool'] = tsaug.Pool(size=2).augment(df_new.cs_009.to_numpy()) 
df_new['ee_008_pool'] = tsaug.Pool(size=2).augment(df_new.ee_008.to_numpy())
df_new['ag_006_pool'] = tsaug.Pool(size=2).augment(df_new.ag_006.to_numpy())  
df_new['cn_002_pool'] = tsaug.Pool(size=2).augment(df_new.cn_002.to_numpy())
df_new['cs_005_pool'] = tsaug.Pool(size=2).augment(df_new.cs_005.to_numpy()) 
df_new['br_000_pool'] = tsaug.Pool(size=2).augment(df_new.br_000.to_numpy())
df_new['cj_000_pool'] = tsaug.Pool(size=2).augment(df_new.cj_000.to_numpy()) 
df_new['bi_000_pool'] = tsaug.Pool(size=2).augment(df_new.bi_000.to_numpy())
df_new['do_000_pool'] = tsaug.Pool(size=2).augment(df_new.do_000.to_numpy())
df_new['di_000_pool'] = tsaug.Pool(size=2).augment(df_new.di_000.to_numpy())
df_new['an_000_pool'] = tsaug.Pool(size=2).augment(df_new.an_000.to_numpy()) 
df_new['du_000_pool'] = tsaug.Pool(size=2).augment(df_new.du_000.to_numpy())
df_new['ao_000_pool'] = tsaug.Pool(size=2).augment(df_new.ao_000.to_numpy()) 
df_new['cm_000_pool'] = tsaug.Pool(size=2).augment(df_new.cm_000.to_numpy())
df_new['cs_006_pool'] = tsaug.Pool(size=2).augment(df_new.cs_006.to_numpy())
df_new['ee_001_pool'] = tsaug.Pool(size=2).augment(df_new.ee_001.to_numpy())
df_new['ba_002_pool'] = tsaug.Pool(size=2).augment(df_new.ba_002.to_numpy())
df_new['ca_000_pool'] = tsaug.Pool(size=2).augment(df_new.ca_000.to_numpy())
df_new['be_000_pool'] = tsaug.Pool(size=2).augment(df_new.be_000.to_numpy())
df_new['ck_000_pool'] = tsaug.Pool(size=2).augment(df_new.ck_000.to_numpy())
df_new['cs_002_pool'] = tsaug.Pool(size=2).augment(df_new.cs_002.to_numpy()) 
df_new['aq_000_pool'] = tsaug.Pool(size=2).augment(df_new.aq_000.to_numpy())
df_new['bf_000_pool'] = tsaug.Pool(size=2).augment(df_new.bf_000.to_numpy())
df_new['at_000_pool'] = tsaug.Pool(size=2).augment(df_new.at_000.to_numpy())
df_new['ee_005_pool'] = tsaug.Pool(size=2).augment(df_new.ee_005.to_numpy())
df_new['bb_000_pool'] = tsaug.Pool(size=2).augment(df_new.bb_000.to_numpy())
df_new['bl_000_pool'] = tsaug.Pool(size=2).augment(df_new.bl_000.to_numpy())
df_new['ee_000_pool'] = tsaug.Pool(size=2).augment(df_new.ee_000.to_numpy())
df_new['bo_000_pool'] = tsaug.Pool(size=2).augment(df_new.bo_000.to_numpy())
df_new['bk_000_pool'] = tsaug.Pool(size=2).augment(df_new.bk_000.to_numpy())



df_new
# Out:
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/1202446930.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cm_000_pool'] = tsaug.Pool(size=2).augment(df_new.cm_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/1202446930.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_006_pool'] = tsaug.Pool(size=2).augment(df_new.cs_006.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/1202446930.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_001_pool'] = tsaug.Pool(size=2).augment(df_new.ee_001.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/1202446930.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ba_002_pool'] = tsaug.Pool(size=2).augment(df_new.ba_002.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/1202446930.py:47: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ca_000_pool'] = tsaug.Pool(size=2).augment(df_new.ca_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/1202446930.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['be_000_pool'] = tsaug.Pool(size=2).augment(df_new.be_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/1202446930.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ck_000_pool'] = tsaug.Pool(size=2).augment(df_new.ck_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/1202446930.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['cs_002_pool'] = tsaug.Pool(size=2).augment(df_new.cs_002.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/1202446930.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['aq_000_pool'] = tsaug.Pool(size=2).augment(df_new.aq_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/1202446930.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bf_000_pool'] = tsaug.Pool(size=2).augment(df_new.bf_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/1202446930.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['at_000_pool'] = tsaug.Pool(size=2).augment(df_new.at_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/1202446930.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_005_pool'] = tsaug.Pool(size=2).augment(df_new.ee_005.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/1202446930.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bb_000_pool'] = tsaug.Pool(size=2).augment(df_new.bb_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/1202446930.py:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bl_000_pool'] = tsaug.Pool(size=2).augment(df_new.bl_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/1202446930.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['ee_000_pool'] = tsaug.Pool(size=2).augment(df_new.ee_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/1202446930.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bo_000_pool'] = tsaug.Pool(size=2).augment(df_new.bo_000.to_numpy())
# /var/folders/05/ntvwwb8x6tdf167m58_ryr800000gn/T/ipykernel_4273/1202446930.py:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_new['bk_000_pool'] = tsaug.Pool(size=2).augment(df_new.bk_000.to_numpy())
#           bj_000      ci_000    ay_002    ag_001         ay_005    ag_002  \
# 0       799478.0  5245752.00  2198.356   828.488  469014.000000  8571.650
# 1       392208.0  2291079.36     0.000     0.000   71510.000000     0.000
# 2       139730.0  2322692.16     0.000     0.000  202696.500000     0.000
# 3         3090.0     2135.04     0.000     0.000  181363.333333     0.000
# 4       399410.0  3565684.80     0.000     0.000  372236.000000     0.000
# ...          ...         ...       ...       ...            ...       ...
# 59995   678792.0  8289544.32  5757.992  1061.362   45114.000000  6691.674
# 59996     9572.0   123344.64  5757.992  1061.362    4610.000000  6691.674
# 59997     6224.0     7518.72  5757.992  1061.362  137882.849000  6691.674
# 59998  1032454.0  4776505.92  5757.992  1061.362  119742.000000  6691.558
# 59999   260378.0  2480113.92     0.000     0.000  105702.000000     0.000
#
#              am_0        ay_006    ee_003     ay_001  ...  cs_002_pool  \
# 0      107278.622  4.239660e+06  493384.0   3798.284  ...     216429.0
# 1           0.000  7.727200e+05  178064.0      0.000  ...     216429.0
# 2         486.750  8.704560e+05  159812.0      0.000  ...      28193.0
# 3        3894.000  1.781648e+06      46.0      0.000  ...      28193.0
# 4         811.250  2.128914e+06  229790.0      0.000  ...      77089.0
# ...           ...           ...       ...        ...  ...          ...
# 59995    2114.000  2.533260e+06  566884.0  13500.280  ...      69022.0
# 59996   76769.085  9.912000e+04    6760.0  13500.280  ...       1839.0
# 59997   76768.344  1.062160e+06     386.0  13500.280  ...       1839.0
# 59998   76758.797  4.445146e+06  222654.0  13500.280  ...     207575.0
# 59999       0.000  1.433988e+06  183200.0      0.000  ...     207575.0
#
#        aq_000_pool  bf_000_pool  at_000_pool  ee_005_pool  bb_000_pool  \
# 0         735292.0   200.000000     3354.991     357604.0    5173437.0
# 1         735292.0   200.000000     3354.991     357604.0    5173437.0
# 2          77356.0    55.966667        0.000     204804.0    1347476.0
# 3          77356.0    55.966667        0.000     204804.0    1347476.0
# 4         449038.0     3.000000        0.000     323800.0    3521036.0
# ...            ...          ...          ...          ...          ...
# 59995     388532.0    40.330000     1574.588     609205.0    5451215.0
# 59996       6248.0    66.658000     1588.913      34284.0      95688.0
# 59997       6248.0    66.658000     1588.913      34284.0      95688.0
# 59998     774917.0    36.000000    28650.000     239896.0    4618067.0
# 59999     774917.0    36.000000    28650.000     239896.0    4618067.0
#
#          bl_000_pool  ee_000_pool    bo_000_pool  bk_000_pool
# 0      356590.000000     815185.0  236400.000000    336090.00
# 1      356590.000000     815185.0  236400.000000    336090.00
# 2      191957.333333     133851.0   91014.000000    191831.00
# 3      191957.333333     133851.0   91014.000000    191831.00
# 4      252680.000000     352909.0   53865.428571    246640.00
# ...              ...          ...            ...          ...
# 59995  192753.500000     807553.0  126330.860000    211734.65
# 59996  163425.535000      14905.0   99753.170000    160038.54
# 59997  163425.535000      14905.0   99753.170000    160038.54
# 59998  300290.000000     795256.0  181180.000000    247010.00
# 59999  300290.000000     795256.0  181180.000000    247010.00
#
# [60000 rows x 580 columns]

# %%
df_new=df_new.fillna(0)
df_new
# Out:
#           bj_000      ci_000    ay_002    ag_001         ay_005    ag_002  \
# 0       799478.0  5245752.00  2198.356   828.488  469014.000000  8571.650
# 1       392208.0  2291079.36     0.000     0.000   71510.000000     0.000
# 2       139730.0  2322692.16     0.000     0.000  202696.500000     0.000
# 3         3090.0     2135.04     0.000     0.000  181363.333333     0.000
# 4       399410.0  3565684.80     0.000     0.000  372236.000000     0.000
# ...          ...         ...       ...       ...            ...       ...
# 59995   678792.0  8289544.32  5757.992  1061.362   45114.000000  6691.674
# 59996     9572.0   123344.64  5757.992  1061.362    4610.000000  6691.674
# 59997     6224.0     7518.72  5757.992  1061.362  137882.849000  6691.674
# 59998  1032454.0  4776505.92  5757.992  1061.362  119742.000000  6691.558
# 59999   260378.0  2480113.92     0.000     0.000  105702.000000     0.000
#
#              am_0        ay_006    ee_003     ay_001  ...  cs_002_pool  \
# 0      107278.622  4.239660e+06  493384.0   3798.284  ...     216429.0
# 1           0.000  7.727200e+05  178064.0      0.000  ...     216429.0
# 2         486.750  8.704560e+05  159812.0      0.000  ...      28193.0
# 3        3894.000  1.781648e+06      46.0      0.000  ...      28193.0
# 4         811.250  2.128914e+06  229790.0      0.000  ...      77089.0
# ...           ...           ...       ...        ...  ...          ...
# 59995    2114.000  2.533260e+06  566884.0  13500.280  ...      69022.0
# 59996   76769.085  9.912000e+04    6760.0  13500.280  ...       1839.0
# 59997   76768.344  1.062160e+06     386.0  13500.280  ...       1839.0
# 59998   76758.797  4.445146e+06  222654.0  13500.280  ...     207575.0
# 59999       0.000  1.433988e+06  183200.0      0.000  ...     207575.0
#
#        aq_000_pool  bf_000_pool  at_000_pool  ee_005_pool  bb_000_pool  \
# 0         735292.0   200.000000     3354.991     357604.0    5173437.0
# 1         735292.0   200.000000     3354.991     357604.0    5173437.0
# 2          77356.0    55.966667        0.000     204804.0    1347476.0
# 3          77356.0    55.966667        0.000     204804.0    1347476.0
# 4         449038.0     3.000000        0.000     323800.0    3521036.0
# ...            ...          ...          ...          ...          ...
# 59995     388532.0    40.330000     1574.588     609205.0    5451215.0
# 59996       6248.0    66.658000     1588.913      34284.0      95688.0
# 59997       6248.0    66.658000     1588.913      34284.0      95688.0
# 59998     774917.0    36.000000    28650.000     239896.0    4618067.0
# 59999     774917.0    36.000000    28650.000     239896.0    4618067.0
#
#          bl_000_pool  ee_000_pool    bo_000_pool  bk_000_pool
# 0      356590.000000     815185.0  236400.000000    336090.00
# 1      356590.000000     815185.0  236400.000000    336090.00
# 2      191957.333333     133851.0   91014.000000    191831.00
# 3      191957.333333     133851.0   91014.000000    191831.00
# 4      252680.000000     352909.0   53865.428571    246640.00
# ...              ...          ...            ...          ...
# 59995  192753.500000     807553.0  126330.860000    211734.65
# 59996  163425.535000      14905.0   99753.170000    160038.54
# 59997  163425.535000      14905.0   99753.170000    160038.54
# 59998  300290.000000     795256.0  181180.000000    247010.00
# 59999  300290.000000     795256.0  181180.000000    247010.00
#
# [60000 rows x 580 columns]

# %%
df_new.to_csv('APS_augmented_best_augmented.csv')
