# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import numpy as np
from pylab import rcParams

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import recall_score, classification_report, auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, f1_score

from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from numpy import mean

from imblearn.pipeline import Pipeline

from imblearn.combine import SMOTETomek
from imblearn.under_sampling import TomekLinks
from imblearn.combine import SMOTEENN
from imblearn.under_sampling import EditedNearestNeighbours
from imblearn.over_sampling import ADASYN

from sklearn.preprocessing import LabelEncoder

from numpy.random import seed
seed(7)

from sklearn.model_selection import train_test_split

SEED = 123 #used to help randomly select the data points
DATA_SPLIT_PCT = 0.2

rcParams['figure.figsize'] = 8, 6
LABELS = ["Normal","Break"]

# %%
df = pd.read_csv("bearing_dataset_combined_0.5%_augmented_stage1.csv") 
df.head(n=5)  # visualize the data.
# Out:
#    Unnamed: 0        DE        FE  status    lag_DE    lag_FE  \
# 0           0  0.014603  0.192920       0       NaN       NaN
# 1           1  0.054449  0.164360       0  0.014603  0.192920
# 2           2  0.107650  0.090811       0  0.054449  0.164360
# 3           3  0.133720  0.086496       0  0.107650  0.090811
# 4           4  0.112650  0.099235       0  0.133720  0.086496
#
#    rolling_mean_DE  rolling_mean_FE  DE_pct_change  FE_pct_change  \
# 0              NaN              NaN            NaN            NaN
# 1              NaN              NaN       2.728617      -0.148041
# 2              NaN              NaN       0.977079      -0.447487
# 3              NaN              NaN       0.242174      -0.047516
# 4              NaN              NaN      -0.157568       0.147278
#
#    DE_pct_change_5  FE_pct_change_5  expanding_mean_DE  expanding_mean_FE
# 0              NaN              NaN                NaN                NaN
# 1              NaN              NaN           0.034526           0.178640
# 2              NaN              NaN           0.058901           0.149364
# 3              NaN              NaN           0.077605           0.133647
# 4              NaN              NaN           0.084614           0.126764

# %%
df['status'].value_counts()[1]
# Out:
# 100

# %%
df['status'].value_counts()[0]
# Out:
# 19900

# %%
X = df.drop(['status'], axis=1)

y = df['status']

# %%
le = LabelEncoder()
y = le.fit_transform(y)
y
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
X=X.fillna(0)
X
# Out:
#        Unnamed: 0        DE        FE    lag_DE    lag_FE  rolling_mean_DE  \
# 0               0  0.014603  0.192920  0.000000  0.000000         0.000000
# 1               1  0.054449  0.164360  0.014603  0.192920         0.000000
# 2               2  0.107650  0.090811  0.054449  0.164360         0.000000
# 3               3  0.133720  0.086496  0.107650  0.090811         0.000000
# 4               4  0.112650  0.099235  0.133720  0.086496         0.000000
# ...           ...       ...       ...       ...       ...              ...
# 19995       19995  0.028789  0.016642  0.081360 -0.055473         0.068246
# 19996       19996 -0.042766  0.073347  0.028789  0.016642         0.046730
# 19997       19997 -0.077605  0.079305 -0.042766  0.073347         0.024378
# 19998       19998 -0.061333  0.044789 -0.077605  0.079305         0.008494
# 19999       19999 -0.006676 -0.031640 -0.061333  0.044789        -0.000179
#
#        rolling_mean_FE  DE_pct_change  FE_pct_change  DE_pct_change_5  \
# 0             0.000000       0.000000       0.000000         0.000000
# 1             0.000000       2.728617      -0.148041         0.000000
# 2             0.000000       0.977079      -0.447487         0.000000
# 3             0.000000       0.242174      -0.047516         0.000000
# 4             0.000000      -0.157568       0.147278         0.000000
# ...                ...            ...            ...              ...
# 19995        -0.051100      -0.646153      -1.300002        -0.634921
# 19996        -0.031669      -2.485498       3.407343        -1.857739
# 19997        -0.012973       0.814642       0.081230        -2.436305
# 19998         0.003727      -0.209677      -0.435231        -1.796750
# 19999         0.008247      -0.891156      -1.706423        -1.082051
#
#        FE_pct_change_5  expanding_mean_DE  expanding_mean_FE
# 0             0.000000           0.000000           0.000000
# 1             0.000000           0.034526           0.178640
# 2             0.000000           0.058901           0.149364
# 3             0.000000           0.077605           0.133647
# 4             0.000000           0.084614           0.126764
# ...                ...                ...                ...
# 19995        -1.322713           0.013112           0.032767
# 19996        -2.017084           0.013110           0.032769
# 19997        -2.253240           0.013105           0.032772
# 19998        -1.646885           0.013101           0.032772
# 19999        -0.429632           0.013100           0.032769
#
# [20000 rows x 13 columns]

# %%
y_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# Feature scaling

# %%
X=X.drop(['Unnamed: 0'], axis=1)
X=X.round(3)
X
# Out:
#           DE     FE  lag_DE  lag_FE  rolling_mean_DE  rolling_mean_FE  \
# 0      0.015  0.193   0.000   0.000            0.000            0.000
# 1      0.054  0.164   0.015   0.193            0.000            0.000
# 2      0.108  0.091   0.054   0.164            0.000            0.000
# 3      0.134  0.086   0.108   0.091            0.000            0.000
# 4      0.113  0.099   0.134   0.086            0.000            0.000
# ...      ...    ...     ...     ...              ...              ...
# 19995  0.029  0.017   0.081  -0.055            0.068           -0.051
# 19996 -0.043  0.073   0.029   0.017            0.047           -0.032
# 19997 -0.078  0.079  -0.043   0.073            0.024           -0.013
# 19998 -0.061  0.045  -0.078   0.079            0.008            0.004
# 19999 -0.007 -0.032  -0.061   0.045           -0.000            0.008
#
#        DE_pct_change  FE_pct_change  DE_pct_change_5  FE_pct_change_5  \
# 0              0.000          0.000            0.000            0.000
# 1              2.729         -0.148            0.000            0.000
# 2              0.977         -0.447            0.000            0.000
# 3              0.242         -0.048            0.000            0.000
# 4             -0.158          0.147            0.000            0.000
# ...              ...            ...              ...              ...
# 19995         -0.646         -1.300           -0.635           -1.323
# 19996         -2.485          3.407           -1.858           -2.017
# 19997          0.815          0.081           -2.436           -2.253
# 19998         -0.210         -0.435           -1.797           -1.647
# 19999         -0.891         -1.706           -1.082           -0.430
#
#        expanding_mean_DE  expanding_mean_FE
# 0                  0.000              0.000
# 1                  0.035              0.179
# 2                  0.059              0.149
# 3                  0.078              0.134
# 4                  0.085              0.127
# ...                  ...                ...
# 19995              0.013              0.033
# 19996              0.013              0.033
# 19997              0.013              0.033
# 19998              0.013              0.033
# 19999              0.013              0.033
#
# [20000 rows x 12 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
X_train.shape, X_test.shape
# Out:
# ((16000, 12), (4000, 12))

# %%
X_train
# Out:
#           DE     FE  lag_DE  lag_FE  rolling_mean_DE  rolling_mean_FE  \
# 17815  0.081 -0.075   0.061  -0.058            0.032           -0.024
# 18370  0.044  0.007   0.053  -0.046           -0.013           -0.020
# 1379   0.050 -0.075   0.069  -0.125            0.047           -0.090
# 14763 -0.037  0.116   0.019   0.053           -0.000            0.023
# 7346   0.170  0.142   0.179   0.066            0.074            0.081
# ...      ...    ...     ...     ...              ...              ...
# 13123  0.027 -0.025   0.002   0.008           -0.046            0.045
# 19648  0.081 -0.162   0.049  -0.159            0.035           -0.084
# 9845  -0.027 -0.034  -0.096  -0.008           -0.052            0.021
# 10799 -0.021 -0.030  -0.024  -0.064            0.028           -0.006
# 2732   0.036 -0.140   0.051  -0.140            0.018           -0.087
#
#        DE_pct_change  FE_pct_change  DE_pct_change_5  FE_pct_change_5  \
# 17815          0.333          0.285            1.985            2.230
# 18370         -0.176         -1.152           -1.764           -2.889
# 1379          -0.269         -0.403           -0.087           -0.088
# 14763         -2.914          1.177            0.092          -48.167
# 7346          -0.050          1.153          -12.628            0.304
# ...              ...            ...              ...              ...
# 13123         13.223         -4.128           -1.360           -1.581
# 19648          0.641          0.018            0.404            1.405
# 9845          -0.715          3.395           -2.180           -2.777
# 10799         -0.089         -0.537           -1.184           -3.636
# 2732          -0.293          0.003            1.023            0.848
#
#        expanding_mean_DE  expanding_mean_FE
# 17815              0.013              0.033
# 18370              0.013              0.033
# 1379               0.012              0.032
# 14763              0.013              0.033
# 7346               0.013              0.032
# ...                  ...                ...
# 13123              0.012              0.033
# 19648              0.013              0.033
# 9845               0.012              0.032
# 10799              0.012              0.033
# 2732               0.013              0.032
#
# [16000 rows x 12 columns]

# %%
# Feature scaling
# Fill missing values with a constant
X_train = X_train.fillna(0)
X_test = X_test.fillna(0)

X_train = X_train.replace([np.inf, -np.inf], 0) 
X_test = X_test.replace([np.inf, -np.inf], 0) 

cols = X_train.columns

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

X_train = pd.DataFrame(X_train, columns=[cols])
X_test = pd.DataFrame(X_test, columns=[cols])

# %%
scaler = StandardScaler()

# Feature scaling
# Fill missing values with a constant
X = X.fillna(0)

X = X.replace([np.inf, -np.inf], 0) 

cols = X.columns

scaler = StandardScaler()
X = scaler.fit_transform(X)

X = pd.DataFrame(X, columns=[cols])

# %%
# define model
model = XGBClassifier()
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: %.5f' % mean(scores))
# Out:
# Mean ROC AUC: 0.88246

# %%
model = XGBClassifier()

clf_0 = model.fit(X_train, y_train)

# %%
pred_y_0 = clf_0.predict(X_test)

print(accuracy_score(pred_y_0, y_test))
# Out:
# 0.9955

# %%
target_names = ['class 0', 'class 1']
print(classification_report(y_test, pred_y_0, target_names=target_names))

# View confusion matrix for test data and predictions
confusion_matrix(y_test, pred_y_0)
# Out:
#               precision    recall  f1-score   support
#
#      class 0       1.00      1.00      1.00      3983
#      class 1       0.00      0.00      0.00        17
#
#     accuracy                           1.00      4000
#    macro avg       0.50      0.50      0.50      4000
# weighted avg       0.99      1.00      0.99      4000
# array([[3982,    1],
#        [  17,    0]])

# %% [markdown]
# # Weighted XGBoost for Class Imbalance

# %%
# define model
#scale_pos_weight=total_negative_examples / total_positive_examples
#total number of examples in the majority class / total number of examples in the minority class.
#19900/100=199
model = XGBClassifier(scale_pos_weight=199)

# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: %.5f' % mean(scores))
# Out:
# Mean ROC AUC: 0.86808

# %%
clf_1 = model.fit(X_train, y_train)
pred_y_1 = clf_1.predict(X_test)

print(accuracy_score(pred_y_1, y_test))
# Out:
# 0.99475

# %%
target_names = ['class 0', 'class 1']
print(classification_report(y_test, pred_y_1, target_names=target_names))

# View confusion matrix for test data and predictions
confusion_matrix(y_test, pred_y_1)
# Out:
#               precision    recall  f1-score   support
#
#      class 0       1.00      1.00      1.00      3983
#      class 1       0.17      0.06      0.09        17
#
#     accuracy                           0.99      4000
#    macro avg       0.58      0.53      0.54      4000
# weighted avg       0.99      0.99      0.99      4000
# array([[3978,    5],
#        [  16,    1]])

# %% [markdown]
# # Tune with GridSearch CV

# %%
# define grid
weights = [1, 10, 25, 50, 75, 99, 100, 1000]
param_grid = dict(scale_pos_weight=weights)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# define grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='roc_auc')

# %%
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.882464 using {'scale_pos_weight': 1}
# 0.882464 (0.033614) with: {'scale_pos_weight': 1}
# 0.881350 (0.035238) with: {'scale_pos_weight': 10}
# 0.880690 (0.033526) with: {'scale_pos_weight': 25}
# 0.874328 (0.040966) with: {'scale_pos_weight': 50}
# 0.878481 (0.038425) with: {'scale_pos_weight': 75}
# 0.877611 (0.037845) with: {'scale_pos_weight': 99}
# 0.876945 (0.034700) with: {'scale_pos_weight': 100}
# 0.867938 (0.035687) with: {'scale_pos_weight': 1000}

# %%
# define model
model = XGBClassifier(scale_pos_weight=500)

# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: %.5f' % np.mean(scores))
# Out:
# Mean ROC AUC: 0.86290

# %%
clf_2 = model.fit(X_train, y_train)
pred_y_2 = clf_2.predict(X_test)

print(accuracy_score(pred_y_2, y_test))
# Out:
# 0.9945

# %%
target_names = ['class 0', 'class 1']
print(classification_report(y_test, pred_y_2, target_names=target_names))

# View confusion matrix for test data and predictions
confusion_matrix(y_test, pred_y_2)
# Out:
#               precision    recall  f1-score   support
#
#      class 0       1.00      1.00      1.00      3983
#      class 1       0.14      0.06      0.08        17
#
#     accuracy                           0.99      4000
#    macro avg       0.57      0.53      0.54      4000
# weighted avg       0.99      0.99      0.99      4000
# array([[3977,    6],
#        [  16,    1]])
