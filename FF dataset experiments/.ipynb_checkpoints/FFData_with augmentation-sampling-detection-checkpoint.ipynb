# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import numpy as np
from pylab import rcParams

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import recall_score, classification_report, auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, f1_score

from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from numpy import mean

from imblearn.pipeline import Pipeline
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import TomekLinks
from imblearn.combine import SMOTEENN
from imblearn.under_sampling import EditedNearestNeighbours

from imblearn.over_sampling import ADASYN
from collections import Counter
from sklearn.metrics import accuracy_score

from numpy.random import seed
seed(7)

from sklearn.model_selection import train_test_split

SEED = 123 #used to help randomly select the data points
DATA_SPLIT_PCT = 0.2

rcParams['figure.figsize'] = 8, 6
LABELS = ["Normal","Break"]

# %%
df = pd.read_csv("combined_filtered_aug.csv") 
df.head(n=5)
# Out:
#    Unnamed: 0                     _time  GreenRocket  Door1  Door2  \
# 0           0  2023-09-19T14:21:53.393Z            1      0      0
# 1           1  2023-09-19T14:21:53.485Z            1      0      0
# 2           2  2023-09-19T14:21:53.582Z            1      0      0
# 3           3  2023-09-19T14:21:53.687Z            1      0      0
# 4           4  2023-09-19T14:21:53.793Z            1      0      0
#
#    LoadCell_R02  Potentiometer_R02  LoadCell_R03  Potentiometer_R03  \
# 0          1857              11866          1693               2390
# 1          1862              11896          1679               2396
# 2          1867              11957          1669               2379
# 3          1886              11955          1699               2403
# 4          1887              11966          1670               2388
#
#    LoadCell_R04  ...  rolling_mean_Potentiometer_R04  \
# 0          2640  ...                             NaN
# 1          2643  ...                             NaN
# 2          2659  ...                             NaN
# 3          2612  ...                             NaN
# 4          2630  ...                             NaN
#
#    expanding_mean_GreenRocket  expanding_mean_Door1  expanding_mean_Door2  \
# 0                         NaN                   NaN                   NaN
# 1                         1.0                   0.0                   0.0
# 2                         1.0                   0.0                   0.0
# 3                         1.0                   0.0                   0.0
# 4                         1.0                   0.0                   0.0
#
#    expanding_mean_LoadCell_R02  expanding_mean_Potentiometer_R02  \
# 0                          NaN                               NaN
# 1                       1859.5                      11881.000000
# 2                       1862.0                      11906.333333
# 3                       1868.0                      11918.500000
# 4                       1871.8                      11928.000000
#
#    expanding_mean_LoadCell_R03  expanding_mean_Potentiometer_R03  \
# 0                          NaN                               NaN
# 1                  1686.000000                       2393.000000
# 2                  1680.333333                       2388.333333
# 3                  1685.000000                       2392.000000
# 4                  1682.000000                       2391.200000
#
#    expanding_mean_LoadCell_R04  expanding_mean_Potentiometer_R04
# 0                          NaN                               NaN
# 1                  2641.500000                      11881.500000
# 2                  2647.333333                      11900.666667
# 3                  2638.500000                      11908.500000
# 4                  2636.800000                      11913.000000
#
# [5 rows x 49 columns]

# %%
df['Success'] = df['Success'].replace({1: 0, 0: 1})
df
# Out:
#         Unnamed: 0                     _time  GreenRocket  Door1  Door2  \
# 0                0  2023-09-19T14:21:53.393Z            1      0      0
# 1                1  2023-09-19T14:21:53.485Z            1      0      0
# 2                2  2023-09-19T14:21:53.582Z            1      0      0
# 3                3  2023-09-19T14:21:53.687Z            1      0      0
# 4                4  2023-09-19T14:21:53.793Z            1      0      0
# ...            ...                       ...          ...    ...    ...
# 216029      216029  2023-09-19T20:21:59.584Z            0      0      0
# 216030      216030  2023-09-19T20:21:59.686Z            0      0      0
# 216031      216031  2023-09-19T20:21:59.785Z            0      0      0
# 216032      216032  2023-09-19T20:21:59.887Z            0      0      0
# 216033      216033  2023-09-19T20:21:59.981Z            0      0      0
#
#         LoadCell_R02  Potentiometer_R02  LoadCell_R03  Potentiometer_R03  \
# 0               1857              11866          1693               2390
# 1               1862              11896          1679               2396
# 2               1867              11957          1669               2379
# 3               1886              11955          1699               2403
# 4               1887              11966          1670               2388
# ...              ...                ...           ...                ...
# 216029          1888               2061          1676               2382
# 216030          1854               2061          1686               2404
# 216031          1859               2073          1685               2403
# 216032          1860               2067          1655               2385
# 216033          1883               2071          1680               2396
#
#         LoadCell_R04  ...  rolling_mean_Potentiometer_R04  \
# 0               2640  ...                             NaN
# 1               2643  ...                             NaN
# 2               2659  ...                             NaN
# 3               2612  ...                             NaN
# 4               2630  ...                             NaN
# ...              ...  ...                             ...
# 216029          2604  ...                    11871.714286
# 216030          2776  ...                    11868.571429
# 216031          3218  ...                    11877.857143
# 216032          2176  ...                    11878.285714
# 216033          3437  ...                    11884.000000
#
#         expanding_mean_GreenRocket  expanding_mean_Door1  \
# 0                              NaN                   NaN
# 1                         1.000000              0.000000
# 2                         1.000000              0.000000
# 3                         1.000000              0.000000
# 4                         1.000000              0.000000
# ...                            ...                   ...
# 216029                    0.027325              0.015229
# 216030                    0.027325              0.015229
# 216031                    0.027325              0.015229
# 216032                    0.027325              0.015229
# 216033                    0.027324              0.015229
#
#         expanding_mean_Door2  expanding_mean_LoadCell_R02  \
# 0                        NaN                          NaN
# 1                   0.000000                  1859.500000
# 2                   0.000000                  1862.000000
# 3                   0.000000                  1868.000000
# 4                   0.000000                  1871.800000
# ...                      ...                          ...
# 216029              0.018849                  1869.839615
# 216030              0.018849                  1869.839542
# 216031              0.018849                  1869.839491
# 216032              0.018849                  1869.839446
# 216033              0.018849                  1869.839507
#
#         expanding_mean_Potentiometer_R02  expanding_mean_LoadCell_R03  \
# 0                                    NaN                          NaN
# 1                           11881.000000                  1686.000000
# 2                           11906.333333                  1680.333333
# 3                           11918.500000                  1685.000000
# 4                           11928.000000                  1682.000000
# ...                                  ...                          ...
# 216029                      11245.814230                  2760.599134
# 216030                      11245.771713                  2760.594160
# 216031                      11245.729253                  2760.589181
# 216032                      11245.686765                  2760.584064
# 216033                      11245.644297                  2760.579062
#
#         expanding_mean_Potentiometer_R03  expanding_mean_LoadCell_R04  \
# 0                                    NaN                          NaN
# 1                            2393.000000                  2641.500000
# 2                            2388.333333                  2647.333333
# 3                            2392.000000                  2638.500000
# 4                            2391.200000                  2636.800000
# ...                                  ...                          ...
# 216029                       3642.971143                  3006.628565
# 216030                       3642.965408                  3006.627498
# 216031                       3642.959668                  3006.628476
# 216032                       3642.953845                  3006.624631
# 216033                       3642.948073                  3006.626624
#
#         expanding_mean_Potentiometer_R04
# 0                                    NaN
# 1                           11881.500000
# 2                           11900.666667
# 3                           11908.500000
# 4                           11913.000000
# ...                                  ...
# 216029                      10718.385798
# 216030                      10718.391166
# 216031                      10718.396714
# 216032                      10718.402202
# 216033                      10718.407700
#
# [216034 rows x 49 columns]

# %%
df['Success'].value_counts()
# Out:
# 0    212296
# 1      3738
# Name: Success, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216034 entries, 0 to 216033
# Data columns (total 49 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Unnamed: 0                        216034 non-null  int64
#  1   _time                             216034 non-null  object
#  2   GreenRocket                       216034 non-null  int64
#  3   Door1                             216034 non-null  int64
#  4   Door2                             216034 non-null  int64
#  5   LoadCell_R02                      216034 non-null  int64
#  6   Potentiometer_R02                 216034 non-null  int64
#  7   LoadCell_R03                      216034 non-null  int64
#  8   Potentiometer_R03                 216034 non-null  int64
#  9   LoadCell_R04                      216034 non-null  int64
#  10  Potentiometer_R04                 216034 non-null  int64
#  11  Anomally                          216034 non-null  int64
#  12  Success                           216034 non-null  int64
#  13  GreenRocket_pct_change            5974 non-null    float64
#  14  Door1_pct_change                  3303 non-null    float64
#  15  Door2_pct_change                  4079 non-null    float64
#  16  LoadCell_R02_pct_change           216033 non-null  float64
#  17  Potentiometer_R02_pct_change      216033 non-null  float64
#  18  LoadCell_R03_pct_change           216033 non-null  float64
#  19  Potentiometer_R03_pct_change      216033 non-null  float64
#  20  LoadCell_R04_pct_change           216033 non-null  float64
#  21  Potentiometer_R04_pct_change      216033 non-null  float64
#  22  lag_GreenRocket                   216033 non-null  float64
#  23  lag_Door1                         216033 non-null  float64
#  24  lag_Door2                         216033 non-null  float64
#  25  lag_LoadCell_R02                  216033 non-null  float64
#  26  lag_Potentiometer_R02             216033 non-null  float64
#  27  lag_LoadCell_R03                  216033 non-null  float64
#  28  lag_Potentiometer_R03             216033 non-null  float64
#  29  lag_LoadCell_R04                  216033 non-null  float64
#  30  lag_Potentiometer_R04             216033 non-null  float64
#  31  rolling_mean_GreenRocket          216028 non-null  float64
#  32  rolling_mean_Door1                216028 non-null  float64
#  33  rolling_mean_Door2                216028 non-null  float64
#  34  rolling_mean_LoadCell_R02         216028 non-null  float64
#  35  rolling_mean_Potentiometer_R02    216028 non-null  float64
#  36  rolling_mean_LoadCell_R03         216028 non-null  float64
#  37  rolling_mean_Potentiometer_R03    216028 non-null  float64
#  38  rolling_mean_LoadCell_R04         216028 non-null  float64
#  39  rolling_mean_Potentiometer_R04    216028 non-null  float64
#  40  expanding_mean_GreenRocket        216033 non-null  float64
#  41  expanding_mean_Door1              216033 non-null  float64
#  42  expanding_mean_Door2              216033 non-null  float64
#  43  expanding_mean_LoadCell_R02       216033 non-null  float64
#  44  expanding_mean_Potentiometer_R02  216033 non-null  float64
#  45  expanding_mean_LoadCell_R03       216033 non-null  float64
#  46  expanding_mean_Potentiometer_R03  216033 non-null  float64
#  47  expanding_mean_LoadCell_R04       216033 non-null  float64
#  48  expanding_mean_Potentiometer_R04  216033 non-null  float64
# dtypes: float64(36), int64(12), object(1)
# memory usage: 80.8+ MB

# %%
# Remove time column
df = df.drop(['_time','Unnamed: 0'], axis=1)

# %%
df.replace([np.inf, -np.inf], 0, inplace=True)
df
# Out:
#         GreenRocket  Door1  Door2  LoadCell_R02  Potentiometer_R02  \
# 0                 1      0      0          1857              11866
# 1                 1      0      0          1862              11896
# 2                 1      0      0          1867              11957
# 3                 1      0      0          1886              11955
# 4                 1      0      0          1887              11966
# ...             ...    ...    ...           ...                ...
# 216029            0      0      0          1888               2061
# 216030            0      0      0          1854               2061
# 216031            0      0      0          1859               2073
# 216032            0      0      0          1860               2067
# 216033            0      0      0          1883               2071
#
#         LoadCell_R03  Potentiometer_R03  LoadCell_R04  Potentiometer_R04  \
# 0               1693               2390          2640              11855
# 1               1679               2396          2643              11908
# 2               1669               2379          2659              11939
# 3               1699               2403          2612              11932
# 4               1670               2388          2630              11931
# ...              ...                ...           ...                ...
# 216029          1676               2382          2604              11801
# 216030          1686               2404          2776              11878
# 216031          1685               2403          3218              11917
# 216032          1655               2385          2176              11904
# 216033          1680               2396          3437              11906
#
#         Anomally  ...  rolling_mean_Potentiometer_R04  \
# 0              0  ...                             NaN
# 1              0  ...                             NaN
# 2              0  ...                             NaN
# 3              0  ...                             NaN
# 4              0  ...                             NaN
# ...          ...  ...                             ...
# 216029         1  ...                    11871.714286
# 216030         1  ...                    11868.571429
# 216031         1  ...                    11877.857143
# 216032         1  ...                    11878.285714
# 216033         1  ...                    11884.000000
#
#         expanding_mean_GreenRocket  expanding_mean_Door1  \
# 0                              NaN                   NaN
# 1                         1.000000              0.000000
# 2                         1.000000              0.000000
# 3                         1.000000              0.000000
# 4                         1.000000              0.000000
# ...                            ...                   ...
# 216029                    0.027325              0.015229
# 216030                    0.027325              0.015229
# 216031                    0.027325              0.015229
# 216032                    0.027325              0.015229
# 216033                    0.027324              0.015229
#
#         expanding_mean_Door2  expanding_mean_LoadCell_R02  \
# 0                        NaN                          NaN
# 1                   0.000000                  1859.500000
# 2                   0.000000                  1862.000000
# 3                   0.000000                  1868.000000
# 4                   0.000000                  1871.800000
# ...                      ...                          ...
# 216029              0.018849                  1869.839615
# 216030              0.018849                  1869.839542
# 216031              0.018849                  1869.839491
# 216032              0.018849                  1869.839446
# 216033              0.018849                  1869.839507
#
#         expanding_mean_Potentiometer_R02  expanding_mean_LoadCell_R03  \
# 0                                    NaN                          NaN
# 1                           11881.000000                  1686.000000
# 2                           11906.333333                  1680.333333
# 3                           11918.500000                  1685.000000
# 4                           11928.000000                  1682.000000
# ...                                  ...                          ...
# 216029                      11245.814230                  2760.599134
# 216030                      11245.771713                  2760.594160
# 216031                      11245.729253                  2760.589181
# 216032                      11245.686765                  2760.584064
# 216033                      11245.644297                  2760.579062
#
#         expanding_mean_Potentiometer_R03  expanding_mean_LoadCell_R04  \
# 0                                    NaN                          NaN
# 1                            2393.000000                  2641.500000
# 2                            2388.333333                  2647.333333
# 3                            2392.000000                  2638.500000
# 4                            2391.200000                  2636.800000
# ...                                  ...                          ...
# 216029                       3642.971143                  3006.628565
# 216030                       3642.965408                  3006.627498
# 216031                       3642.959668                  3006.628476
# 216032                       3642.953845                  3006.624631
# 216033                       3642.948073                  3006.626624
#
#         expanding_mean_Potentiometer_R04
# 0                                    NaN
# 1                           11881.500000
# 2                           11900.666667
# 3                           11908.500000
# 4                           11913.000000
# ...                                  ...
# 216029                      10718.385798
# 216030                      10718.391166
# 216031                      10718.396714
# 216032                      10718.402202
# 216033                      10718.407700
#
# [216034 rows x 47 columns]

# %%
X = df.drop(['Success','Anomally'], axis=1)
y = df['Success']

# %%
X
X=X.fillna(0)
X
# Out:
#         GreenRocket  Door1  Door2  LoadCell_R02  Potentiometer_R02  \
# 0                 1      0      0          1857              11866
# 1                 1      0      0          1862              11896
# 2                 1      0      0          1867              11957
# 3                 1      0      0          1886              11955
# 4                 1      0      0          1887              11966
# ...             ...    ...    ...           ...                ...
# 216029            0      0      0          1888               2061
# 216030            0      0      0          1854               2061
# 216031            0      0      0          1859               2073
# 216032            0      0      0          1860               2067
# 216033            0      0      0          1883               2071
#
#         LoadCell_R03  Potentiometer_R03  LoadCell_R04  Potentiometer_R04  \
# 0               1693               2390          2640              11855
# 1               1679               2396          2643              11908
# 2               1669               2379          2659              11939
# 3               1699               2403          2612              11932
# 4               1670               2388          2630              11931
# ...              ...                ...           ...                ...
# 216029          1676               2382          2604              11801
# 216030          1686               2404          2776              11878
# 216031          1685               2403          3218              11917
# 216032          1655               2385          2176              11904
# 216033          1680               2396          3437              11906
#
#         GreenRocket_pct_change  ...  rolling_mean_Potentiometer_R04  \
# 0                          0.0  ...                        0.000000
# 1                          0.0  ...                        0.000000
# 2                          0.0  ...                        0.000000
# 3                          0.0  ...                        0.000000
# 4                          0.0  ...                        0.000000
# ...                        ...  ...                             ...
# 216029                     0.0  ...                    11871.714286
# 216030                     0.0  ...                    11868.571429
# 216031                     0.0  ...                    11877.857143
# 216032                     0.0  ...                    11878.285714
# 216033                     0.0  ...                    11884.000000
#
#         expanding_mean_GreenRocket  expanding_mean_Door1  \
# 0                         0.000000              0.000000
# 1                         1.000000              0.000000
# 2                         1.000000              0.000000
# 3                         1.000000              0.000000
# 4                         1.000000              0.000000
# ...                            ...                   ...
# 216029                    0.027325              0.015229
# 216030                    0.027325              0.015229
# 216031                    0.027325              0.015229
# 216032                    0.027325              0.015229
# 216033                    0.027324              0.015229
#
#         expanding_mean_Door2  expanding_mean_LoadCell_R02  \
# 0                   0.000000                     0.000000
# 1                   0.000000                  1859.500000
# 2                   0.000000                  1862.000000
# 3                   0.000000                  1868.000000
# 4                   0.000000                  1871.800000
# ...                      ...                          ...
# 216029              0.018849                  1869.839615
# 216030              0.018849                  1869.839542
# 216031              0.018849                  1869.839491
# 216032              0.018849                  1869.839446
# 216033              0.018849                  1869.839507
#
#         expanding_mean_Potentiometer_R02  expanding_mean_LoadCell_R03  \
# 0                               0.000000                     0.000000
# 1                           11881.000000                  1686.000000
# 2                           11906.333333                  1680.333333
# 3                           11918.500000                  1685.000000
# 4                           11928.000000                  1682.000000
# ...                                  ...                          ...
# 216029                      11245.814230                  2760.599134
# 216030                      11245.771713                  2760.594160
# 216031                      11245.729253                  2760.589181
# 216032                      11245.686765                  2760.584064
# 216033                      11245.644297                  2760.579062
#
#         expanding_mean_Potentiometer_R03  expanding_mean_LoadCell_R04  \
# 0                               0.000000                     0.000000
# 1                            2393.000000                  2641.500000
# 2                            2388.333333                  2647.333333
# 3                            2392.000000                  2638.500000
# 4                            2391.200000                  2636.800000
# ...                                  ...                          ...
# 216029                       3642.971143                  3006.628565
# 216030                       3642.965408                  3006.627498
# 216031                       3642.959668                  3006.628476
# 216032                       3642.953845                  3006.624631
# 216033                       3642.948073                  3006.626624
#
#         expanding_mean_Potentiometer_R04
# 0                               0.000000
# 1                           11881.500000
# 2                           11900.666667
# 3                           11908.500000
# 4                           11913.000000
# ...                                  ...
# 216029                      10718.385798
# 216030                      10718.391166
# 216031                      10718.396714
# 216032                      10718.402202
# 216033                      10718.407700
#
# [216034 rows x 45 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
X_train.shape, X_test.shape
# Out:
# ((172827, 45), (43207, 45))

# %%
# Feature scaling

# %%
cols = X_train.columns

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

X_train = pd.DataFrame(X_train, columns=[cols])
X_test = pd.DataFrame(X_test, columns=[cols])

# %%
# define model
model = XGBClassifier()

# %%
# Define SMOTE-Tomek Links
resample=SMOTETomek(tomek=TomekLinks(sampling_strategy='majority'))
# Define pipeline
pipeline=Pipeline(steps=[('r', resample), ('m', model)])

# %%
clf_0 = pipeline.fit(X_train, y_train)

# %%
pred_y_0 = clf_0.predict(X_test)

print(accuracy_score(pred_y_0, y_test))
# Out:
# 0.9999537112042031

# %%
target_names = ['class 0', 'class 1']
print(classification_report(y_test, pred_y_0, target_names=target_names))

# View confusion matrix for test data and predictions
confusion_matrix(y_test, pred_y_0)
# Out:
#               precision    recall  f1-score   support
#
#      class 0       1.00      1.00      1.00     42477
#      class 1       1.00      1.00      1.00       730
#
#     accuracy                           1.00     43207
#    macro avg       1.00      1.00      1.00     43207
# weighted avg       1.00      1.00      1.00     43207
# array([[42476,     1],
#        [    1,   729]])

# %%
#enn

# %%
# define model
model = XGBClassifier()

#Define SMOTE-ENN
resample=SMOTEENN(enn=EditedNearestNeighbours(sampling_strategy='all'))
#Define pipeline
pipeline=Pipeline(steps=[('r', resample), ('m', model)])

# %%
pipeline
# Out:
# Pipeline(steps=[('r',
#                  SMOTEENN(enn=EditedNearestNeighbours(sampling_strategy='all'))),
#                 ('m',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric=None,
#                                feature_types=None, gamma=None, gpu_id=None,
#                                grow_policy=None, importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, n_estimators=100,
#                                n_jobs=None, num_parallel_tree=None,
#                                predictor=None, random_state=None, ...))])

# %%
clf_2 = pipeline.fit(X_train, y_train)
pred_y_2 = clf_2.predict(X_test)

print(accuracy_score(pred_y_2, y_test))
# Out:
# 0.9995371120420302

# %%
target_names = ['class 0', 'class 1']
print(classification_report(y_test, pred_y_2, target_names=target_names))

# View confusion matrix for test data and predictions
confusion_matrix(y_test, pred_y_2)
# Out:
#               precision    recall  f1-score   support
#
#      class 0       1.00      1.00      1.00     42477
#      class 1       0.97      1.00      0.99       730
#
#     accuracy                           1.00     43207
#    macro avg       0.99      1.00      0.99     43207
# weighted avg       1.00      1.00      1.00     43207
# array([[42458,    19],
#        [    1,   729]])

# %%
#ADASYN
ada = ADASYN(random_state=42)
X_res, y_res = ada.fit_resample(X, y)

# %%
print('Resampled dataset shape %s' % Counter(y_res))
# Out:
# Resampled dataset shape Counter({1: 212528, 0: 212296})

# %%
model = XGBClassifier()

#Define ADASYN
resample=ADASYN(random_state=42)
#Define pipeline
pipeline=Pipeline(steps=[('r', resample), ('m', model)])

# %%
clf_2 = pipeline.fit(X_train, y_train)
pred_y_2 = clf_2.predict(X_test)

print(accuracy_score(pred_y_2, y_test))
# Out:
# 0.999907422408406

# %%
target_names = ['class 0', 'class 1']
print(classification_report(y_test, pred_y_2, target_names=target_names))

# View confusion matrix for test data and predictions
confusion_matrix(y_test, pred_y_2)
# Out:
#               precision    recall  f1-score   support
#
#      class 0       1.00      1.00      1.00     42477
#      class 1       1.00      1.00      1.00       730
#
#     accuracy                           1.00     43207
#    macro avg       1.00      1.00      1.00     43207
# weighted avg       1.00      1.00      1.00     43207
# array([[42475,     2],
#        [    2,   728]])
